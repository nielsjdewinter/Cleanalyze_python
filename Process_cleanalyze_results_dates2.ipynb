# %% [markdown]
# # Combine and process Cleanalyze results

# %% [markdown]
# Author: **Niels J. de Winter** (*n.j.de.winter@vu.nl*)<br>
# Assistant Professor Vrije Universiteit Amsterdam

# %% [markdown]
# ## Load packages

# %%
import os
import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib.dates as mdates
import numpy as np
import pandas as pd
import re
from sklearn.linear_model import LinearRegression
from scipy.stats import t
from collections import OrderedDict

# %% [markdown]
# ## Read all cleanalyze data

# %%
folder_path = "Cleanalyze_results"
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')] # List all CSV files in the folder
dataframes = {}

for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    dataframes[file] = df

# Print the first few rows of each DataFrame
for file, df in dataframes.items():
    print(f"Data from {file}:")
    print(df.head(), "\n")  # Display the first few rows of each DataFrame
    print(f"Shape: {df.shape}\n")  # Print the shape of the DataFrame
    print(f"Columns: {df.columns.tolist()}\n")  # Print the column names
    print("-" * 40)  # Separator for clarity
# Out:
# Data from B255_int_peakid.csv:
#       depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.445779        0.013676  62.33211  30944.10620  80703.27530  6301.588000
# 1  0.891558        0.000000  62.44125  30944.46978  80703.01737  5301.123838
# 2  1.337336        0.019326  62.55040  30944.83337  80702.75945  4600.846556
# 3  1.783115        0.037763  62.65955  30945.19695  80702.50152  5751.322804
# 4  2.228894        0.013795  62.76871  30945.56053  80702.24359  6251.562891
#
#     23Na/43Ca  25Mg/43Ca  43Ca/43Ca  55Mn/43Ca  88Sr/43Ca  138Ba/43Ca  \
# 0  199.059248   1.253571       1000   0.306491   0.013676         0.0
# 1  235.482235   3.406310       1000   0.347474   0.000000         0.0
# 2  284.331679   1.771388       1000   0.380053   0.019326         0.0
# 3  221.307763   3.115197       1000   0.348871   0.037763         0.0
# 4  205.558351   1.264443       1000   0.242893   0.013795         0.0
#
#      peakID_1    peakID_2    peakID_3    peakID_4
# 0  interval 7  interval 7  interval 7  interval 7
# 1  interval 7  interval 7  interval 7  interval 7
# 2  interval 7  interval 7  interval 7  interval 7
# 3  interval 7  interval 7  interval 7  interval 7
# 4  interval 7  interval 7  interval 7  interval 7
#
# Shape: (42642, 16)
#
# Columns: ['depth', 'proxy_filtered', 'time', 'Xpos', 'Ypos', 'Ca43', '23Na/43Ca', '25Mg/43Ca', '43Ca/43Ca', '55Mn/43Ca', '88Sr/43Ca', '138Ba/43Ca', 'peakID_1', 'peakID_2', 'peakID_3', 'peakID_4']
#
# ----------------------------------------
# Data from B323_int_peakid.csv:
#      depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.00000        0.024061  62.98675  34712.41390  65012.50220  5551.232374
# 1  0.43145        0.027384  63.09597  34712.41390  65012.50220  4950.980294
# 2  0.86290        0.014567  63.20513  34712.18161  65012.13862  6051.464454
# 3  1.29435        0.035128  63.31432  34711.94932  65011.77504  6251.562891
# 4  1.72580        0.027856  63.42340  34711.71704  65011.41146  6301.588000
#
#     23Na/43Ca  25Mg/43Ca  43Ca/43Ca  55Mn/43Ca  88Sr/43Ca  138Ba/43Ca  \
# 0  302.361806   2.615137       1000   0.561287   0.024061         0.0
# 1  347.383247   3.401471       1000   0.705663   0.027384         0.0
# 2  273.196279   3.053552       1000   0.474172   0.014567         0.0
# 3  267.133045   1.636295       1000   0.531707   0.035128         0.0
# 4  268.982597   2.270707       1000   0.578052   0.027856         0.0
#
#      peakID_1    peakID_2    peakID_3    peakID_4
# 0  interval 7  interval 7  interval 7  interval 7
# 1  interval 7  interval 7  interval 7  interval 7
# 2  interval 7  interval 7  interval 7  interval 7
# 3  interval 7  interval 7  interval 7  interval 7
# 4  interval 7  interval 7  interval 7  interval 7
#
# Shape: (28559, 16)
#
# Columns: ['depth', 'proxy_filtered', 'time', 'Xpos', 'Ypos', 'Ca43', '23Na/43Ca', '25Mg/43Ca', '43Ca/43Ca', '55Mn/43Ca', '88Sr/43Ca', '138Ba/43Ca', 'peakID_1', 'peakID_2', 'peakID_3', 'peakID_4']
#
# ----------------------------------------
# Data from B325_int_peakid.csv:
#       depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.444372        0.036392  62.65810  78402.61730  64997.28160  7102.016973
# 1  0.888743        0.031167  62.76725  78402.42011  64996.88338  5651.277189
# 2  1.333115        0.006792  62.87644  78402.22291  64996.48515  6401.638820
# 3  1.777487        0.008028  62.98558  78402.02572  64996.08693  5501.210266
# 4  2.221858        0.035163  63.09466  78401.82853  64995.68871  6201.537981
#
#     23Na/43Ca  25Mg/43Ca  43Ca/43Ca  55Mn/43Ca  ...  Unnamed: 19  Unnamed: 20  \
# 0  204.097024   1.407290       1000   0.391168  ...          NaN          NaN
# 1  266.786204   2.531021       1000   0.491702  ...          NaN          NaN
# 2  223.407164   1.891035       1000   0.447444  ...          NaN          NaN
# 3  269.015976   0.745080       1000   0.579008  ...          NaN          NaN
# 4  229.901673   1.631700       1000   0.526712  ...          NaN          NaN
#
#    Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24    peakID_1    peakID_2  \
# 0          NaN          NaN          NaN          NaN  interval 7  interval 7
# 1          NaN          NaN          NaN          NaN  interval 7  interval 7
# 2          NaN          NaN          NaN          NaN  interval 7  interval 7
# 3          NaN          NaN          NaN          NaN  interval 7  interval 7
# 4          NaN          NaN          NaN          NaN  interval 7  interval 7
#
#      peakID_3    peakID_4
# 0  interval 7  interval 7
# 1  interval 7  interval 7
# 2  interval 7  interval 7
# 3  interval 7  interval 7
# 4  interval 7  interval 7
#
# [5 rows x 30 columns]
#
# Shape: (27027, 30)
#
# Columns: ['depth', 'proxy_filtered', 'time', 'Xpos', 'Ypos', 'Ca43', '23Na/43Ca', '25Mg/43Ca', '43Ca/43Ca', '55Mn/43Ca', '88Sr/43Ca', '138Ba/43Ca', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'peakID_1', 'peakID_2', 'peakID_3', 'peakID_4']
#
# ----------------------------------------
# Data from G652_sub_peakid.csv:
#       depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.426825        0.131868  62.87978  71074.74930  46513.67210  1650.108907
# 1  0.853650        0.108273  62.98893  71074.59489  46513.27419  1850.136910
# 2  1.280475        0.000000  63.09807  71074.44047  46512.87627  1500.090005
# 3  1.707300        0.139467  63.20722  71074.28606  46512.47836  1600.102407
# 4  2.134126        0.065934  63.31641  71074.13164  46512.08044  1650.108907
#
#      23Na/43Ca  25Mg/43Ca  55Mn/43Ca  88Sr/43Ca  138Ba/43Ca    peakID_1  \
# 0   831.612523   6.181713   2.065418   0.131868         0.0  interval 7
# 1   694.830082   8.459364   1.591473   0.108273         0.0  interval 7
# 2  1055.629092  12.315843   2.279010   0.000000         0.0  interval 7
# 3   936.795248  32.690322   2.117207   0.139467         0.0  interval 7
# 4   889.753685  18.545361   2.128978   0.065934         0.0  interval 7
#
#      peakID_2    peakID_3    peakID_4
# 0  interval 7  interval 7  interval 7
# 1  interval 7  interval 7  interval 7
# 2  interval 7  interval 7  interval 7
# 3  interval 7  interval 7  interval 7
# 4  interval 7  interval 7  interval 7
#
# Shape: (49952, 15)
#
# Columns: ['depth', 'proxy_filtered', 'time', 'Xpos', 'Ypos', 'Ca43', '23Na/43Ca', '25Mg/43Ca', '55Mn/43Ca', '88Sr/43Ca', '138Ba/43Ca', 'peakID_1', 'peakID_2', 'peakID_3', 'peakID_4']
#
# ----------------------------------------
# Data from G664_sub_peakid.csv:
#       depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.000000        0.107353  62.22426  14171.95800  46112.81460  2050.168114
# 1  0.428977        0.342453  62.33340  14171.95800  46112.81460  1650.108907
# 2  0.857955        0.136291  62.44255  14172.18529  46112.45078  1400.078404
# 3  1.286932        0.209988  62.55168  14172.41257  46112.08697  1800.129609
# 4  1.715909        0.168907  62.66084  14172.63986  46111.72315  2000.160013
#
#      23Na/43Ca  25Mg/43Ca  55Mn/43Ca  88Sr/43Ca  138Ba/43Ca    peakID_1  \
# 0  1206.500344  16.066224   3.362566   0.107353         0.0  interval 7
# 1  1863.752400  17.083297   5.040048   0.342453         0.0  interval 7
# 2  2891.445929  45.326997   6.171755   0.136291         0.0  interval 7
# 3  1548.538930  30.262459   3.697988   0.209988         0.0  interval 7
# 4  1244.806237  16.852019   2.719533   0.168907         0.0  interval 7
#
#      peakID_2    peakID_3    peakID_4
# 0  interval 7  interval 7  interval 7
# 1  interval 7  interval 7  interval 7
# 2  interval 7  interval 7  interval 7
# 3  interval 7  interval 7  interval 7
# 4  interval 7  interval 7  interval 7
#
# Shape: (33335, 15)
#
# Columns: ['depth', 'proxy_filtered', 'time', 'Xpos', 'Ypos', 'Ca43', '23Na/43Ca', '25Mg/43Ca', '55Mn/43Ca', '88Sr/43Ca', '138Ba/43Ca', 'peakID_1', 'peakID_2', 'peakID_3', 'peakID_4']
#
# ----------------------------------------
# Data from G668_sub_peakid.csv:
#       depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.000000        0.048755  62.11364  8625.907100  41161.10150  5551.232374
# 1  0.439044        0.034629  62.22280  8625.907100  41161.10150  5251.102732
# 2  0.878088        0.031225  62.33201  8626.305401  41160.91680  5751.322804
# 3  1.317132        0.000000  62.44120  8626.703702  41160.73209  5601.254681
# 4  1.756175        0.022967  62.55036  8627.102003  41160.54739  5851.369220
#
#     23Na/43Ca  25Mg/43Ca  43Ca/43Ca  55Mn/43Ca  88Sr/43Ca  138Ba/43Ca  \
# 0  458.528871   1.874288       1000   0.308624   0.048755         0.0
# 1  497.400198   2.396273       1000   0.372988   0.034629         0.0
# 2  431.939942   1.800586       1000   0.393860   0.031225         0.0
# 3  459.102908   0.371058       1000   0.405829   0.000000         0.0
# 4  438.382655   1.765867       1000   0.334177   0.022967         0.0
#
#      peakID_1    peakID_2    peakID_3    peakID_4
# 0  interval 7  interval 7  interval 7  interval 7
# 1  interval 7  interval 7  interval 7  interval 7
# 2  interval 7  interval 7  interval 7  interval 7
# 3  interval 7  interval 7  interval 7  interval 7
# 4  interval 7  interval 7  interval 7  interval 7
#
# Shape: (23176, 16)
#
# Columns: ['depth', 'proxy_filtered', 'time', 'Xpos', 'Ypos', 'Ca43', '23Na/43Ca', '25Mg/43Ca', '43Ca/43Ca', '55Mn/43Ca', '88Sr/43Ca', '138Ba/43Ca', 'peakID_1', 'peakID_2', 'peakID_3', 'peakID_4']
#
# ----------------------------------------
# Data from G691_int_peakid.csv:
#       depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.435766        0.000000  63.20523  45588.22770  68163.90920  1500.090005
# 1  0.871532        0.157393  63.31441  45588.17617  68163.47649  1700.115608
# 2  1.307298        0.000000  63.42354  45588.12464  68163.04378  2000.160013
# 3  1.743065        0.080150  63.53260  45588.07310  68162.61107  2050.168114
# 4  2.178831        0.191161  63.64181  45588.02157  68162.17837  1500.090005
#
#     23Na/43Ca  25Mg/43Ca  55Mn/43Ca  88Sr/43Ca  138Ba/43Ca    peakID_1  \
# 0  917.594352  10.155490   1.283234   0.000000         0.0  interval 7
# 1  774.881329  15.050864   1.615989   0.157393         0.0  interval 7
# 2  626.522508  11.898104   1.359385   0.000000         0.0  interval 7
# 3  565.469146   5.109603   1.186903   0.080150         0.0  interval 7
# 4  955.848727  20.311184   1.635541   0.191161         0.0  interval 7
#
#      peakID_2    peakID_3    peakID_4
# 0  interval 7  interval 7  interval 7
# 1  interval 7  interval 7  interval 7
# 2  interval 7  interval 7  interval 7
# 3  interval 7  interval 7  interval 7
# 4  interval 7  interval 7  interval 7
#
# Shape: (36478, 15)
#
# Columns: ['depth', 'proxy_filtered', 'time', 'Xpos', 'Ypos', 'Ca43', '23Na/43Ca', '25Mg/43Ca', '55Mn/43Ca', '88Sr/43Ca', '138Ba/43Ca', 'peakID_1', 'peakID_2', 'peakID_3', 'peakID_4']
#
# ----------------------------------------
# Data from G717_sub_peakid.csv:
#       depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.426901        0.004739  62.33120  7579.077500  42112.15500  8953.205247
# 1  0.853803        0.017784  62.44034  7579.300963  42111.79126  9503.611372
# 2  1.280704        0.018405  62.54953  7579.524426  42111.42751  9203.386846
# 3  1.707606        0.019304  62.65869  7579.747890  42111.06377  8803.098691
# 4  2.134507        0.018299  62.76784  7579.971353  42110.70003  9253.423767
#
#     23Na/43Ca  25Mg/43Ca  55Mn/43Ca  88Sr/43Ca  138Ba/43Ca    peakID_1  \
# 0  395.470710   1.547047   0.349787   0.004739         0.0  interval 7
# 1  360.846904   1.865960   0.328137   0.017784         0.0  interval 7
# 2  377.573273   2.145733   0.342410   0.018405         0.0  interval 7
# 3  428.163479   2.700701   0.320863   0.019304         0.0  interval 7
# 4  362.350741   1.066644   0.273445   0.018299         0.0  interval 7
#
#      peakID_2    peakID_3    peakID_4
# 0  interval 7  interval 7  interval 7
# 1  interval 7  interval 7  interval 7
# 2  interval 7  interval 7  interval 7
# 3  interval 7  interval 7  interval 7
# 4  interval 7  interval 7  interval 7
#
# Shape: (30704, 15)
#
# Columns: ['depth', 'proxy_filtered', 'time', 'Xpos', 'Ypos', 'Ca43', '23Na/43Ca', '25Mg/43Ca', '55Mn/43Ca', '88Sr/43Ca', '138Ba/43Ca', 'peakID_1', 'peakID_2', 'peakID_3', 'peakID_4']
#
# ----------------------------------------
# Data from G719_int_peakid.csv:
#       depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.428658        0.010329  61.78710  60546.38580  42455.62070  8302.756515
# 1  0.857316        0.000000  61.89624  60546.69754  42455.32648  9103.313606
# 2  1.285974        0.010680  62.00539  60547.00929  42455.03227  8052.592935
# 3  1.714632        0.000000  62.11452  60547.32103  42454.73805  7702.372331
# 4  2.143290        0.000000  62.22373  60547.63278  42454.44384  8552.925100
#
#     23Na/43Ca  25Mg/43Ca  55Mn/43Ca  88Sr/43Ca  138Ba/43Ca    peakID_1  \
# 0  335.447892   1.456361   0.489067   0.010329         0.0  interval 7
# 1  303.244196   1.317963   0.365297   0.000000         0.0  interval 7
# 2  353.724958   1.756737   0.453477   0.010680         0.0  interval 7
# 3  364.074596   1.317379   0.476090   0.000000         0.0  interval 7
# 4  324.397569   0.470026   0.496084   0.000000         0.0  interval 7
#
#      peakID_2    peakID_3    peakID_4
# 0  interval 7  interval 7  interval 7
# 1  interval 7  interval 7  interval 7
# 2  interval 7  interval 7  interval 7
# 3  interval 7  interval 7  interval 7
# 4  interval 7  interval 7  interval 7
#
# Shape: (35284, 15)
#
# Columns: ['depth', 'proxy_filtered', 'time', 'Xpos', 'Ypos', 'Ca43', '23Na/43Ca', '25Mg/43Ca', '55Mn/43Ca', '88Sr/43Ca', '138Ba/43Ca', 'peakID_1', 'peakID_2', 'peakID_3', 'peakID_4']
#
# ----------------------------------------
# Data from G723_sub_peakid.csv:
#       depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.425918        0.024288  62.33315  48759.23540  40971.44120  5451.188359
# 1  0.851835        0.014299  62.44226  48759.56446  40971.17078  6101.488763
# 2  1.277753        0.044918  62.55130  48759.89352  40970.90036  5851.369220
# 3  1.703670        0.007280  62.66044  48760.22257  40970.62994  6001.440346
# 4  2.129588        0.019110  62.76955  48760.55163  40970.35952  4700.883766
#
#     23Na/43Ca  25Mg/43Ca  43Ca/43Ca  55Mn/43Ca  88Sr/43Ca  138Ba/43Ca  \
# 0  369.318902   2.246180       1000   0.369418   0.024288         0.0
# 1  312.181242   0.991807       1000   0.276584   0.014299         0.0
# 2  331.869392   2.077003       1000   0.293318   0.044918         0.0
# 3  319.828118   2.356614       1000   0.245535   0.007280         0.0
# 4  416.220114   2.209192       1000   0.412302   0.019110         0.0
#
#      peakID_1    peakID_2    peakID_3    peakID_4
# 0  interval 7  interval 7  interval 7  interval 7
# 1  interval 7  interval 7  interval 7  interval 7
# 2  interval 7  interval 7  interval 7  interval 7
# 3  interval 7  interval 7  interval 7  interval 7
# 4  interval 7  interval 7  interval 7  interval 7
#
# Shape: (33782, 16)
#
# Columns: ['depth', 'proxy_filtered', 'time', 'Xpos', 'Ypos', 'Ca43', '23Na/43Ca', '25Mg/43Ca', '43Ca/43Ca', '55Mn/43Ca', '88Sr/43Ca', '138Ba/43Ca', 'peakID_1', 'peakID_2', 'peakID_3', 'peakID_4']
#
# ----------------------------------------
# Data from G728_int_peakid.csv:
#       depth  proxy_filtered      time        Xpos         Ypos         Ca43  \
# 0  0.000000        0.021329  62.11345  8647.57630  63805.31340  9753.803984
# 1  0.438999        0.017606  62.22250  8647.57630  63805.31340  7202.074197
# 2  0.877998        0.028159  62.33159  8647.82194  63804.94956  8903.169528
# 3  1.316997        0.034692  62.44080  8648.06758  63804.58572  8452.857066
# 4  1.755995        0.008532  62.54987  8648.31322  63804.22187  9753.803984
#
#     23Na/43Ca  25Mg/43Ca  55Mn/43Ca  88Sr/43Ca  138Ba/43Ca    peakID_1  \
# 0  288.847644   1.188124   0.206571   0.021329         0.0  interval 7
# 1  393.503501   2.996792   0.334206   0.017606         0.0  interval 7
# 2  313.217608   1.307143   0.239893   0.028159         0.0  interval 7
# 3  335.681179   1.610404   0.264440   0.034692         0.0  interval 7
# 4  286.286811   1.584171   0.221876   0.008532         0.0  interval 7
#
#      peakID_2    peakID_3    peakID_4
# 0  interval 7  interval 7  interval 7
# 1  interval 7  interval 7  interval 7
# 2  interval 7  interval 7  interval 7
# 3  interval 7  interval 7  interval 7
# 4  interval 7  interval 7  interval 7
#
# Shape: (47952, 15)
#
# Columns: ['depth', 'proxy_filtered', 'time', 'Xpos', 'Ypos', 'Ca43', '23Na/43Ca', '25Mg/43Ca', '55Mn/43Ca', '88Sr/43Ca', '138Ba/43Ca', 'peakID_1', 'peakID_2', 'peakID_3', 'peakID_4']
#
# ----------------------------------------
# Data from G730_sub_peakid.csv:
#       depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.444912        0.243863  62.33216  11659.03710  65652.83700  1850.136910
# 1  0.889825        0.204499  62.44128  11659.26718  65652.45620  1750.122509
# 2  1.334737        0.115682  62.55029  11659.49725  65652.07539  2400.230422
# 3  1.779650        0.182896  62.65943  11659.72733  65651.69459  1850.136910
# 4  2.224562        0.108436  62.76857  11659.95741  65651.31379  2500.250025
#
#      23Na/43Ca  25Mg/43Ca  55Mn/43Ca  88Sr/43Ca  138Ba/43Ca    peakID_1  \
# 0  1173.631830  12.025687   2.975028   0.243863         0.0  interval 7
# 1  1296.103920  15.687164   3.092140   0.204499         0.0  interval 7
# 2   738.291007   6.338529   2.173286   0.115682         0.0  interval 7
# 3  1150.264652   8.017092   3.352205   0.182896         0.0  interval 7
# 4   690.033157  11.883155   1.490541   0.108436         0.0  interval 7
#
#      peakID_2    peakID_3    peakID_4
# 0  interval 7  interval 7  interval 7
# 1  interval 7  interval 7  interval 7
# 2  interval 7  interval 7  interval 7
# 3  interval 7  interval 7  interval 7
# 4  interval 7  interval 7  interval 7
#
# Shape: (35067, 15)
#
# Columns: ['depth', 'proxy_filtered', 'time', 'Xpos', 'Ypos', 'Ca43', '23Na/43Ca', '25Mg/43Ca', '55Mn/43Ca', '88Sr/43Ca', '138Ba/43Ca', 'peakID_1', 'peakID_2', 'peakID_3', 'peakID_4']
#
# ----------------------------------------
# Data from G732_sub_peakid.csv:
#       depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.430734        0.107366  62.66020  33606.12380  87100.14170  2050.168114
# 1  0.861468        0.094327  62.76941  33605.89309  87099.77796  2200.193617
# 2  1.292201        0.000000  62.87854  33605.66239  87099.41422  2050.168114
# 3  1.722935        0.063487  62.98767  33605.43168  87099.05048  2800.313635
# 4  2.153669        0.000000  63.09683  33605.20098  87098.68674  1950.152112
#
#      23Na/43Ca  25Mg/43Ca  55Mn/43Ca  88Sr/43Ca  138Ba/43Ca    peakID_1  \
# 0   977.688012   7.002723   1.494921   0.107366         0.0  interval 7
# 1   830.054082  12.304754   1.199160   0.094327         0.0  interval 7
# 2   988.535532   7.002723   2.101674   0.000000         0.0  interval 7
# 3   548.285750   7.246524   0.832724   0.063487         0.0  interval 7
# 4  1081.868336  28.926290   1.813735   0.000000         0.0  interval 7
#
#      peakID_2    peakID_3    peakID_4
# 0  interval 7  interval 7  interval 7
# 1  interval 7  interval 7  interval 7
# 2  interval 7  interval 7  interval 7
# 3  interval 7  interval 7  interval 7
# 4  interval 7  interval 7  interval 7
#
# Shape: (37104, 15)
#
# Columns: ['depth', 'proxy_filtered', 'time', 'Xpos', 'Ypos', 'Ca43', '23Na/43Ca', '25Mg/43Ca', '55Mn/43Ca', '88Sr/43Ca', '138Ba/43Ca', 'peakID_1', 'peakID_2', 'peakID_3', 'peakID_4']
#
# ----------------------------------------
# Data from G737_sub_peakid.csv:
#       depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.428265        0.015103  62.44156  67208.00250  62838.47170  8302.756515
# 1  0.856530        0.021346  62.55071  67207.70882  62838.15999  7852.465674
# 2  1.284796        0.015103  62.65986  67207.41514  62837.84828  8302.756515
# 3  1.713061        0.027043  62.76899  67207.12145  62837.53658  7752.403245
# 4  2.141326        0.005336  62.87812  67206.82777  62837.22487  7852.465674
#
#     23Na/43Ca  25Mg/43Ca  55Mn/43Ca  88Sr/43Ca  138Ba/43Ca    peakID_1  \
# 0  228.405504   1.161989   0.251221   0.015103         0.0  interval 7
# 1  236.054055   2.463451   0.283401   0.021346         0.0  interval 7
# 2  220.307588   0.929589   0.251221   0.015103         0.0  interval 7
# 3  245.057532   1.498033   0.319429   0.027043         0.0  interval 7
# 4  244.535876   1.724405   0.280957   0.005336         0.0  interval 7
#
#      peakID_2    peakID_3    peakID_4
# 0  interval 7  interval 7  interval 7
# 1  interval 7  interval 7  interval 7
# 2  interval 7  interval 7  interval 7
# 3  interval 7  interval 7  interval 7
# 4  interval 7  interval 7  interval 7
#
# Shape: (37667, 15)
#
# Columns: ['depth', 'proxy_filtered', 'time', 'Xpos', 'Ypos', 'Ca43', '23Na/43Ca', '25Mg/43Ca', '55Mn/43Ca', '88Sr/43Ca', '138Ba/43Ca', 'peakID_1', 'peakID_2', 'peakID_3', 'peakID_4']
#
# ----------------------------------------
# Data from G753_sub_peakid.csv:
#       depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.437407        0.076726  62.76802  68650.96820  84936.85340  2200.193617
# 1  0.874815        0.127571  62.87717  68650.78762  84936.45501  2050.168114
# 2  1.312222        0.062466  62.98630  68650.60704  84936.05662  2550.260127
# 3  1.749629        0.132356  63.09542  68650.42646  84935.65823  2000.160013
# 4  2.187037        0.098720  63.20462  68650.24588  84935.25983  3050.372145
#
#     23Na/43Ca  25Mg/43Ca  55Mn/43Ca  88Sr/43Ca  138Ba/43Ca    peakID_1  \
# 0  763.954586  17.243328   1.511757   0.076726         0.0  interval 7
# 1  849.355905  15.017527   2.137211   0.127571         0.0  interval 7
# 2  612.178297   7.019130   1.266460   0.062466         0.0  interval 7
# 3  853.566068  16.997223   2.368579   0.132356         0.0  interval 7
# 4  482.747434   3.961709   1.240394   0.098720         0.0  interval 7
#
#      peakID_2    peakID_3    peakID_4
# 0  interval 7  interval 7  interval 7
# 1  interval 7  interval 7  interval 7
# 2  interval 7  interval 7  interval 7
# 3  interval 7  interval 7  interval 7
# 4  interval 7  interval 7  interval 7
#
# Shape: (36457, 15)
#
# Columns: ['depth', 'proxy_filtered', 'time', 'Xpos', 'Ypos', 'Ca43', '23Na/43Ca', '25Mg/43Ca', '55Mn/43Ca', '88Sr/43Ca', '138Ba/43Ca', 'peakID_1', 'peakID_2', 'peakID_3', 'peakID_4']
#
# ----------------------------------------
# Data from G767_sub_peakid.csv:
#       depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.442323        0.009420  61.78820  83185.58790  60187.64950  8853.134009
# 1  0.884647        0.010835  61.89743  83186.00335  60187.80132  7752.403245
# 2  1.326970        0.005381  62.00651  83186.41880  60187.95315  7802.434360
# 3  1.769293        0.012975  62.11566  83186.83425  60188.10497  9603.687816
# 4  2.211617        0.000000  62.22488  83187.24970  60188.25679  8402.823349
#
#     23Na/43Ca  25Mg/43Ca  55Mn/43Ca  88Sr/43Ca  138Ba/43Ca    peakID_1  \
# 0  201.593502   1.306745   0.189798   0.009420         0.0  interval 7
# 1  235.698077   1.753460   0.270072   0.010835         0.0  interval 7
# 2  231.085624   2.487977   0.268241   0.005381         0.0  interval 7
# 3  188.270895   0.799948   0.267742   0.012975         0.0  interval 7
# 4  210.109106   1.840642   0.241859   0.000000         0.0  interval 7
#
#      peakID_2    peakID_3    peakID_4
# 0  interval 7  interval 7  interval 7
# 1  interval 7  interval 7  interval 7
# 2  interval 7  interval 7  interval 7
# 3  interval 7  interval 7  interval 7
# 4  interval 7  interval 7  interval 7
#
# Shape: (28438, 15)
#
# Columns: ['depth', 'proxy_filtered', 'time', 'Xpos', 'Ypos', 'Ca43', '23Na/43Ca', '25Mg/43Ca', '55Mn/43Ca', '88Sr/43Ca', '138Ba/43Ca', 'peakID_1', 'peakID_2', 'peakID_3', 'peakID_4']
#
# ----------------------------------------
# Data from G770_sub_peakid.csv:
#       depth  proxy_filtered      time         Xpos        Ypos         Ca43  \
# 0  0.000000        0.027962  62.66110  11284.27060  80543.4967  7752.403245
# 1  0.428658        0.016427  62.77019  11284.27060  80543.4967  7902.497189
# 2  0.857316        0.026459  62.87927  11284.42929  80543.0985  8152.657766
# 3  1.285974        0.015982  62.98834  11284.58799  80542.7003  8102.625251
# 4  1.714633        0.014077  63.09746  11284.74668  80542.3021  9103.313606
#
#     23Na/43Ca  25Mg/43Ca  55Mn/43Ca  88Sr/43Ca  138Ba/43Ca    peakID_1  \
# 0  354.515909   0.786161   0.545643   0.027962         0.0  interval 7
# 1  353.032677   1.026343   0.460551   0.016427         0.0  interval 7
# 2  340.922061   1.239812   0.485137   0.026459         0.0  interval 7
# 3  337.310855   1.248202   0.533241   0.015982         0.0  interval 7
# 4  301.512730   1.759038   0.473615   0.014077         0.0  interval 7
#
#      peakID_2    peakID_3    peakID_4
# 0  interval 7  interval 7  interval 7
# 1  interval 7  interval 7  interval 7
# 2  interval 7  interval 7  interval 7
# 3  interval 7  interval 7  interval 7
# 4  interval 7  interval 7  interval 7
#
# Shape: (34283, 15)
#
# Columns: ['depth', 'proxy_filtered', 'time', 'Xpos', 'Ypos', 'Ca43', '23Na/43Ca', '25Mg/43Ca', '55Mn/43Ca', '88Sr/43Ca', '138Ba/43Ca', 'peakID_1', 'peakID_2', 'peakID_3', 'peakID_4']
#
# ----------------------------------------
# Data from G779_int_peakid.csv:
#       depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.443269        0.094690  61.78594  82290.05480  62546.51910  1850.136910
# 1  0.886537        0.194504  61.89508  82290.41860  62546.26585  1200.057603
# 2  1.329806        0.089958  62.00416  82290.78240  62546.01260  1250.062503
# 3  1.773075        0.291758  62.11330  82291.14620  62545.75935  1200.057603
# 4  2.216343        0.000000  62.22252  82291.51001  62545.50610  1900.144411
#
#      23Na/43Ca  25Mg/43Ca  55Mn/43Ca  88Sr/43Ca  138Ba/43Ca    peakID_1  \
# 0   626.174581  17.777374   0.897794   0.094690         0.0  interval 7
# 1  1341.704613  39.559890   2.408786   0.194504         0.0  interval 7
# 2  1196.920807  22.518426   1.914757   0.089958         0.0  interval 7
# 3  1310.094434  27.387397   2.295860   0.291758         0.0  interval 7
# 4   624.143320  11.401407   1.445469   0.000000         0.0  interval 7
#
#      peakID_2    peakID_3    peakID_4
# 0  interval 7  interval 7  interval 7
# 1  interval 7  interval 7  interval 7
# 2  interval 7  interval 7  interval 7
# 3  interval 7  interval 7  interval 7
# 4  interval 7  interval 7  interval 7
#
# Shape: (38766, 15)
#
# Columns: ['depth', 'proxy_filtered', 'time', 'Xpos', 'Ypos', 'Ca43', '23Na/43Ca', '25Mg/43Ca', '55Mn/43Ca', '88Sr/43Ca', '138Ba/43Ca', 'peakID_1', 'peakID_2', 'peakID_3', 'peakID_4']
#
# ----------------------------------------
# Data from G781_sub_peakid.csv:
#       depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.000000        0.000000  61.78823  53136.09580  83312.56000  7652.341617
# 1  0.432411        0.024696  61.89732  53136.09580  83312.56000  7001.960549
# 2  0.864821        0.018236  62.00647  53136.40761  83312.26041  7102.016973
# 3  1.297232        0.028218  62.11562  53136.71941  83311.96081  7602.311103
# 4  1.729642        0.011128  62.22472  53137.03122  83311.66122  7702.372331
#
#     23Na/43Ca  25Mg/43Ca  55Mn/43Ca  88Sr/43Ca  138Ba/43Ca    peakID_1  \
# 0  307.517332   1.584141   0.268357   0.000000         0.0  interval 7
# 1  346.390930   2.327192   0.310609   0.024696         0.0  interval 7
# 2  356.204412   1.145647   0.388178   0.018236         0.0  interval 7
# 3  312.698321   1.063649   0.289393   0.028218         0.0  interval 7
# 4  304.700189   1.835126   0.290693   0.011128         0.0  interval 7
#
#      peakID_2    peakID_3    peakID_4
# 0  interval 7  interval 7  interval 7
# 1  interval 7  interval 7  interval 7
# 2  interval 7  interval 7  interval 7
# 3  interval 7  interval 7  interval 7
# 4  interval 7  interval 7  interval 7
#
# Shape: (38258, 15)
#
# Columns: ['depth', 'proxy_filtered', 'time', 'Xpos', 'Ypos', 'Ca43', '23Na/43Ca', '25Mg/43Ca', '55Mn/43Ca', '88Sr/43Ca', '138Ba/43Ca', 'peakID_1', 'peakID_2', 'peakID_3', 'peakID_4']
#
# ----------------------------------------

# %% [markdown]
# ### Plot locations of intervals in each specimen

# %%
plt.figure(figsize=(10, 6))

# Prepare color maps for treatments
subtidal_files = [f for f in dataframes if 'sub' in f.lower()]
intertidal_files = [f for f in dataframes if 'int' in f.lower()]
other_files = [f for f in dataframes if f not in subtidal_files + intertidal_files]

# Generate color maps
subtidal_colors = cm.Blues(np.linspace(0.5, 1, len(subtidal_files)))
intertidal_colors = cm.Reds(np.linspace(0.5, 1, len(intertidal_files)))

# Initialize long format DataFrame for tracking depth values of transitions
transition_depths_df = pd.DataFrame(columns=['file', 'specimen', 'treatment', 'peakID', 'peak_interval', 'depth'])

# Initialize indices for color selection per specimen
sub_idx = 0
int_idx = 0

for file, df in dataframes.items():
    if 'depth' in df.columns and 'peakID_1' in df.columns:
        # Isolate columns containing "peakID"
        peakid_cols = [col for col in df.columns if "peakID" in col]
        # Choose color for specimen
        if file in subtidal_files:
            color = subtidal_colors[sub_idx]
            treatment = 'subtidal'
        elif file in intertidal_files:
            color = intertidal_colors[int_idx]
            treatment = 'intertidal'
        else:
            color = 'green'
            treatment = 'other'
        # Isolate specimen name from filename (specimen name is part of filename before first underscore)
        specimen = re.split(r'[_\s]', file)[0]
        for peak_col in peakid_cols: # Loop through each peakID column
            # Determine transitions based on peak_col column and get their depths
            transitions = df[peak_col] != df[peak_col].shift() # Identify where the value in the peakID column changes
            transition_depths = df.loc[transitions, 'depth'].reset_index(drop=True) # Get corresponding depths for these transitions
            scatter = plt.scatter(transition_depths, range(1, len(transition_depths) + 1), label=file, s=30, color=color)
            plt.plot(transition_depths, range(1, len(transition_depths) + 1), linestyle='-', alpha=0.5, color=color)

            # Append transition depths to the long format DataFrame
            peak_intervals = df.loc[transitions, peak_col].reset_index(drop=True)
            temp_df = pd.DataFrame({
                'file': file,
                'specimen': specimen,
                'treatment': treatment,
                'peakID': peak_col,
                'peak_interval': peak_intervals,
                'depth': transition_depths
            })
            transition_depths_df = pd.concat([transition_depths_df, temp_df], ignore_index=True)
               
        # Increment indices for subtidal or intertidal files
        if file in subtidal_files: sub_idx += 1
        if file in intertidal_files: int_idx += 1

# After the for loop, add interval labels inside the plotting area, one per interval
ref_file = next((f for f, df in dataframes.items() if 'depth' in df.columns and "peakID_1" in df.columns), None)
if ref_file:
    ref_df = dataframes[ref_file]
    transitions = ref_df["peakID_1"] != ref_df["peakID_1"].shift()
    transition_depths = ref_df.loc[transitions, 'depth'].reset_index(drop=True)
    peak_labels = ref_df.loc[transitions, "peakID_1"].reset_index(drop=True)
    for y, label in enumerate(peak_labels, start=1):
        plt.text(
            transition_depths.iloc[y-1], y, str(label),
            va='center', ha='left', fontsize=8, color='black', alpha=0.7,
            bbox=dict(facecolor='white', edgecolor='none', alpha=0.5, boxstyle='round,pad=0.2')
        )

plt.xlabel('Distance along the shell (um)')
plt.ylabel('Event Number')
plt.title('Event vs. Depth of Transition Points from peakID Columns')
plt.tight_layout()

ax = plt.gca()
handles, labels = ax.get_legend_handles_labels()
unique = OrderedDict()
for h, l in zip(handles, labels):
    if l and l not in unique:
        unique[l] = h
if unique:
    ax.legend(unique.values(), unique.keys(), loc='best', bbox_to_anchor=(1.05, 1))
plt.draw()
plt.show()
# Out:
# C:\Users\nwi213\AppData\Local\Temp\ipykernel_28052\2673342287.py:52: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   transition_depths_df = pd.concat([transition_depths_df, temp_df], ignore_index=True)

# %% [markdown]
# ### Plot spread in depth values per interval and per specimen

# %%
# Calculate spread and standard deviation of depth values per interval and per specimen
spread_stats = transition_depths_df.groupby(['specimen', 'treatment', 'peak_interval'])['depth'].agg(['min', 'max', 'mean', 'std']).reset_index()
spread_stats['spread'] = spread_stats['max'] - spread_stats['min']
spread_stats.head()

# Plot spread statistics as pointrange plots, grouping by specimen and coloring by treatment
plt.figure(figsize=(10, 6))

# Initialize indices for color selection per specimen
sub_idx = 0
int_idx = 0

treatments = spread_stats['treatment'].unique()
for treatment in treatments:
    subset = spread_stats[spread_stats['treatment'] == treatment]
    # Add jitter to x positions for each specimen to avoid overlap
    specimens = subset['specimen'].unique()
    for i, specimen in enumerate(specimens):
        # Choose color for specimen
        if treatment == 'subtidal':
            color = subtidal_colors[sub_idx]
        elif treatment == 'intertidal':
            color = intertidal_colors[int_idx]

        spec_data = subset[subset['specimen'] == specimen]
        spec_data = spec_data.sort_values('mean')  # Sort by mean depth for better visualization
        # Jitter: add a small offset based on specimen index
        jitter = (i - len(specimens)/2) * 0.1
        x = np.arange(len(spec_data['peak_interval']) * 2, step = 2) + jitter
        # Plot spread as line segments
        for j, row in spec_data.iterrows():
            plt.vlines(x=x[spec_data.index.get_loc(j)], 
                      ymin=row['min'], 
                      ymax=row['max'],
                      color=color, alpha=0.5, linewidth=2)
        plt.errorbar( # Add pointrange for mean and st.dev
            x, spec_data['mean'],
            yerr=spec_data['std'], fmt='o', label=f"{treatment} - {specimen}",
            capsize=5,
            color=color,
            alpha=0.7
        )

plt.title('Spread and Standard Deviation of Depth Values per Peak Interval')
plt.xlabel('Peak Interval')
plt.ylabel('Depth (um)')
plt.show()

# %% [markdown]
# ### Plot summary of spread between peakIDs per treatment and interval

# %%
# Calculate mean spread per treatment and interval
mean_spread = spread_stats.groupby(['treatment', 'peak_interval'])['spread'].mean().reset_index()
mean_spread['min'] = spread_stats.groupby(['treatment', 'peak_interval'])['spread'].min().reset_index()['spread']
mean_spread['max'] = spread_stats.groupby(['treatment', 'peak_interval'])['spread'].max().reset_index()['spread']
mean_spread['depth'] = spread_stats.groupby(['treatment', 'peak_interval'])['mean'].mean().reset_index()['mean']

# Plot mean spread per treatment and interval
plt.figure(figsize=(10, 6))
for treatment in treatments:
    subset = mean_spread[mean_spread['treatment'] == treatment]
    subset = subset.sort_values('depth')  # Sort by mean depth for better visualization
    if treatment == 'subtidal':
        color = 'blue'
    elif treatment == 'intertidal':
        color = 'red'
    else:
        color = 'green'
    # Create adjacent bars for each treatment using a fixed bar width and offset
    bar_width = 0.4
    x = np.arange(len(subset['peak_interval']))
    if treatment == 'subtidal':
        offset = -bar_width/2
    elif treatment == 'intertidal':
        offset = bar_width/2
    else:
        offset = 0
    plt.bar(x + offset, subset['spread'] / 1000, width=bar_width, color=color, alpha=0.6, label=treatment)
    plt.xticks(x, subset['peak_interval'], rotation=45, ha='right')
    # Plot spread as line segments
    for j, row in subset.iterrows():
        plt.vlines(x=x[subset.index.get_loc(j)] + offset, 
                    ymin=row['min'] / 1000, 
                    ymax=row['max'] / 1000,
                    color=color, alpha=0.5, linewidth=2)
plt.title('Mean Spread of Depth Values per Peak Interval and Treatment')
plt.xlabel('Peak Interval')
plt.ylabel('Spread between peak IDs (mm)')
plt.legend(loc = 'upper left')
plt.tight_layout()

# %% [markdown]
# ### Export depth data of intervals and peaks

# %%
transition_depths_df.to_csv("Depth_values_intervals_peaks.csv", index=False)

# %% [markdown]
# ## Load information about the timing of the peaks and the beginning and end of the experiment

# %% [markdown]
# ### Timing of the Sr peaks and start and end of experiment

# %%
timing_sr_spikes = pd.read_csv("Timing_Sr_spikes.csv") # Load the CSV file containing timing data
# Convert 'Start' and 'End' columns to datetime, specifying the format to include both date and time
timing_sr_spikes['Start'] = pd.to_datetime(timing_sr_spikes['Start'], format='%d-%m-%Y%H:%M')
timing_sr_spikes['End'] = pd.to_datetime(timing_sr_spikes['End'], format='%d-%m-%Y%H:%M')

# # Reverse the order of the "Number" column without sorting the other columns
# max_number = timing_sr_spikes['Number'].max()
# min_number = timing_sr_spikes['Number'].min()
# timing_sr_spikes['Number'] = max_number - (timing_sr_spikes['Number'] - min_number)

# Duplicate rows where 'Containers' == 'All' for both 'Subtidal' and 'Intertidal'
all_rows = timing_sr_spikes[timing_sr_spikes['Containers'] == 'All']
if not all_rows.empty:
    subtidal_rows = all_rows.copy()
    subtidal_rows['Containers'] = 'Subtidal'
    intertidal_rows = all_rows.copy()
    intertidal_rows['Containers'] = 'Intertidal'
    # Append the new rows to the dataframe
    timing_sr_spikes = pd.concat([timing_sr_spikes, subtidal_rows, intertidal_rows], ignore_index=True)
    timing_sr_spikes = timing_sr_spikes[timing_sr_spikes['Containers'] != 'All'].reset_index(drop=True)

# Add rows for the start and end of the experiment
start_row = timing_sr_spikes.iloc[0].copy()
start_row['Start'] = pd.to_datetime("01-02-202210:00", format='%d-%m-%Y%H:%M') # Add start date and time (February 1, 2022, 10:00 AM)
start_row['End'] = pd.to_datetime("01-02-202210:00", format='%d-%m-%Y%H:%M')
start_row['Number'] = 0
start_row['level'] = None
end_row = timing_sr_spikes.iloc[-1].copy()
end_row['Start'] = pd.to_datetime("25-10-202210:00", format='%d-%m-%Y%H:%M') # Add end date and time (October 25, 2022, 10:00 AM)
end_row['End'] = pd.to_datetime("25-10-202210:00", format='%d-%m-%Y%H:%M')
end_row['Number'] = timing_sr_spikes['Number'].max() + 1
end_row['level'] = None
# Add start and end rows for both 'Subtidal' and 'Intertidal'
for container in ['Subtidal', 'Intertidal']:
    start_row_mod = start_row.copy()
    start_row_mod['Containers'] = container
    end_row_mod = end_row.copy()
    end_row_mod['Containers'] = container
    timing_sr_spikes = pd.concat([timing_sr_spikes, start_row_mod.to_frame().T, end_row_mod.to_frame().T], ignore_index=True)

print(timing_sr_spikes.head())
# Out:
#   Number  Containers                Start                  End level
# 0      2  Intertidal  2022-05-11 10:40:00  2022-05-12 10:50:00   low
# 1      2    Subtidal  2022-05-11 11:00:00  2022-05-12 11:10:00   low
# 2      3  Intertidal  2022-05-31 15:00:00  2022-06-01 15:00:00  High
# 3      3    Subtidal  2022-05-31 15:30:00  2022-06-01 15:30:00  High
# 4      4  Intertidal  2022-06-27 13:30:00  2022-06-28 12:45:00   Low

# %% [markdown]
# ## Load information about the timing and data on caliper measurements

# %%
# Open the sheet containing caliper measurements
caliper_file = "Caliper measurements cockles 2022.xlsx"
caliper_data = {"Caliper measurements": pd.read_excel(caliper_file, sheet_name="Caliper measurements")}
# print(caliper_data["Caliper measurements"].head())

# Extract the "Height" data for all specimens contained in the Sr spiking data
# Extract specimen names as the first letter and first three numbers from each file name
specimen_names = [re.match(r'([A-Z]\d{3})', name).group(1) if re.match(r'([A-Z]\d{3})', name) else name for name in dataframes.keys()]
print("Specimens in Sr spiking data:", specimen_names)
# Isolate columns containing "Height"
height_columns = [col for col in caliper_data["Caliper measurements"].columns if "Height" in col]

# Isolate rows with specimen names in "specimen_names"
# The specimen name is likely in the "ID" column
caliper_df = caliper_data["Caliper measurements"]
filtered_caliper_data = caliper_df[caliper_df["ID"].isin(specimen_names)][["ID"] + height_columns]

print(filtered_caliper_data)
# Out:
# Specimens in Sr spiking data: ['B255', 'B323', 'B325', 'G652', 'G664', 'G668', 'G691', 'G717', 'G719', 'G723', 'G728', 'G730', 'G732', 'G737', 'G753', 'G767', 'G770', 'G779', 'G781']
#        ID  220119 Height  220301 Height  220424 Height  220601 Height  \
# 14   G753          10.58          10.89          14.92            NaN
# 17   G767          12.00          12.29          15.00            NaN
# 38   G781           9.49          10.18          14.40            NaN
# 45   G770          15.62          15.72          17.92            NaN
# 49   G730          12.21          12.26          15.99            NaN
# 50   G664          17.93          18.39          20.27            NaN
# 55   G737          11.12          11.67          15.83            NaN
# 71   G732          13.57          13.77          17.00            NaN
# 73   G717          14.25          14.65          16.74            NaN
# 89   G652          16.19          16.40          18.63            NaN
# 105  G719          12.93          13.63          15.90            NaN
# 116  B255            NaN            NaN            NaN          17.03
# 127  G691          15.50          15.60          17.53            NaN
# 129  G668          19.35          19.58          20.52            NaN
# 138  G723          15.49          15.82          18.94            NaN
# 151  G728          14.76          15.45          18.10            NaN
# 166  G779          16.42          16.80          19.31            NaN
#
#      221011 Height
# 14           20.59
# 17           20.46
# 38           19.61
# 45           22.43
# 49           21.36
# 50           24.99
# 55           21.66
# 71           23.54
# 73           22.69
# 89           23.42
# 105          22.93
# 116          28.25
# 127          25.82
# 129          25.40
# 138          23.94
# 151          25.68
# 166          26.03

# %% [markdown]
# ### Load information from 2020 experiment to link caliper measurements for cockles to distance along profile

# %%
calibration_caliper_df = pd.read_csv("Calibration_caliper_measurements_2020.csv")

# Prepare data for linear regression
X = calibration_caliper_df['Adjusted caliper size'].values.reshape(-1, 1)
y = calibration_caliper_df['Peak_mm'].values

# Fit linear regression
reg = LinearRegression()
reg.fit(X, y)
y_pred = reg.predict(X)

# Calculate residuals and standard error of regression
residuals = y - y_pred
n = len(y)
p = 2  # number of parameters (slope + intercept)
s_err = np.sqrt(np.sum(residuals**2) / (n - p))

# For error envelope: calculate 95% confidence interval for the regression line
X_flat = X.flatten()
mean_x = np.mean(X_flat)
t_val = t.ppf(0.975, n - p)  # two-tailed 95% CI

# Expand prediction to entire x-axis (0, 4.5)
x_range = np.linspace(0, 4.5, 200).reshape(-1, 1)
y_range_pred = reg.predict(x_range)

# Calculate confidence interval for the expanded range
mean_x = np.mean(X_flat)
conf_interval_range = t_val * s_err * np.sqrt(1/n + (x_range.flatten() - mean_x)**2 / np.sum((X_flat - mean_x)**2))
upper_range = y_range_pred + conf_interval_range
lower_range = y_range_pred - conf_interval_range

# Print regression formula with uncertainty
# Standard errors of slope and intercept
Sxx = np.sum((X_flat - mean_x)**2)
slope_se = s_err / np.sqrt(Sxx)
intercept_se = s_err * np.sqrt(1/n + mean_x**2 / Sxx)

# Add regression formula with uncertainty to the legend
regression_label = (
    f"Fit: y = ({reg.coef_[0]:.2f} ± {slope_se:.2f})x + ({reg.intercept_:.2f} ± {intercept_se:.2f})"
)

# Plot
plt.figure(figsize=(8, 5))
plt.scatter(X, y, label='Data', color='blue')
plt.plot(x_range, y_range_pred, color='red', label=regression_label)
plt.fill_between(x_range.flatten(), lower_range, upper_range, color='red', alpha=0.2, label='95% CI')
plt.xlim(0, 4.5)
plt.ylim(0, 9)
plt.xlabel('Caliper size - starting size (mm)')
plt.ylabel('Distance along shell (mm)')
plt.title('Linear Regression: Distance along shell vs Adjusted caliper size')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Extract dates of shell height measurements from 2022 caliper measurements and convert to equivalent length along record

# %%
# --------------Extracting Caliper Measurements----------------
# Extract dates from the first 6 digits of the column names and parse as datetime
date_columns = [col for col in filtered_caliper_data.columns if any(char.isdigit() for char in col)]
date_mapping = {}

# Extract dates from column names
for col in date_columns:
    match = re.match(r'(\d{6})', col)
    if match:
        date_str = match.group(1)
        # Parse as datetime, assuming format is YYMMDD (e.g., 220101 for January 1, 2022)
        date = pd.to_datetime(date_str, format='%y%m%d')
        date_mapping[col] = date

# Melt the dataframe to long format: columns -> 'ID', 'date', 'shell_height'
caliper_long = filtered_caliper_data.melt(
    id_vars=['ID'],
    value_vars=date_columns,
    var_name='date_col',
    value_name='shell_height'
)

# Map the extracted dates to the 'date_col' column
caliper_long['date'] = caliper_long['date_col'].map(date_mapping)
caliper_long = caliper_long.dropna(subset=['date', 'shell_height'])

# Rename columns for clarity
caliper_long = caliper_long.rename(columns={'ID': 'specimen'})
caliper_long = caliper_long[['specimen', 'date', 'shell_height']] # Reorder and select columns

# ----------------Calculating distance along shell----------------
# Find lowest shell height in dataset and round down to nearest mm
min_shell_height = caliper_long['shell_height'].min()
min_shell_height = np.floor(min_shell_height)

# Adjust shell heights to relative to the minimum shell height
caliper_long['adjusted_shell_height'] = caliper_long['shell_height'] - min_shell_height

# Calculate minimum shell height per specimen (floored)
min_shell_height_per_specimen = caliper_long.groupby('specimen')['shell_height'].min().apply(np.floor)

# For specimen B255, set its minimum shell height to the mean minimum of the other specimens because the first measurement for this specimen is in May
other_specimens = min_shell_height_per_specimen.drop('B255')
mean_min_other = other_specimens.mean()
min_shell_height_per_specimen['B255'] = mean_min_other

# Map to each row and compute adjusted shell height per individual
caliper_long['adjusted_shell_height_individual'] = caliper_long.apply(
    lambda row: row['shell_height'] - min_shell_height_per_specimen[row['specimen']],
    axis=1
)

# Convert to equivalent distance along the shell and subtract starting point to compare with Sr spiking data
# Use the regression model to predict distance along shell (mm) from adjusted shell height
caliper_long['distance_mm'] = reg.predict(caliper_long[['adjusted_shell_height']])
caliper_long['distance_mm_individual'] = reg.predict(caliper_long[['adjusted_shell_height_individual']])

# Calculate 95% confidence interval for each prediction
# Formula: CI = t_val * s_err * sqrt(1/n + (x - mean_x)^2 / Sxx)
caliper_long['distance_mm_ci'] = t_val * s_err * np.sqrt(
    1 / n + (caliper_long['adjusted_shell_height'] - mean_x) ** 2 / Sxx
)
caliper_long['distance_mm_ci_individual'] = t_val * s_err * np.sqrt(
    1 / n + (caliper_long['adjusted_shell_height_individual'] - mean_x) ** 2 / Sxx
)

# --------------Plotting the Caliper Measurements----------------
# Plot the caliper measurements over time for each specimen
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16, 6), sharey=False)
specimens = caliper_long['specimen'].unique()
colors = plt.cm.tab20(np.linspace(0, 1, len(specimens)))

# Panel 1 (left): Shell height vs date
for i, specimen in enumerate(specimens):
    df_spec = caliper_long[caliper_long['specimen'] == specimen]
    ax1.plot(
        df_spec['date'],
        df_spec['shell_height'],
        'o-',
        label=specimen,
        color=colors[i],
        alpha=0.8
    )
ax1.set_xlabel('Date')
ax1.set_ylabel('Shell height (mm)')
ax1.set_title('Shell height vs. date per specimen')
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Panel 2 (middle): Distance along shell (mm) vs date
for i, specimen in enumerate(specimens):
    df_spec = caliper_long[caliper_long['specimen'] == specimen]
    ax2.errorbar(
        df_spec['date'],
        df_spec['distance_mm'],
        yerr=df_spec['distance_mm_ci'],
        fmt='o-',
        label=specimen,
        color=colors[i],
        capsize=3,
        alpha=0.8
    )
ax2.set_xlabel('Date')
ax2.set_ylabel('Distance along shell (mm, population minimum)')
ax2.set_title('Profile distance (population minimum start) vs. date per specimen')
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax2.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Panel 3 (right): Distance along shell (individual) vs date
for i, specimen in enumerate(specimens):
    df_spec = caliper_long[caliper_long['specimen'] == specimen]
    ax3.errorbar(
        df_spec['date'],
        df_spec['distance_mm_individual'],
        yerr=df_spec['distance_mm_ci_individual'],
        fmt='o-',
        label=specimen,
        color=colors[i],
        capsize=3,
        alpha=0.8
    )
ax3.set_xlabel('Date')
ax3.set_ylabel('Distance along shell (mm, individual start)')
ax3.set_title('Profile distance (individual) vs. date per specimen')
ax3.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax3.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.setp(ax1.get_xticklabels(), rotation=45)
plt.setp(ax2.get_xticklabels(), rotation=45)
plt.setp(ax3.get_xticklabels(), rotation=45)
plt.tight_layout()
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %% [markdown]
# ## Count number of spikes identified between caliper measurements

# %%
# First create overview of how many spikes should be between each successive pair of caliper measurements
caliper_long_dist = caliper_long[['specimen', 'date', 'distance_mm_individual']].copy() # Extract relevant columns

# Create dataframe to hold true spike counts between caliper measurements
true_spike_nr = pd.DataFrame(columns=['specimen', 'start_date', 'end_date', 'start_distance_mm', 'end_distance_mm', 'true_spike_count'])
for specimen in specimens:
    df_spec = caliper_long_dist[caliper_long_dist['specimen'] == specimen].sort_values('date').reset_index(drop=True)
    # Find out if specimen is in subtidal or intertidal treatment
    treatment = 'Subtidal' if any(file in subtidal_files for file in dataframes if specimen in file) else 'Intertidal'
    for i in range(len(df_spec) - 1):
        start_date = df_spec.loc[i, 'date']
        end_date = df_spec.loc[i + 1, 'date']
        start_distance = df_spec.loc[i, 'distance_mm_individual']
        end_distance = df_spec.loc[i + 1, 'distance_mm_individual']
        # Count spikes in timing_sr_spikes between these dates for this specimen
        spikes_in_interval = timing_sr_spikes[
            (timing_sr_spikes['Containers'].str.contains(treatment)) & 
            (timing_sr_spikes['Start'] >= start_date) & 
            (timing_sr_spikes['End'] <= end_date)
        ]
        true_spike_count = len(spikes_in_interval)
        # Append to true_spike_nr dataframe
        true_spike_nr = pd.concat([true_spike_nr, pd.DataFrame([{
            'specimen': specimen,
            'start_date': start_date,
            'end_date': end_date,
            'start_distance_mm': start_distance,
            'end_distance_mm': end_distance,
            'true_spike_count': true_spike_count
        }])], ignore_index=True)

# Now calculate the numbers of spikes actually identified between the caliper measurement distances
identified_spike_nr = pd.DataFrame(columns=['specimen', 'peakID', 'start_date', 'end_date', 'start_distance_mm', 'end_distance_mm', 'identified_spike_count'])
for specimen in specimens: # Loop through each specimen
    # Extract true spike dates for this specimen
    true_spike_dates_specimen = true_spike_nr[true_spike_nr['specimen'] == specimen]
    for peakID in transition_depths_df['peakID'].unique():
        df_spec_transitions = transition_depths_df[
            (transition_depths_df['specimen'] == specimen) & (transition_depths_df['peakID'] == peakID) & (transition_depths_df['peak_interval'].str.contains('peak')) # Only consider peak locations
        ]
        for i in true_spike_dates_specimen.index: # Loop through each caliper measurement interval for this specimen
            start_date = true_spike_dates_specimen.loc[i, 'start_date']
            end_date = true_spike_dates_specimen.loc[i, 'end_date']
            start_distance = true_spike_dates_specimen.loc[i, 'start_distance_mm']
            end_distance = true_spike_dates_specimen.loc[i, 'end_distance_mm']
            # Count identified spikes between these distances for this specimen
            identified_spikes_in_interval = df_spec_transitions[
                (df_spec_transitions['depth'] >= start_distance * 1000) & 
                (df_spec_transitions['depth'] <= end_distance * 1000)
            ]
            identified_spike_count = len(identified_spikes_in_interval)
            # Append to identified_spike_nr dataframe
            identified_spike_nr = pd.concat([identified_spike_nr, pd.DataFrame([{
                'specimen': specimen,
                'peakID': peakID,
                'start_date': start_date,
                'end_date': end_date,
                'start_distance_mm': start_distance,
                'end_distance_mm': end_distance,
                'identified_spike_count': identified_spike_count
            }])], ignore_index=True)

# Merge true and identified spike counts
spike_nr_caliper_comparison = pd.merge(
    true_spike_nr,
    identified_spike_nr,
    on=['specimen', 'start_date', 'end_date', 'start_distance_mm', 'end_distance_mm'],
    how='left'
)

# Export results of spike number comparison
spike_nr_caliper_comparison.to_csv("Spike_count_caliper_comparison.csv", index=False)
# Out:
# C:\Users\nwi213\AppData\Local\Temp\ipykernel_28052\1813224548.py:23: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   true_spike_nr = pd.concat([true_spike_nr, pd.DataFrame([{
# C:\Users\nwi213\AppData\Local\Temp\ipykernel_28052\1813224548.py:53: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   identified_spike_nr = pd.concat([identified_spike_nr, pd.DataFrame([{

# %% [markdown]
# ## Plot comparison between true number of spikes between caliper measurements and actually identified number

# %%
# Generate bar chart of numbers of spikes per caliper interval grouped by specimen and colored by peakID
plt.figure(figsize=(15, 5))

specimens = spike_nr_caliper_comparison['specimen'].unique()
specimen_nr = range(len(specimens))
bar_width = 0.25
patterns = ['/', '\\', '|', '-', '+', 'x', 'o', 'O', '.', '*']

for i, specimen in enumerate(specimens):
    subset = spike_nr_caliper_comparison[spike_nr_caliper_comparison['specimen'] == specimen]
    peakIDs = subset['peakID'].unique()
    peakID_colors = plt.cm.tab10(np.linspace(0, 1, len(peakIDs)))
    peakID_color_map = dict(zip(peakIDs, peakID_colors))
    
    for j, peakID in enumerate(peakIDs):
        spec_peak_data = subset[subset['peakID'] == peakID]
        x = np.arange(len(spec_peak_data))
        # Add true spike counts as horizontal lines
        offset = ((x - np.mean(x)) * 4) / (4 * len(peakIDs))
        plt.scatter(
            i + offset,
            spec_peak_data['true_spike_count'],
            marker = "_",
            s = 120,
            color = "black"
        )
        plt.bar(
            i + offset,
            spec_peak_data['true_spike_count'],
            width = bar_width,
            color = "black",
            alpha = 0.1
        )
        # Plot identified spike counts
        offset2 = (j - len(peakIDs)/2 + (x - np.mean(x)) * 5) / (5 * len(peakIDs))
        plt.bar(
            i + offset2,
            spec_peak_data['identified_spike_count'],
            width=bar_width / 5,
            label=peakID,
            color=peakID_color_map[peakID]
        )

plt.xticks(np.arange(len(specimens)) - 0.1,
           specimens,
           rotation=45, ha='right')
plt.xlabel('Specimen')
plt.ylabel('Number of Identified Spikes')
plt.title('Number of Identified Spikes vs true peaks between Caliper Measurements per Specimen and PeakID')
# Remove duplicate labels in legend
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

# %% [markdown]
# ## Link dates of spikes to peaks in profiles (create "age model")

# %%
# Find the start and end times for the entire experiment
# These will be used for linear interpolation of the intervals
start_experiment = pd.to_datetime("01-02-202210:00", format='%d-%m-%Y%H:%M')  # Start date and time
end_experiment = pd.to_datetime("25-10-202210:00", format='%d-%m-%Y%H:%M')  # End date and time

# Loop through each DataFrame and add timing info based on the peak labels
for file, df in dataframes.items():
    # Create new columns for timing info
    df['timing_1'] = None
    df['timing_2'] = None
    df['timing_3'] = None
    df['timing_4'] = None
    # Create new columns for centered timing info, default None
    df['timing_1_centered'] = None
    df['timing_2_centered'] = None
    df['timing_3_centered'] = None
    df['timing_4_centered'] = None

    # Loop through each peak identification option
    for peakID_col in ['peakID_1', 'peakID_2', 'peakID_3', 'peakID_4']:
        # Find column name according to peak label
        if peakID_col == 'peakID_1':
            timing_col = 'timing_1'
            timing_centered_col = 'timing_1_centered'
        elif peakID_col == 'peakID_2':
            timing_col = 'timing_2'
            timing_centered_col = 'timing_2_centered'
        elif peakID_col == 'peakID_3':
            timing_col = 'timing_3'
            timing_centered_col = 'timing_3_centered'
        elif peakID_col == 'peakID_4':
            timing_col = 'timing_4'
            timing_centered_col = 'timing_4_centered'
        # First assign timing to the peaks based on the 'peakID' columns
        # Map the timing info to the DataFrame based on the peak labels
        for i, row in df.iterrows(): # Iterate through each row in the DataFrame
            peaklabel = row[peakID_col] # Get the peak label for the current row following peakID 1       

            # Try to extract the peak number from the label (e.g., "peak 1" -> 1)
            if "peak" in peaklabel:
                try:
                    peak_num = int(peaklabel.split()[-1])
                except Exception:
                    peak_num = None
            else:
                peak_num = None

            # Find timing info for this peak number (if available)
            if peak_num is not None:
                # Find all rows with this peak label
                peak_rows = df[df[peakID_col] == peaklabel]
                if not peak_rows.empty:
                    # Find the middle row index for this peak
                    middle_idx = peak_rows.index[len(peak_rows) // 2]
                    # Find the start and end value for the correct treatment (subtidal vs intertidal)
                    if file.endswith('_sub_peakid.csv'):
                        start_value = timing_sr_spikes.loc[
                            (timing_sr_spikes['Number'] == peak_num) & 
                            (timing_sr_spikes['Containers'].str.lower() == 'subtidal'), 'Start'
                        ]
                        end_value = timing_sr_spikes.loc[
                            (timing_sr_spikes['Number'] == peak_num) & 
                            (timing_sr_spikes['Containers'].str.lower() == 'subtidal'), 'End'
                        ]
                    else:
                        start_value = timing_sr_spikes.loc[
                            (timing_sr_spikes['Number'] == peak_num) & 
                            (timing_sr_spikes['Containers'].str.lower() == 'intertidal'), 'Start'
                        ]
                        end_value = timing_sr_spikes.loc[
                            (timing_sr_spikes['Number'] == peak_num) & 
                            (timing_sr_spikes['Containers'].str.lower() == 'intertidal'), 'End'
                        ]

                    start_value = start_value.iloc[0] if not start_value.empty else None
                    end_value = end_value.iloc[0] if not end_value.empty else None
                    # Average start and end values (as datetime) for this peak (single values)
                    avg_time = start_value + (end_value - start_value) / 2
                    # Only assign timing_info_centered for the middle row
                    if i == middle_idx:
                        if start_value is not None and end_value is not None:
                            df.at[i, timing_centered_col] = avg_time            
                    # Add timing info to all rows in the peak               
                    df.at[i, timing_col] = avg_time # Assign the average time to the 'timing' column for this peak
    
        # Assign start and end times to the first and last rows of the DataFrame
        df.at[df.index[-1], timing_col] = start_experiment  # Assign start time to the last row (LAICPMS data was measured against the growth direction)
        df.at[df.index[0], timing_col] = end_experiment  # Assign end time to the first row (LAICPMS data was measured against the growth direction)
        df.at[df.index[-1], timing_centered_col] = start_experiment  # Assign start time to the last row (LAICPMS data was measured against the growth direction)
        df.at[df.index[0], timing_centered_col] = end_experiment  # Assign end time to the first row (LAICPMS data was measured against the growth direction)

        # Then assign timing to the intervals between peaks
        # Linearly interpolate timing_info for interval sections (where timing_info is None)
        # Find indices where timing_info is not None (i.e., at peaks)
        peak_indices = df.index[df[timing_col].notnull()].tolist()
        peak_depths = df.loc[peak_indices, 'depth'].values  # Get the depths at the peak indices
        peak_times = pd.to_datetime(df.loc[peak_indices, timing_col]).values  # Get the times at the peak indices

        # Interpolate timing for all intervals between peaks, using depth as independent variable
        for idx in range(len(peak_indices) - 1):
            start_idx = peak_indices[idx]
            end_idx = peak_indices[idx + 1]
            start_depth = df.at[start_idx, 'depth']
            end_depth = df.at[end_idx, 'depth']
            start_time = pd.to_datetime(df.at[start_idx, timing_col])
            end_time = pd.to_datetime(df.at[end_idx, timing_col])

            # Get indices in the interval (exclusive of start_idx and end_idx)
            interval_indices = range(start_idx + 1, end_idx)
            if len(interval_indices) > 0:
                interval_depths = df.loc[interval_indices, 'depth'].values
                # Linear interpolation of timestamps based on depth
                total_seconds = (end_time - start_time).total_seconds()
                if end_depth != start_depth:
                    rel_pos = (interval_depths - start_depth) / (end_depth - start_depth)
                    interp_times = [start_time + pd.Timedelta(seconds=total_seconds * rp) for rp in rel_pos]
                    for i, interp_time in zip(interval_indices, interp_times):
                        df.at[i, timing_col] = interp_time

        # Repeat the same interpolation for timing_info_centered
        centered_peak_indices = df.index[df[timing_centered_col].notnull()].tolist()
        centered_peak_depths = df.loc[centered_peak_indices, 'depth'].values
        centered_peak_times = pd.to_datetime(df.loc[centered_peak_indices, timing_centered_col]).values

        for idx in range(len(centered_peak_indices) - 1):
            start_idx = centered_peak_indices[idx]
            end_idx = centered_peak_indices[idx + 1]
            start_depth = df.at[start_idx, 'depth']
            end_depth = df.at[end_idx, 'depth']
            start_time = pd.to_datetime(df.at[start_idx, timing_centered_col])
            end_time = pd.to_datetime(df.at[end_idx, timing_centered_col])

            interval_indices = range(start_idx + 1, end_idx)
            if len(interval_indices) > 0:
                interval_depths = df.loc[interval_indices, 'depth'].values
                total_seconds = (end_time - start_time).total_seconds()
                if end_depth != start_depth:
                    rel_pos = (interval_depths - start_depth) / (end_depth - start_depth)
                    interp_times = [start_time + pd.Timedelta(seconds=total_seconds * rp) for rp in rel_pos]
                    for i, interp_time in zip(interval_indices, interp_times):
                        df.at[i, timing_centered_col] = interp_time

        # Round the timing info to the nearest second for consistency
        df[timing_col] = pd.to_datetime(df[timing_col]).dt.round('s')
        df[timing_centered_col] = pd.to_datetime(df[timing_centered_col]).dt.round('s')

        # Print the updated DataFrames with timing info
        print(f"Updated data from {file} and {peakID_col}:")
        print(df.head(), "\n")  # Display the first few rows of each updated DataFrame
        unique_peaks = df['timing_1'].unique()
        print(f"Unique values in 'timing_1' column (first 10): {unique_peaks[:10]}\n")  # Print first 10 unique values in the 'timing_1' column
        print("-" * 40)  # Separator for clarity
    
    # Save the updated DataFrame back to the dictionary
    dataframes[file] = df
# Out:
# Updated data from B255_int_peakid.csv and peakID_1:
#       depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.445779        0.013676  62.33211  30944.10620  80703.27530  6301.588000
# 1  0.891558        0.000000  62.44125  30944.46978  80703.01737  5301.123838
# 2  1.337336        0.019326  62.55040  30944.83337  80702.75945  4600.846556
# 3  1.783115        0.037763  62.65955  30945.19695  80702.50152  5751.322804
# 4  2.228894        0.013795  62.76871  30945.56053  80702.24359  6251.562891
#
#     23Na/43Ca  25Mg/43Ca  43Ca/43Ca  55Mn/43Ca  ...    peakID_3    peakID_4  \
# 0  199.059248   1.253571       1000   0.306491  ...  interval 7  interval 7
# 1  235.482235   3.406310       1000   0.347474  ...  interval 7  interval 7
# 2  284.331679   1.771388       1000   0.380053  ...  interval 7  interval 7
# 3  221.307763   3.115197       1000   0.348871  ...  interval 7  interval 7
# 4  205.558351   1.264443       1000   0.242893  ...  interval 7  interval 7
#
#              timing_1 timing_2 timing_3 timing_4   timing_1_centered  \
# 0 2022-10-25 10:00:00     None     None     None 2022-10-25 10:00:00
# 1 2022-10-25 09:28:25     None     None     None 2022-10-25 09:30:01
# 2 2022-10-25 08:56:51     None     None     None 2022-10-25 09:00:01
# 3 2022-10-25 08:25:16     None     None     None 2022-10-25 08:30:02
# 4 2022-10-25 07:53:42     None     None     None 2022-10-25 08:00:02
#
#   timing_2_centered timing_3_centered timing_4_centered
# 0              None              None              None
# 1              None              None              None
# 2              None              None              None
# 3              None              None              None
# 4              None              None              None
#
# [5 rows x 24 columns]
#
# Unique values in 'timing_1' column (first 10): <DatetimeArray>
# ['2022-10-25 10:00:00', '2022-10-25 09:28:25', '2022-10-25 08:56:51',
#  '2022-10-25 08:25:16', '2022-10-25 07:53:42', '2022-10-25 07:22:07',
#  '2022-10-25 06:50:33', '2022-10-25 06:18:58', '2022-10-25 05:47:23',
#  '2022-10-25 05:15:49']
# Length: 10, dtype: datetime64[ns]
#
# ----------------------------------------
# Updated data from B255_int_peakid.csv and peakID_2:
#       depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.445779        0.013676  62.33211  30944.10620  80703.27530  6301.588000
# 1  0.891558        0.000000  62.44125  30944.46978  80703.01737  5301.123838
# 2  1.337336        0.019326  62.55040  30944.83337  80702.75945  4600.846556
# 3  1.783115        0.037763  62.65955  30945.19695  80702.50152  5751.322804
# 4  2.228894        0.013795  62.76871  30945.56053  80702.24359  6251.562891
#
#     23Na/43Ca  25Mg/43Ca  43Ca/43Ca  55Mn/43Ca  ...    peakID_3    peakID_4  \
# 0  199.059248   1.253571       1000   0.306491  ...  interval 7  interval 7
# 1  235.482235   3.406310       1000   0.347474  ...  interval 7  interval 7
# 2  284.331679   1.771388       1000   0.380053  ...  interval 7  interval 7
# 3  221.307763   3.115197       1000   0.348871  ...  interval 7  interval 7
# 4  205.558351   1.264443       1000   0.242893  ...  interval 7  interval 7
#
#              timing_1            timing_2 timing_3 timing_4  \
# 0 2022-10-25 10:00:00 2022-10-25 10:00:00     None     None
# 1 2022-10-25 09:28:25 2022-10-25 09:28:25     None     None
# 2 2022-10-25 08:56:51 2022-10-25 08:56:51     None     None
# 3 2022-10-25 08:25:16 2022-10-25 08:25:16     None     None
# 4 2022-10-25 07:53:42 2022-10-25 07:53:42     None     None
#
#     timing_1_centered   timing_2_centered timing_3_centered timing_4_centered
# 0 2022-10-25 10:00:00 2022-10-25 10:00:00              None              None
# 1 2022-10-25 09:30:01 2022-10-25 09:30:01              None              None
# 2 2022-10-25 09:00:01 2022-10-25 09:00:01              None              None
# 3 2022-10-25 08:30:02 2022-10-25 08:30:02              None              None
# 4 2022-10-25 08:00:02 2022-10-25 08:00:02              None              None
#
# [5 rows x 24 columns]
#
# Unique values in 'timing_1' column (first 10): <DatetimeArray>
# ['2022-10-25 10:00:00', '2022-10-25 09:28:25', '2022-10-25 08:56:51',
#  '2022-10-25 08:25:16', '2022-10-25 07:53:42', '2022-10-25 07:22:07',
#  '2022-10-25 06:50:33', '2022-10-25 06:18:58', '2022-10-25 05:47:23',
#  '2022-10-25 05:15:49']
# Length: 10, dtype: datetime64[ns]
#
# ----------------------------------------
# Updated data from B255_int_peakid.csv and peakID_3:
#       depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.445779        0.013676  62.33211  30944.10620  80703.27530  6301.588000
# 1  0.891558        0.000000  62.44125  30944.46978  80703.01737  5301.123838
# 2  1.337336        0.019326  62.55040  30944.83337  80702.75945  4600.846556
# 3  1.783115        0.037763  62.65955  30945.19695  80702.50152  5751.322804
# 4  2.228894        0.013795  62.76871  30945.56053  80702.24359  6251.562891
#
#     23Na/43Ca  25Mg/43Ca  43Ca/43Ca  55Mn/43Ca  ...    peakID_3    peakID_4  \
# 0  199.059248   1.253571       1000   0.306491  ...  interval 7  interval 7
# 1  235.482235   3.406310       1000   0.347474  ...  interval 7  interval 7
# 2  284.331679   1.771388       1000   0.380053  ...  interval 7  interval 7
# 3  221.307763   3.115197       1000   0.348871  ...  interval 7  interval 7
# 4  205.558351   1.264443       1000   0.242893  ...  interval 7  interval 7
#
#              timing_1            timing_2            timing_3 timing_4  \
# 0 2022-10-25 10:00:00 2022-10-25 10:00:00 2022-10-25 10:00:00     None
# 1 2022-10-25 09:28:25 2022-10-25 09:28:25 2022-10-25 09:28:25     None
# 2 2022-10-25 08:56:51 2022-10-25 08:56:51 2022-10-25 08:56:51     None
# 3 2022-10-25 08:25:16 2022-10-25 08:25:16 2022-10-25 08:25:16     None
# 4 2022-10-25 07:53:42 2022-10-25 07:53:42 2022-10-25 07:53:42     None
#
#     timing_1_centered   timing_2_centered   timing_3_centered  \
# 0 2022-10-25 10:00:00 2022-10-25 10:00:00 2022-10-25 10:00:00
# 1 2022-10-25 09:30:01 2022-10-25 09:30:01 2022-10-25 09:30:01
# 2 2022-10-25 09:00:01 2022-10-25 09:00:01 2022-10-25 09:00:01
# 3 2022-10-25 08:30:02 2022-10-25 08:30:02 2022-10-25 08:30:02
# 4 2022-10-25 08:00:02 2022-10-25 08:00:02 2022-10-25 08:00:02
#
#   timing_4_centered
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
#
# [5 rows x 24 columns]
#
# Unique values in 'timing_1' column (first 10): <DatetimeArray>
# ['2022-10-25 10:00:00', '2022-10-25 09:28:25', '2022-10-25 08:56:51',
#  '2022-10-25 08:25:16', '2022-10-25 07:53:42', '2022-10-25 07:22:07',
#  '2022-10-25 06:50:33', '2022-10-25 06:18:58', '2022-10-25 05:47:23',
#  '2022-10-25 05:15:49']
# Length: 10, dtype: datetime64[ns]
#
# ----------------------------------------
# Updated data from B255_int_peakid.csv and peakID_4:
#       depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.445779        0.013676  62.33211  30944.10620  80703.27530  6301.588000
# 1  0.891558        0.000000  62.44125  30944.46978  80703.01737  5301.123838
# 2  1.337336        0.019326  62.55040  30944.83337  80702.75945  4600.846556
# 3  1.783115        0.037763  62.65955  30945.19695  80702.50152  5751.322804
# 4  2.228894        0.013795  62.76871  30945.56053  80702.24359  6251.562891
#
#     23Na/43Ca  25Mg/43Ca  43Ca/43Ca  55Mn/43Ca  ...    peakID_3    peakID_4  \
# 0  199.059248   1.253571       1000   0.306491  ...  interval 7  interval 7
# 1  235.482235   3.406310       1000   0.347474  ...  interval 7  interval 7
# 2  284.331679   1.771388       1000   0.380053  ...  interval 7  interval 7
# 3  221.307763   3.115197       1000   0.348871  ...  interval 7  interval 7
# 4  205.558351   1.264443       1000   0.242893  ...  interval 7  interval 7
#
#              timing_1            timing_2            timing_3  \
# 0 2022-10-25 10:00:00 2022-10-25 10:00:00 2022-10-25 10:00:00
# 1 2022-10-25 09:28:25 2022-10-25 09:28:25 2022-10-25 09:28:25
# 2 2022-10-25 08:56:51 2022-10-25 08:56:51 2022-10-25 08:56:51
# 3 2022-10-25 08:25:16 2022-10-25 08:25:16 2022-10-25 08:25:16
# 4 2022-10-25 07:53:42 2022-10-25 07:53:42 2022-10-25 07:53:42
#
#              timing_4   timing_1_centered   timing_2_centered  \
# 0 2022-10-25 10:00:00 2022-10-25 10:00:00 2022-10-25 10:00:00
# 1 2022-10-25 09:28:25 2022-10-25 09:30:01 2022-10-25 09:30:01
# 2 2022-10-25 08:56:51 2022-10-25 09:00:01 2022-10-25 09:00:01
# 3 2022-10-25 08:25:16 2022-10-25 08:30:02 2022-10-25 08:30:02
# 4 2022-10-25 07:53:42 2022-10-25 08:00:02 2022-10-25 08:00:02
#
#     timing_3_centered   timing_4_centered
# 0 2022-10-25 10:00:00 2022-10-25 10:00:00
# 1 2022-10-25 09:30:01 2022-10-25 09:30:01
# 2 2022-10-25 09:00:01 2022-10-25 09:00:01
# 3 2022-10-25 08:30:02 2022-10-25 08:30:02
# 4 2022-10-25 08:00:02 2022-10-25 08:00:02
#
# [5 rows x 24 columns]
#
# Unique values in 'timing_1' column (first 10): <DatetimeArray>
# ['2022-10-25 10:00:00', '2022-10-25 09:28:25', '2022-10-25 08:56:51',
#  '2022-10-25 08:25:16', '2022-10-25 07:53:42', '2022-10-25 07:22:07',
#  '2022-10-25 06:50:33', '2022-10-25 06:18:58', '2022-10-25 05:47:23',
#  '2022-10-25 05:15:49']
# Length: 10, dtype: datetime64[ns]
#
# ----------------------------------------
# Updated data from B323_int_peakid.csv and peakID_1:
#      depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.00000        0.024061  62.98675  34712.41390  65012.50220  5551.232374
# 1  0.43145        0.027384  63.09597  34712.41390  65012.50220  4950.980294
# 2  0.86290        0.014567  63.20513  34712.18161  65012.13862  6051.464454
# 3  1.29435        0.035128  63.31432  34711.94932  65011.77504  6251.562891
# 4  1.72580        0.027856  63.42340  34711.71704  65011.41146  6301.588000
#
#     23Na/43Ca  25Mg/43Ca  43Ca/43Ca  55Mn/43Ca  ...    peakID_3    peakID_4  \
# 0  302.361806   2.615137       1000   0.561287  ...  interval 7  interval 7
# 1  347.383247   3.401471       1000   0.705663  ...  interval 7  interval 7
# 2  273.196279   3.053552       1000   0.474172  ...  interval 7  interval 7
# 3  267.133045   1.636295       1000   0.531707  ...  interval 7  interval 7
# 4  268.982597   2.270707       1000   0.578052  ...  interval 7  interval 7
#
#              timing_1 timing_2 timing_3 timing_4   timing_1_centered  \
# 0 2022-10-25 10:00:00     None     None     None 2022-10-25 10:00:00
# 1 2022-10-25 09:24:01     None     None     None 2022-10-25 09:29:29
# 2 2022-10-25 08:48:02     None     None     None 2022-10-25 08:58:57
# 3 2022-10-25 08:12:03     None     None     None 2022-10-25 08:28:26
# 4 2022-10-25 07:36:04     None     None     None 2022-10-25 07:57:55
#
#   timing_2_centered timing_3_centered timing_4_centered
# 0              None              None              None
# 1              None              None              None
# 2              None              None              None
# 3              None              None              None
# 4              None              None              None
#
# [5 rows x 24 columns]
#
# Unique values in 'timing_1' column (first 10): <DatetimeArray>
# ['2022-10-25 10:00:00', '2022-10-25 09:24:01', '2022-10-25 08:48:02',
#  '2022-10-25 08:12:03', '2022-10-25 07:36:04', '2022-10-25 07:00:05',
#  '2022-10-25 06:24:06', '2022-10-25 05:48:07', '2022-10-25 05:12:08',
#  '2022-10-25 04:36:09']
# Length: 10, dtype: datetime64[ns]
#
# ----------------------------------------
# Updated data from B323_int_peakid.csv and peakID_2:
#      depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.00000        0.024061  62.98675  34712.41390  65012.50220  5551.232374
# 1  0.43145        0.027384  63.09597  34712.41390  65012.50220  4950.980294
# 2  0.86290        0.014567  63.20513  34712.18161  65012.13862  6051.464454
# 3  1.29435        0.035128  63.31432  34711.94932  65011.77504  6251.562891
# 4  1.72580        0.027856  63.42340  34711.71704  65011.41146  6301.588000
#
#     23Na/43Ca  25Mg/43Ca  43Ca/43Ca  55Mn/43Ca  ...    peakID_3    peakID_4  \
# 0  302.361806   2.615137       1000   0.561287  ...  interval 7  interval 7
# 1  347.383247   3.401471       1000   0.705663  ...  interval 7  interval 7
# 2  273.196279   3.053552       1000   0.474172  ...  interval 7  interval 7
# 3  267.133045   1.636295       1000   0.531707  ...  interval 7  interval 7
# 4  268.982597   2.270707       1000   0.578052  ...  interval 7  interval 7
#
#              timing_1            timing_2 timing_3 timing_4  \
# 0 2022-10-25 10:00:00 2022-10-25 10:00:00     None     None
# 1 2022-10-25 09:24:01 2022-10-25 09:24:01     None     None
# 2 2022-10-25 08:48:02 2022-10-25 08:48:02     None     None
# 3 2022-10-25 08:12:03 2022-10-25 08:12:03     None     None
# 4 2022-10-25 07:36:04 2022-10-25 07:36:04     None     None
#
#     timing_1_centered   timing_2_centered timing_3_centered timing_4_centered
# 0 2022-10-25 10:00:00 2022-10-25 10:00:00              None              None
# 1 2022-10-25 09:29:29 2022-10-25 09:29:29              None              None
# 2 2022-10-25 08:58:57 2022-10-25 08:58:57              None              None
# 3 2022-10-25 08:28:26 2022-10-25 08:28:26              None              None
# 4 2022-10-25 07:57:55 2022-10-25 07:57:55              None              None
#
# [5 rows x 24 columns]
#
# Unique values in 'timing_1' column (first 10): <DatetimeArray>
# ['2022-10-25 10:00:00', '2022-10-25 09:24:01', '2022-10-25 08:48:02',
#  '2022-10-25 08:12:03', '2022-10-25 07:36:04', '2022-10-25 07:00:05',
#  '2022-10-25 06:24:06', '2022-10-25 05:48:07', '2022-10-25 05:12:08',
#  '2022-10-25 04:36:09']
# Length: 10, dtype: datetime64[ns]
#
# ----------------------------------------
# Updated data from B323_int_peakid.csv and peakID_3:
#      depth  proxy_filtered      time         Xpos         Ypos         Ca43  \
# 0  0.00000        0.024061  62.98675  34712.41390  65012.50220  5551.232374
# 1  0.43145        0.027384  63.09597  34712.41390  65012.50220  4950.980294
# 2  0.86290        0.014567  63.20513  34712.18161  65012.13862  6051.464454
# 3  1.29435        0.035128  63.31432  34711.94932  65011.77504  6251.562891
# 4  1.72580        0.027856  63.42340  34711.71704  65011.41146  6301.588000
#
#     23Na/43Ca  25Mg/43Ca  43Ca/43Ca  55Mn/43Ca  ...    peakID_3    peakID_4  \
# 0  302.361806   2.615137       1000   0.561287  ...  interval 7  interval 7
# 1  347.383247   3.401471       1000   0.705663  ...  interval 7  interval 7
# 2  273.196279   3.053552       1000   0.474172  ...  interval 7  interval 7
# 3  267.133045   1.636295       1000   0.531707  ...  interval 7  interval 7
# 4  268.982597   2.270707       1000   0.578052  ...  interval 7  interval 7
#
#              timing_1            timing_2            timing_3 timing_4  \
# 0 2022-10-25 10:00:00 2022-10-25 10:00:00 2022-10-25 10:00:00     None
# 1 2022-10-25 09:24:01 2022-10-25 09:24:01 2022-10-25 09:24:01     None
# 2 2022-10-25 08:48:02 2022-10-25 08:48:02 2022-10-25 08:48:02     None
# 3 2022-10-25 08:12:03 2022-10-25 08:12:03 2022-10-25 08:12:03     None
# 4 2022-10-25 07:36:04 2022-10-25 07:36:04 2022-10-25 07:36:04     None
#
#     timing_1_centered   timing_2_centered   timing_3_centered  \
# 0 2022-10-25 10:00:00 2022-10-25 10:00:00 2022-10-25 10:00:00
# 1 2022-10-25 09:29:29 2022-10-25 09:29:29 2022-10-25 09:29:29
# 2 2022-10-25 08:58:57 2022-10-25 08:58:57 2022-10-25 08:58:57
# 3 2022-10-25 08:28:26 2022-10-25 08:28:26 2022-10-25 08:28:26
# 4 2022-10-25 07:57:55 2022-10-25 07:57:55 2022-10-25 07:57:55
#
#   timing_4_centered
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
#
# [5 rows x 24 columns]
#
# Unique values in 'timing_1' column (first 10): <DatetimeArray>
# ['2022-10-25 10:00:00', '2022-10-25 09:24:01', '2022-10-25 08:48:02',
#  '2022-10-25 08:12:03', '2022-10-25 07:36:04', '2022-10-25 07:00:05',
#  '2022-10-25 06:24:06', '2022-10-25 05:48:07', '2022-10-25 05:12:08',
#  '2022-10-25 04:36:09']
# Length: 10, dtype: datetime64[ns]
#
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 51
#      48 # Find timing info for this peak number (if available)
#      49 if peak_num is not None:
#      50     # Find all rows with this peak label
# ---> 51     peak_rows = df[df[peakID_col] == peaklabel]
#      52     if not peak_rows.empty:
#      53         # Find the middle row index for this peak
#      54         middle_idx = peak_rows.index[len(peak_rows) // 2]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4093, in DataFrame.__getitem__(self, key)
#    4091 # Do we have a (boolean) 1d indexer?
#    4092 if com.is_bool_indexer(key):
# -> 4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
#    4097 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4155, in DataFrame._getitem_bool_array(self, key)
#    4152     return self.copy(deep=None)
#    4154 indexer = key.nonzero()[0]
# -> 4155 return self._take_with_is_copy(indexer, axis=0)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:4153, in NDFrame._take_with_is_copy(self, indices, axis)
#    4142 @final
#    4143 def _take_with_is_copy(self, indices, axis: Axis = 0) -> Self:
#    4144     """
#    4145     Internal version of the `take` method that sets the `_is_copy`
#    4146     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    4151     See the docstring of `take` for full explanation of the parameters.
#    4152     """
# -> 4153     result = self.take(indices=indices, axis=axis)
#    4154     # Maybe set copy if we didn't actually change the index.
#    4155     if self.ndim == 2 and not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:4133, in NDFrame.take(self, indices, axis, **kwargs)
#    4128     # We can get here with a slice via DataFrame.__getitem__
#    4129     indices = np.arange(
#    4130         indices.start, indices.stop, indices.step, dtype=np.intp
#    4131     )
# -> 4133 new_data = self._mgr.take(
#    4134     indices,
#    4135     axis=self._get_block_manager_axis(axis),
#    4136     verify=True,
#    4137 )
#    4138 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4139     self, method="take"
#    4140 )
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:893, in BaseBlockManager.take(self, indexer, axis, verify)
#     890 n = self.shape[axis]
#     891 indexer = maybe_convert_indices(indexer, n, verify=verify)
# --> 893 new_labels = self.axes[axis].take(indexer)
#     894 return self.reindex_indexer(
#     895     new_axis=new_labels,
#     896     indexer=indexer,
#    (...)
#     899     copy=None,
#     900 )
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:1178, in RangeIndex.take(self, indices, axis, allow_fill, fill_value, **kwargs)
#    1174 if ind_min < -len(self):
#    1175     raise IndexError(
#    1176         f"index {ind_min} is out of bounds for axis 0 with size {len(self)}"
#    1177     )
# -> 1178 taken = indices.astype(self.dtype, casting="safe")
#    1179 if ind_min < 0:
#    1180     taken %= len(self)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Test age models with plot

# %%
file = list(dataframes.keys())[7]
df = dataframes[file]
    
# Check dating outcomes for one specimen
plt.figure(figsize=(10, 6))
plt.plot(df['depth'], df['timing_1'], '-', label='Timing 1')
plt.plot(df['depth'], df['timing_1_centered'], '-', label='Timing 1 Centered')
plt.plot(df['depth'], df['timing_2'], '-', label='Timing 2')
plt.plot(df['depth'], df['timing_2_centered'], '-', label='Timing 2 Centered')
plt.plot(df['depth'], df['timing_3'], '-', label='Timing 3')
plt.plot(df['depth'], df['timing_3_centered'], '-', label='Timing 3 Centered')
plt.plot(df['depth'], df['timing_4'], '-', label='Timing 4')
plt.plot(df['depth'], df['timing_4_centered'], '-', label='Timing 4 Centered')
plt.title(f'Timing vs Depth for {file}')
plt.xlabel('Depth (um)')
# Out:
# Text(0.5, 0, 'Depth (um)')

# %% [markdown]
# ### Extract growth rate per interval and per specimen

# %%
growth_intervals = {}

for file, df in dataframes.items():
    # Loop through each peak identification option
    for peakID_col in ['peakID_1', 'peakID_2', 'peakID_3', 'peakID_4']:
        # Determine which timing column to use based on peakID_col
        if peakID_col == 'peakID_1':
            timing_col = 'timing_1'
        elif peakID_col == 'peakID_2':
            timing_col = 'timing_2'
        elif peakID_col == 'peakID_3':
            timing_col = 'timing_3'
        elif peakID_col == 'peakID_4':
            timing_col = 'timing_4'

        # Select rows where peakID_col starts with 'interval'
        interval_rows = df[df[peakID_col].str.startswith('interval', na=False)]
        # Calculate total growth for each interval (e.g., "interval 0", "interval 1", ...)
        interval_growths = {}
        interval_labels = interval_rows[peakID_col].unique()
        for interval_label in interval_labels:
            rows = interval_rows[interval_rows[peakID_col] == interval_label]
            growth = rows['depth'].diff().abs().sum()

            # ALSO CALCULATE GROWTH RATES ASSUMING PEAKS HAVE NO WIDTH
            # Find names of peaks before and after the interval
            interval_idx = df.index[rows.index[0]]

            # Find previous peak
            if interval_idx > 0:
                prev_row = df.iloc[interval_idx - 1]
                if isinstance(prev_row[peakID_col], str) and prev_row[peakID_col].startswith(peakID_col):
                    prev_peak = prev_row[peakID_col]

            # Find next peak
            last_idx = df.index[rows.index[-1]]
            if last_idx < len(df) - 1:
                next_row = df.iloc[last_idx + 1]
                if isinstance(next_row[peakID_col], str) and next_row[peakID_col].startswith(peakID_col):
                    next_peak = next_row[peakID_col]

            # Initialize peak widths as NaN
            prev_peak_width = np.nan
            next_peak_width = np.nan

            # Find width of previous peak
            if 'prev_peak' in locals():
                prev_peak_rows = df[df[peakID_col] == prev_peak]
                if not prev_peak_rows.empty:
                    prev_peak_width = prev_peak_rows['depth'].max() - prev_peak_rows['depth'].min()

            # Find width of next peak
            if 'next_peak' in locals():
                next_peak_rows = df[df[peakID_col] == next_peak]
                if not next_peak_rows.empty:
                    next_peak_width = next_peak_rows['depth'].max() - next_peak_rows['depth'].min()

            # Add half widths to growth (uncomment if needed)
            centered_growth = growth + 0.5 * (prev_peak_width if not np.isnan(prev_peak_width) else 0) + 0.5 * (next_peak_width if not np.isnan(next_peak_width) else 0)

            interval_times = pd.to_datetime(rows[timing_col], errors='coerce')
            if interval_times.notnull().sum() > 1:
                start_date = interval_times.min()
                end_date = interval_times.max()
                total_time_days = (end_date - start_date).total_seconds() / (60 * 60 * 24)
            else:
                start_date = end_date = pd.NaT
                total_time_days = np.nan

            # Calculate growth rates (um/day)
            growth_rate = growth / total_time_days if total_time_days and not np.isnan(total_time_days) and total_time_days > 0 else np.nan
            growth_rate_centered = centered_growth / total_time_days if total_time_days and not np.isnan(total_time_days) and total_time_days > 0 else np.nan

            interval_growths[interval_label] = {
                'peakID': peakID_col,
                'total_growth': growth,
                'total_growth_centered' : centered_growth,
                'total_time_days': total_time_days,
                'growth_rate': growth_rate,
                'growth_rate_centered': growth_rate_centered,
                'start_date': start_date,
                'end_date': end_date
            }
        # Store the interval growths for this file and peakID_col    
        growth_intervals[file + "_" + peakID_col] = interval_growths

# Print the total growth, growth rate, and dates for each interval in each file
for file, growths in growth_intervals.items():
    print(f"Total growth, growth rate, and dates for intervals in {file}:")
    for interval, stats in growths.items():
        peakID_col = stats.get('peakID', np.nan)
        total_growth = stats.get('total_growth', np.nan)
        growth_rate = stats.get('growth_rate', np.nan)
        total_growth_centered = stats.get('total_growth_centered', np.nan)
        growth_rate_centered = stats.get('growth_rate_centered', np.nan)
        start_date = stats.get('start_date', pd.NaT)
        end_date = stats.get('end_date', pd.NaT)
        print(f"{peakID_col} {interval}: {total_growth:.2f} um, {growth_rate:.2f} um/day, {growth_rate_centered:.2f} um/day, start: {start_date}, end: {end_date}")
    print("-" * 40)  # Separator for clarity

# Export the growth intervals to a CSV file
growth_intervals_df = pd.DataFrame.from_dict(
    {file: {interval: stats for interval, stats in growths.items()} for file, growths in growth_intervals.items()},
    orient='index'
)
growth_intervals_df = growth_intervals_df.stack().reset_index()
growth_intervals_df.columns = ['File', 'Interval', 'Stats']
# Expand the 'Stats' column into separate columns
growth_intervals_df = growth_intervals_df.join(
    pd.json_normalize(growth_intervals_df['Stats'])
).drop(columns=['Stats'])
# Save to CSV
growth_intervals_df.to_csv('Growth_intervals_summary_peakID.csv', index=False)
# Out:
# Total growth, growth rate, and dates for intervals in B255_int_peakid.csv_peakID_1:
# peakID_1 interval 7: 941.78 um, 20.33 um/day, 20.33 um/day, start: 2022-09-09 02:10:26, end: 2022-10-25 10:00:00
# peakID_1 interval 6: 968.72 um, 34.61 um/day, 34.61 um/day, start: 2022-08-12 01:38:14, end: 2022-09-09 01:22:08
# peakID_1 interval 4: 2658.44 um, 101.49 um/day, 101.49 um/day, start: 2022-06-28 01:13:38, end: 2022-07-24 05:53:56
# peakID_1 interval 3: 4132.76 um, 153.54 um/day, 153.54 um/day, start: 2022-06-01 03:04:05, end: 2022-06-28 01:03:21
# peakID_1 interval 2: 1561.56 um, 77.44 um/day, 77.44 um/day, start: 2022-05-11 22:52:58, end: 2022-06-01 02:51:59
# peakID_1 interval 1: 2810.91 um, 165.91 um/day, 165.91 um/day, start: 2022-04-25 00:03:43, end: 2022-05-11 22:41:12
# peakID_1 interval 0: 1752.26 um, 21.22 um/day, 21.22 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:30:13
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in B255_int_peakid.csv_peakID_2:
# peakID_2 interval 7: 941.78 um, 20.33 um/day, 20.33 um/day, start: 2022-09-09 02:10:26, end: 2022-10-25 10:00:00
# peakID_2 interval 6: 968.72 um, 34.61 um/day, 34.61 um/day, start: 2022-08-12 01:38:14, end: 2022-09-09 01:22:08
# peakID_2 interval 4: 1130.20 um, 43.17 um/day, 43.17 um/day, start: 2022-06-28 01:22:00, end: 2022-07-24 05:45:43
# peakID_2 interval 3: 124.61 um, 4.66 um/day, 4.66 um/day, start: 2022-06-01 05:13:41, end: 2022-06-27 22:53:49
# peakID_2 interval 2: 936.26 um, 46.45 um/day, 46.45 um/day, start: 2022-05-11 22:58:44, end: 2022-06-01 02:46:16
# peakID_2 interval 1: 9991.75 um, 589.61 um/day, 589.61 um/day, start: 2022-04-25 00:01:04, end: 2022-05-11 22:43:56
# peakID_2 interval 0: 1229.88 um, 14.90 um/day, 14.90 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:18:05
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in B255_int_peakid.csv_peakID_3:
# peakID_3 interval 7: 941.78 um, 20.33 um/day, 20.33 um/day, start: 2022-09-09 02:10:26, end: 2022-10-25 10:00:00
# peakID_3 interval 6: 968.72 um, 34.61 um/day, 34.61 um/day, start: 2022-08-12 01:38:14, end: 2022-09-09 01:22:08
# peakID_3 interval 4: 2658.44 um, 101.49 um/day, 101.49 um/day, start: 2022-06-28 01:13:38, end: 2022-07-24 05:53:56
# peakID_3 interval 3: 936.26 um, 34.81 um/day, 34.81 um/day, start: 2022-06-01 03:18:20, end: 2022-06-28 00:49:10
# peakID_3 interval 2: 4758.40 um, 235.87 um/day, 235.87 um/day, start: 2022-05-11 22:47:37, end: 2022-06-01 02:57:21
# peakID_3 interval 1: 4233.05 um, 249.82 um/day, 249.82 um/day, start: 2022-04-25 00:02:30, end: 2022-05-11 22:42:29
# peakID_3 interval 0: 1229.88 um, 14.90 um/day, 14.90 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:18:05
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in B255_int_peakid.csv_peakID_4:
# peakID_4 interval 7: 941.78 um, 20.33 um/day, 20.33 um/day, start: 2022-09-09 02:10:26, end: 2022-10-25 10:00:00
# peakID_4 interval 6: 968.72 um, 34.61 um/day, 34.61 um/day, start: 2022-08-12 01:38:14, end: 2022-09-09 01:22:08
# peakID_4 interval 4: 1130.20 um, 43.17 um/day, 43.17 um/day, start: 2022-06-28 01:22:00, end: 2022-07-24 05:45:43
# peakID_4 interval 3: 4383.04 um, 162.84 um/day, 162.84 um/day, start: 2022-06-01 03:03:51, end: 2022-06-28 01:03:40
# peakID_4 interval 2: 1561.56 um, 77.44 um/day, 77.44 um/day, start: 2022-05-11 22:52:58, end: 2022-06-01 02:51:59
# peakID_4 interval 1: 4233.05 um, 249.82 um/day, 249.82 um/day, start: 2022-04-25 00:02:30, end: 2022-05-11 22:42:29
# peakID_4 interval 0: 1229.88 um, 14.90 um/day, 14.90 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:18:05
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in B323_int_peakid.csv_peakID_1:
# peakID_1 interval 7: 799.81 um, 17.27 um/day, 17.27 um/day, start: 2022-09-09 02:16:04, end: 2022-10-25 10:00:00
# peakID_1 interval 6: 558.07 um, 19.95 um/day, 19.95 um/day, start: 2022-08-12 01:51:50, end: 2022-09-09 01:08:47
# peakID_1 interval 5: 1566.09 um, 83.33 um/day, 83.33 um/day, start: 2022-07-24 06:07:38, end: 2022-08-12 01:12:23
# peakID_1 interval 4: 2141.88 um, 81.77 um/day, 81.77 um/day, start: 2022-06-28 01:15:06, end: 2022-07-24 05:52:13
# peakID_1 interval 3: 2166.67 um, 80.51 um/day, 80.51 um/day, start: 2022-06-01 03:07:45, end: 2022-06-28 00:59:47
# peakID_1 interval 1: 1437.65 um, 84.88 um/day, 84.88 um/day, start: 2022-04-25 00:07:26, end: 2022-05-11 22:37:40
# peakID_1 interval 0: 1570.39 um, 19.02 um/day, 19.02 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:26:55
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in B323_int_peakid.csv_peakID_2:
# peakID_2 interval 7: 799.81 um, 17.27 um/day, 17.27 um/day, start: 2022-09-09 02:16:04, end: 2022-10-25 10:00:00
# peakID_2 interval 6: 558.07 um, 19.95 um/day, 19.95 um/day, start: 2022-08-12 01:51:50, end: 2022-09-09 01:08:47
# peakID_2 interval 5: 1566.09 um, 83.33 um/day, 83.33 um/day, start: 2022-07-24 06:07:38, end: 2022-08-12 01:12:23
# peakID_2 interval 4: 2141.88 um, 81.77 um/day, 81.77 um/day, start: 2022-06-28 01:15:06, end: 2022-07-24 05:52:13
# peakID_2 interval 3: 2210.43 um, 82.14 um/day, 82.14 um/day, start: 2022-06-01 03:07:36, end: 2022-06-28 00:59:56
# peakID_2 interval 1: 1437.65 um, 84.88 um/day, 84.88 um/day, start: 2022-04-25 00:07:26, end: 2022-05-11 22:37:40
# peakID_2 interval 0: 1570.39 um, 19.02 um/day, 19.02 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:26:55
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in B323_int_peakid.csv_peakID_3:
# peakID_3 interval 7: 799.81 um, 17.27 um/day, 17.27 um/day, start: 2022-09-09 02:16:04, end: 2022-10-25 10:00:00
# peakID_3 interval 6: 558.07 um, 19.95 um/day, 19.95 um/day, start: 2022-08-12 01:51:50, end: 2022-09-09 01:08:47
# peakID_3 interval 5: 1566.09 um, 83.33 um/day, 83.33 um/day, start: 2022-07-24 06:07:38, end: 2022-08-12 01:12:23
# peakID_3 interval 3: 1484.27 um, 55.16 um/day, 55.16 um/day, start: 2022-06-01 03:11:16, end: 2022-06-28 00:56:04
# peakID_3 interval 2: 2166.67 um, 107.43 um/day, 107.43 um/day, start: 2022-05-11 22:50:49, end: 2022-06-01 02:54:13
# peakID_3 interval 1: 2112.39 um, 124.69 um/day, 124.69 um/day, start: 2022-04-25 00:05:04, end: 2022-05-11 22:40:00
# peakID_3 interval 0: 1570.39 um, 19.02 um/day, 19.02 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:26:55
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in B323_int_peakid.csv_peakID_4:
# peakID_4 interval 7: 799.81 um, 17.27 um/day, 17.27 um/day, start: 2022-09-09 02:16:04, end: 2022-10-25 10:00:00
# peakID_4 interval 6: 558.07 um, 19.95 um/day, 19.95 um/day, start: 2022-08-12 01:51:50, end: 2022-09-09 01:08:47
# peakID_4 interval 5: 1566.09 um, 83.33 um/day, 83.33 um/day, start: 2022-07-24 06:07:38, end: 2022-08-12 01:12:23
# peakID_4 interval 3: 3835.17 um, 142.49 um/day, 142.49 um/day, start: 2022-06-01 03:04:23, end: 2022-06-28 01:03:04
# peakID_4 interval 1: 1437.65 um, 84.88 um/day, 84.88 um/day, start: 2022-04-25 00:07:26, end: 2022-05-11 22:37:40
# peakID_4 interval 0: 1570.39 um, 19.02 um/day, 19.02 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:26:55
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in B325_int_peakid.csv_peakID_1:
# peakID_1 interval 7: 578.92 um, 12.50 um/day, 12.50 um/day, start: 2022-09-09 02:29:08, end: 2022-10-25 10:00:00
# peakID_1 interval 6: 1290.97 um, 46.11 um/day, 46.11 um/day, start: 2022-08-12 01:33:39, end: 2022-09-09 01:26:30
# peakID_1 interval 5: 1096.41 um, 58.35 um/day, 58.35 um/day, start: 2022-07-24 06:10:41, end: 2022-08-12 01:09:13
# peakID_1 interval 4: 558.92 um, 21.36 um/day, 21.36 um/day, start: 2022-06-28 01:36:17, end: 2022-07-24 05:31:13
# peakID_1 interval 3: 1260.07 um, 46.84 um/day, 46.84 um/day, start: 2022-06-01 03:13:33, end: 2022-06-28 00:54:03
# peakID_1 interval 2: 637.06 um, 31.62 um/day, 31.62 um/day, start: 2022-05-11 23:04:50, end: 2022-06-01 02:39:55
# peakID_1 interval 1: 46.35 um, 2.79 um/day, 2.79 um/day, start: 2022-04-25 03:48:05, end: 2022-05-11 18:56:55
# peakID_1 interval 0: 3363.83 um, 40.74 um/day, 40.74 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:44:35
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in B325_int_peakid.csv_peakID_2:
# peakID_2 interval 7: 578.92 um, 12.50 um/day, 12.50 um/day, start: 2022-09-09 02:29:08, end: 2022-10-25 10:00:00
# peakID_2 interval 6: 1290.97 um, 46.11 um/day, 46.11 um/day, start: 2022-08-12 01:33:39, end: 2022-09-09 01:26:30
# peakID_2 interval 4: 1726.45 um, 65.92 um/day, 65.92 um/day, start: 2022-06-28 01:16:50, end: 2022-07-24 05:50:27
# peakID_2 interval 3: 1260.07 um, 46.84 um/day, 46.84 um/day, start: 2022-06-01 03:13:33, end: 2022-06-28 00:54:03
# peakID_2 interval 2: 637.06 um, 31.62 um/day, 31.62 um/day, start: 2022-05-11 23:04:50, end: 2022-06-01 02:39:55
# peakID_2 interval 1: 46.35 um, 2.79 um/day, 2.79 um/day, start: 2022-04-25 03:48:05, end: 2022-05-11 18:56:55
# peakID_2 interval 0: 3363.83 um, 40.74 um/day, 40.74 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:44:35
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in B325_int_peakid.csv_peakID_3:
# peakID_3 interval 7: 578.92 um, 12.50 um/day, 12.50 um/day, start: 2022-09-09 02:29:08, end: 2022-10-25 10:00:00
# peakID_3 interval 6: 1290.97 um, 46.11 um/day, 46.11 um/day, start: 2022-08-12 01:33:39, end: 2022-09-09 01:26:30
# peakID_3 interval 4: 1726.45 um, 65.92 um/day, 65.92 um/day, start: 2022-06-28 01:16:50, end: 2022-07-24 05:50:27
# peakID_3 interval 3: 1260.07 um, 46.84 um/day, 46.84 um/day, start: 2022-06-01 03:13:33, end: 2022-06-28 00:54:03
# peakID_3 interval 2: 637.06 um, 31.62 um/day, 31.62 um/day, start: 2022-05-11 23:04:50, end: 2022-06-01 02:39:55
# peakID_3 interval 1: 556.24 um, 32.87 um/day, 32.87 um/day, start: 2022-04-25 00:19:20, end: 2022-05-11 22:25:40
# peakID_3 interval 0: 3698.86 um, 44.79 um/day, 44.79 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:45:59
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in B325_int_peakid.csv_peakID_4:
# peakID_4 interval 7: 578.92 um, 12.50 um/day, 12.50 um/day, start: 2022-09-09 02:29:08, end: 2022-10-25 10:00:00
# peakID_4 interval 6: 1290.97 um, 46.11 um/day, 46.11 um/day, start: 2022-08-12 01:33:39, end: 2022-09-09 01:26:30
# peakID_4 interval 4: 1726.45 um, 65.92 um/day, 65.92 um/day, start: 2022-06-28 01:16:50, end: 2022-07-24 05:50:27
# peakID_4 interval 3: 1260.07 um, 46.84 um/day, 46.84 um/day, start: 2022-06-01 03:13:33, end: 2022-06-28 00:54:03
# peakID_4 interval 2: 637.06 um, 31.62 um/day, 31.62 um/day, start: 2022-05-11 23:04:50, end: 2022-06-01 02:39:55
# peakID_4 interval 1: 46.35 um, 2.79 um/day, 2.79 um/day, start: 2022-04-25 03:48:05, end: 2022-05-11 18:56:55
# peakID_4 interval 0: 3363.83 um, 40.74 um/day, 40.74 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:44:35
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G652_sub_peakid.csv_peakID_1:
# peakID_1 interval 7: 914.71 um, 19.75 um/day, 19.75 um/day, start: 2022-09-09 02:22:33, end: 2022-10-25 10:00:00
# peakID_1 interval 6: 155.38 um, 5.58 um/day, 5.58 um/day, start: 2022-08-12 03:45:12, end: 2022-09-08 23:54:48
# peakID_1 interval 5: 855.82 um, 45.50 um/day, 45.50 um/day, start: 2022-07-24 06:13:31, end: 2022-08-12 01:36:18
# peakID_1 interval 4: 1990.67 um, 76.03 um/day, 76.03 um/day, start: 2022-06-28 01:30:48, end: 2022-07-24 05:51:55
# peakID_1 interval 3: 697.70 um, 25.96 um/day, 25.96 um/day, start: 2022-06-01 03:54:26, end: 2022-06-28 00:58:13
# peakID_1 interval 2: 4223.77 um, 209.31 um/day, 209.31 um/day, start: 2022-05-11 23:08:00, end: 2022-06-01 03:26:58
# peakID_1 interval 1: 2697.30 um, 159.07 um/day, 159.07 um/day, start: 2022-04-25 00:04:00, end: 2022-05-11 23:01:02
# peakID_1 interval 0: 6183.19 um, 74.88 um/day, 74.88 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:51:45
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G652_sub_peakid.csv_peakID_2:
# peakID_2 interval 7: 1465.68 um, 31.64 um/day, 31.64 um/day, start: 2022-09-09 02:10:19, end: 2022-10-25 10:00:00
# peakID_2 interval 6: 1460.39 um, 52.19 um/day, 52.19 um/day, start: 2022-08-12 02:01:47, end: 2022-09-09 01:37:41
# peakID_2 interval 5: 321.60 um, 17.13 um/day, 17.13 um/day, start: 2022-07-24 06:36:56, end: 2022-08-12 01:14:06
# peakID_2 interval 4: 931.30 um, 35.59 um/day, 35.59 um/day, start: 2022-06-28 01:40:13, end: 2022-07-24 05:42:29
# peakID_2 interval 3: 697.70 um, 25.96 um/day, 25.96 um/day, start: 2022-06-01 03:54:26, end: 2022-06-28 00:58:13
# peakID_2 interval 2: 4223.77 um, 209.31 um/day, 209.31 um/day, start: 2022-05-11 23:08:00, end: 2022-06-01 03:26:58
# peakID_2 interval 1: 1633.46 um, 96.35 um/day, 96.35 um/day, start: 2022-04-25 00:06:36, end: 2022-05-11 22:58:27
# peakID_2 interval 0: 7702.57 um, 93.28 um/day, 93.28 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:53:11
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G652_sub_peakid.csv_peakID_3:
# peakID_3 interval 7: 914.71 um, 19.75 um/day, 19.75 um/day, start: 2022-09-09 02:22:33, end: 2022-10-25 10:00:00
# peakID_3 interval 4: 855.82 um, 32.71 um/day, 32.71 um/day, start: 2022-06-28 01:41:18, end: 2022-07-24 05:40:57
# peakID_3 interval 3: 1478.51 um, 54.97 um/day, 54.97 um/day, start: 2022-06-01 03:41:21, end: 2022-06-28 01:11:19
# peakID_3 interval 2: 411.70 um, 20.44 um/day, 20.44 um/day, start: 2022-05-11 23:35:51, end: 2022-06-01 02:59:30
# peakID_3 interval 1: 697.70 um, 41.19 um/day, 41.19 um/day, start: 2022-04-25 00:15:24, end: 2022-05-11 22:49:41
# peakID_3 interval 0: 14319.25 um, 173.40 um/day, 173.40 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:56:21
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G652_sub_peakid.csv_peakID_4:
# peakID_4 interval 7: 941.50 um, 20.33 um/day, 20.33 um/day, start: 2022-09-09 02:21:38, end: 2022-10-25 10:00:00
# peakID_4 interval 5: 855.82 um, 45.50 um/day, 45.50 um/day, start: 2022-07-24 06:13:31, end: 2022-08-12 01:36:18
# peakID_4 interval 4: 1478.51 um, 56.48 um/day, 56.48 um/day, start: 2022-06-28 01:33:32, end: 2022-07-24 05:49:07
# peakID_4 interval 3: 411.70 um, 15.33 um/day, 15.33 um/day, start: 2022-06-01 04:11:08, end: 2022-06-28 00:41:50
# peakID_4 interval 2: 697.70 um, 34.61 um/day, 34.61 um/day, start: 2022-05-11 23:23:20, end: 2022-06-01 03:11:47
# peakID_4 interval 1: 6079.46 um, 358.47 um/day, 358.47 um/day, start: 2022-04-25 00:01:46, end: 2022-05-11 23:03:14
# peakID_4 interval 0: 7702.57 um, 93.28 um/day, 93.28 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:53:11
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G664_sub_peakid.csv_peakID_1:
# peakID_1 interval 7: 140.70 um, 3.05 um/day, 3.05 um/day, start: 2022-09-09 05:12:50, end: 2022-10-25 10:00:00
# peakID_1 interval 6: 1242.29 um, 44.40 um/day, 44.40 um/day, start: 2022-08-12 02:03:59, end: 2022-09-09 01:36:05
# peakID_1 interval 5: 402.83 um, 21.44 um/day, 21.44 um/day, start: 2022-07-24 06:28:58, end: 2022-08-12 01:21:02
# peakID_1 interval 4: 2236.76 um, 85.43 um/day, 85.43 um/day, start: 2022-06-28 01:30:00, end: 2022-07-24 05:52:44
# peakID_1 interval 3: 921.49 um, 34.27 um/day, 34.27 um/day, start: 2022-06-01 03:48:29, end: 2022-06-28 01:03:49
# peakID_1 interval 2: 4516.38 um, 223.80 um/day, 223.80 um/day, start: 2022-05-11 23:07:48, end: 2022-06-01 03:27:10
# peakID_1 interval 0: 2927.55 um, 35.45 um/day, 35.45 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:42:10
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G664_sub_peakid.csv_peakID_2:
# peakID_2 interval 7: 1344.42 um, 29.02 um/day, 29.02 um/day, start: 2022-09-09 02:11:17, end: 2022-10-25 10:00:00
# peakID_2 interval 6: 892.37 um, 31.90 um/day, 31.90 um/day, start: 2022-08-12 02:09:28, end: 2022-09-09 01:30:38
# peakID_2 interval 5: 2236.76 um, 118.86 um/day, 118.86 um/day, start: 2022-07-24 06:05:23, end: 2022-08-12 01:44:46
# peakID_2 interval 4: 921.49 um, 35.21 um/day, 35.21 um/day, start: 2022-06-28 01:40:30, end: 2022-07-24 05:41:48
# peakID_2 interval 3: 258.78 um, 9.65 um/day, 9.65 um/day, start: 2022-06-01 04:35:41, end: 2022-06-28 00:16:49
# peakID_2 interval 2: 2186.47 um, 108.37 um/day, 108.37 um/day, start: 2022-05-11 23:10:52, end: 2022-06-01 03:24:06
# peakID_2 interval 1: 946.05 um, 55.83 um/day, 55.83 um/day, start: 2022-04-25 00:11:14, end: 2022-05-11 22:53:36
# peakID_2 interval 0: 2927.55 um, 35.45 um/day, 35.45 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:42:10
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G664_sub_peakid.csv_peakID_3:
# peakID_3 interval 7: 143.71 um, 3.11 um/day, 3.11 um/day, start: 2022-09-09 05:08:36, end: 2022-10-25 10:00:00
# peakID_3 interval 5: 1745.61 um, 92.77 um/day, 92.77 um/day, start: 2022-07-24 06:06:42, end: 2022-08-12 01:43:20
# peakID_3 interval 4: 2236.76 um, 85.43 um/day, 85.43 um/day, start: 2022-06-28 01:30:00, end: 2022-07-24 05:52:44
# peakID_3 interval 3: 921.49 um, 34.27 um/day, 34.27 um/day, start: 2022-06-01 03:48:29, end: 2022-06-28 01:03:49
# peakID_3 interval 2: 2883.81 um, 142.92 um/day, 142.92 um/day, start: 2022-05-11 23:09:27, end: 2022-06-01 03:25:34
# peakID_3 interval 1: 1587.62 um, 93.65 um/day, 93.65 um/day, start: 2022-04-25 00:06:42, end: 2022-05-11 22:58:12
# peakID_3 interval 0: 3775.70 um, 45.73 um/day, 45.73 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:46:17
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G664_sub_peakid.csv_peakID_4:
# peakID_4 interval 7: 140.70 um, 3.05 um/day, 3.05 um/day, start: 2022-09-09 05:12:50, end: 2022-10-25 10:00:00
# peakID_4 interval 6: 1242.29 um, 44.40 um/day, 44.40 um/day, start: 2022-08-12 02:03:59, end: 2022-09-09 01:36:05
# peakID_4 interval 5: 402.83 um, 21.44 um/day, 21.44 um/day, start: 2022-07-24 06:28:58, end: 2022-08-12 01:21:02
# peakID_4 interval 4: 2236.76 um, 85.43 um/day, 85.43 um/day, start: 2022-06-28 01:30:00, end: 2022-07-24 05:52:44
# peakID_4 interval 3: 921.49 um, 34.27 um/day, 34.27 um/day, start: 2022-06-01 03:48:29, end: 2022-06-28 01:03:49
# peakID_4 interval 2: 4571.71 um, 226.54 um/day, 226.54 um/day, start: 2022-05-11 23:07:46, end: 2022-06-01 03:27:12
# peakID_4 interval 0: 2927.55 um, 35.45 um/day, 35.45 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:42:10
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G668_sub_peakid.csv_peakID_1:
# peakID_1 interval 7: 801.71 um, 17.31 um/day, 17.31 um/day, start: 2022-09-09 02:26:48, end: 2022-10-25 10:00:00
# peakID_1 interval 6: 241.14 um, 8.64 um/day, 8.64 um/day, start: 2022-08-12 03:04:23, end: 2022-09-09 00:35:37
# peakID_1 interval 4: 334.50 um, 12.80 um/day, 12.80 um/day, start: 2022-06-28 02:10:18, end: 2022-07-24 05:12:12
# peakID_1 interval 3: 466.56 um, 17.37 um/day, 17.37 um/day, start: 2022-06-01 04:06:05, end: 2022-06-28 00:46:25
# peakID_1 interval 2: 375.13 um, 18.63 um/day, 18.63 um/day, start: 2022-05-11 23:38:02, end: 2022-06-01 02:56:58
# peakID_1 interval 1: 1027.56 um, 60.63 um/day, 60.63 um/day, start: 2022-04-25 00:10:06, end: 2022-05-11 22:54:34
# peakID_1 interval 0: 3398.99 um, 41.16 um/day, 41.16 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:45:07
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G668_sub_peakid.csv_peakID_2:
# peakID_2 interval 7: 801.71 um, 17.31 um/day, 17.31 um/day, start: 2022-09-09 02:26:48, end: 2022-10-25 10:00:00
# peakID_2 interval 6: 241.14 um, 8.64 um/day, 8.64 um/day, start: 2022-08-12 03:04:23, end: 2022-09-09 00:35:37
# peakID_2 interval 5: 542.34 um, 28.85 um/day, 28.85 um/day, start: 2022-07-24 06:21:13, end: 2022-08-12 01:28:47
# peakID_2 interval 4: 486.14 um, 18.59 um/day, 18.59 um/day, start: 2022-06-28 01:56:12, end: 2022-07-24 05:26:18
# peakID_2 interval 3: 880.99 um, 32.77 um/day, 32.77 um/day, start: 2022-06-01 03:48:47, end: 2022-06-28 01:03:22
# peakID_2 interval 2: 1027.56 um, 50.95 um/day, 50.95 um/day, start: 2022-05-11 23:17:02, end: 2022-06-01 03:17:35
# peakID_2 interval 1: 1321.91 um, 77.99 um/day, 77.99 um/day, start: 2022-04-25 00:07:56, end: 2022-05-11 22:57:08
# peakID_2 interval 0: 1976.61 um, 23.94 um/day, 23.94 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:34:11
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G668_sub_peakid.csv_peakID_3:
# peakID_3 interval 7: 801.71 um, 17.31 um/day, 17.31 um/day, start: 2022-09-09 02:26:48, end: 2022-10-25 10:00:00
# peakID_3 interval 6: 241.14 um, 8.64 um/day, 8.64 um/day, start: 2022-08-12 03:04:23, end: 2022-09-09 00:35:37
# peakID_3 interval 4: 334.50 um, 12.80 um/day, 12.80 um/day, start: 2022-06-28 02:10:18, end: 2022-07-24 05:12:12
# peakID_3 interval 3: 486.14 um, 18.10 um/day, 18.10 um/day, start: 2022-06-01 04:04:38, end: 2022-06-28 00:47:52
# peakID_3 interval 2: 880.99 um, 43.69 um/day, 43.69 um/day, start: 2022-05-11 23:19:05, end: 2022-06-01 03:15:39
# peakID_3 interval 1: 242.04 um, 14.32 um/day, 14.32 um/day, start: 2022-04-25 00:44:10, end: 2022-05-11 22:20:50
# peakID_3 interval 0: 3284.50 um, 39.78 um/day, 39.78 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:44:36
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G668_sub_peakid.csv_peakID_4:
# peakID_4 interval 7: 801.71 um, 17.31 um/day, 17.31 um/day, start: 2022-09-09 02:26:48, end: 2022-10-25 10:00:00
# peakID_4 interval 6: 241.14 um, 8.64 um/day, 8.64 um/day, start: 2022-08-12 03:04:23, end: 2022-09-09 00:35:37
# peakID_4 interval 4: 334.50 um, 12.80 um/day, 12.80 um/day, start: 2022-06-28 02:10:18, end: 2022-07-24 05:12:12
# peakID_4 interval 3: 792.98 um, 29.50 um/day, 29.50 um/day, start: 2022-06-01 03:51:15, end: 2022-06-28 01:01:15
# peakID_4 interval 2: 867.49 um, 43.02 um/day, 43.02 um/day, start: 2022-05-11 23:19:18, end: 2022-06-01 03:15:26
# peakID_4 interval 1: 1027.56 um, 60.63 um/day, 60.63 um/day, start: 2022-04-25 00:10:06, end: 2022-05-11 22:54:34
# peakID_4 interval 0: 3398.99 um, 41.16 um/day, 41.16 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:45:07
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G691_int_peakid.csv_peakID_1:
# peakID_1 interval 7: 857.95 um, 18.52 um/day, 18.52 um/day, start: 2022-09-09 02:13:56, end: 2022-10-25 10:00:00
# peakID_1 interval 6: 865.21 um, 30.92 um/day, 30.92 um/day, start: 2022-08-12 01:40:35, end: 2022-09-09 01:19:40
# peakID_1 interval 5: 154.77 um, 8.28 um/day, 8.28 um/day, start: 2022-07-24 07:17:20, end: 2022-08-12 00:03:58
# peakID_1 interval 4: 830.65 um, 31.73 um/day, 31.73 um/day, start: 2022-06-28 01:27:41, end: 2022-07-24 05:40:11
# peakID_1 interval 2: 4607.17 um, 228.38 um/day, 228.38 um/day, start: 2022-05-11 22:47:47, end: 2022-06-01 02:57:11
# peakID_1 interval 1: 1289.22 um, 76.12 um/day, 76.12 um/day, start: 2022-04-25 00:08:11, end: 2022-05-11 22:36:52
# peakID_1 interval 0: 3476.23 um, 42.10 um/day, 42.10 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:45:09
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G691_int_peakid.csv_peakID_2:
# peakID_2 interval 7: 499.87 um, 10.79 um/day, 10.79 um/day, start: 2022-09-09 02:38:10, end: 2022-10-25 10:00:00
# peakID_2 interval 6: 2072.95 um, 74.03 um/day, 74.03 um/day, start: 2022-08-12 01:28:39, end: 2022-09-09 01:31:31
# peakID_2 interval 4: 437.93 um, 16.75 um/day, 16.75 um/day, start: 2022-06-28 01:45:03, end: 2022-07-24 05:22:27
# peakID_2 interval 3: 2174.02 um, 80.79 um/day, 80.79 um/day, start: 2022-06-01 03:07:48, end: 2022-06-28 00:59:31
# peakID_2 interval 2: 1057.14 um, 52.44 um/day, 52.44 um/day, start: 2022-05-11 22:57:06, end: 2022-06-01 02:48:07
# peakID_2 interval 1: 1445.39 um, 85.34 um/day, 85.34 um/day, start: 2022-04-25 00:07:18, end: 2022-05-11 22:37:34
# peakID_2 interval 0: 3767.48 um, 45.63 um/day, 45.63 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:46:18
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G691_int_peakid.csv_peakID_3:
# peakID_3 interval 7: 499.87 um, 10.79 um/day, 10.79 um/day, start: 2022-09-09 02:38:10, end: 2022-10-25 10:00:00
# peakID_3 interval 5: 1750.70 um, 37.41 um/day, 37.41 um/day, start: 2022-07-24 06:17:07, end: 2022-09-09 01:23:12
# peakID_3 interval 4: 437.93 um, 16.75 um/day, 16.75 um/day, start: 2022-06-28 01:45:03, end: 2022-07-24 05:22:27
# peakID_3 interval 3: 2540.40 um, 94.39 um/day, 94.39 um/day, start: 2022-06-01 03:06:31, end: 2022-06-28 01:00:40
# peakID_3 interval 2: 1811.08 um, 89.80 um/day, 89.80 um/day, start: 2022-05-11 22:52:04, end: 2022-06-01 02:53:09
# peakID_3 interval 1: 1289.22 um, 76.12 um/day, 76.12 um/day, start: 2022-04-25 00:08:11, end: 2022-05-11 22:36:52
# peakID_3 interval 0: 3476.23 um, 42.10 um/day, 42.10 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:45:09
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G691_int_peakid.csv_peakID_4:
# peakID_4 interval 7: 377.81 um, 8.16 um/day, 8.16 um/day, start: 2022-09-09 02:56:53, end: 2022-10-25 10:00:00
# peakID_4 interval 6: 95.99 um, 3.46 um/day, 3.46 um/day, start: 2022-08-12 04:21:45, end: 2022-09-08 22:38:23
# peakID_4 interval 5: 2283.30 um, 121.46 um/day, 121.46 um/day, start: 2022-07-24 06:05:16, end: 2022-08-12 01:14:50
# peakID_4 interval 3: 437.93 um, 16.30 um/day, 16.30 um/day, start: 2022-06-01 03:38:34, end: 2022-06-28 00:28:56
# peakID_4 interval 2: 4231.43 um, 209.76 um/day, 209.76 um/day, start: 2022-05-11 22:48:01, end: 2022-06-01 02:56:55
# peakID_4 interval 1: 1665.05 um, 98.30 um/day, 98.30 um/day, start: 2022-04-25 00:06:20, end: 2022-05-11 22:38:33
# peakID_4 interval 0: 3476.23 um, 42.10 um/day, 42.10 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:45:09
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G717_sub_peakid.csv_peakID_1:
# peakID_1 interval 7: 1364.38 um, 29.45 um/day, 29.45 um/day, start: 2022-09-09 02:10:52, end: 2022-10-25 10:00:00
# peakID_1 interval 6: 554.95 um, 19.85 um/day, 19.85 um/day, start: 2022-08-12 02:21:47, end: 2022-09-09 01:19:02
# peakID_1 interval 5: 1142.76 um, 60.75 um/day, 60.75 um/day, start: 2022-07-24 06:10:34, end: 2022-08-12 01:39:26
# peakID_1 interval 3: 714.02 um, 26.56 um/day, 26.56 um/day, start: 2022-06-01 03:53:50, end: 2022-06-28 00:59:19
# peakID_1 interval 2: 185.03 um, 9.21 um/day, 9.21 um/day, start: 2022-05-12 00:12:07, end: 2022-06-01 02:22:53
# peakID_1 interval 1: 4523.95 um, 266.76 um/day, 266.76 um/day, start: 2022-04-25 00:02:19, end: 2022-05-11 23:02:40
# peakID_1 interval 0: 893.51 um, 10.82 um/day, 10.82 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:02:52
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G717_sub_peakid.csv_peakID_2:
# peakID_2 interval 7: 1042.92 um, 22.51 um/day, 22.51 um/day, start: 2022-09-09 02:17:18, end: 2022-10-25 10:00:00
# peakID_2 interval 6: 569.89 um, 20.38 um/day, 20.38 um/day, start: 2022-08-12 02:20:57, end: 2022-09-09 01:19:51
# peakID_2 interval 5: 1142.76 um, 60.75 um/day, 60.75 um/day, start: 2022-07-24 06:10:34, end: 2022-08-12 01:39:26
# peakID_2 interval 4: 2321.67 um, 88.67 um/day, 88.67 um/day, start: 2022-06-28 01:29:28, end: 2022-07-24 05:53:03
# peakID_2 interval 2: 2433.41 um, 120.60 um/day, 120.60 um/day, start: 2022-05-11 23:10:11, end: 2022-06-01 03:24:51
# peakID_2 interval 1: 1989.98 um, 117.37 um/day, 117.37 um/day, start: 2022-04-25 00:05:16, end: 2022-05-11 22:59:41
# peakID_2 interval 0: 893.51 um, 10.82 um/day, 10.82 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:02:52
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G717_sub_peakid.csv_peakID_3:
# peakID_3 interval 7: 1364.38 um, 29.45 um/day, 29.45 um/day, start: 2022-09-09 02:10:52, end: 2022-10-25 10:00:00
# peakID_3 interval 6: 554.95 um, 19.85 um/day, 19.85 um/day, start: 2022-08-12 02:21:47, end: 2022-09-09 01:19:02
# peakID_3 interval 5: 1142.76 um, 60.75 um/day, 60.75 um/day, start: 2022-07-24 06:10:34, end: 2022-08-12 01:39:26
# peakID_3 interval 3: 714.02 um, 26.56 um/day, 26.56 um/day, start: 2022-06-01 03:53:50, end: 2022-06-28 00:59:19
# peakID_3 interval 2: 3285.87 um, 162.84 um/day, 162.84 um/day, start: 2022-05-11 23:08:50, end: 2022-06-01 03:26:12
# peakID_3 interval 1: 1016.92 um, 60.00 um/day, 60.00 um/day, start: 2022-04-25 00:10:16, end: 2022-05-11 22:54:36
# peakID_3 interval 0: 1387.85 um, 16.81 um/day, 16.81 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:23:13
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G717_sub_peakid.csv_peakID_4:
# peakID_4 interval 7: 1364.38 um, 29.45 um/day, 29.45 um/day, start: 2022-09-09 02:10:52, end: 2022-10-25 10:00:00
# peakID_4 interval 6: 554.95 um, 19.85 um/day, 19.85 um/day, start: 2022-08-12 02:21:47, end: 2022-09-09 01:19:02
# peakID_4 interval 5: 1142.76 um, 60.75 um/day, 60.75 um/day, start: 2022-07-24 06:10:34, end: 2022-08-12 01:39:26
# peakID_4 interval 3: 714.02 um, 26.56 um/day, 26.56 um/day, start: 2022-06-01 03:53:50, end: 2022-06-28 00:59:19
# peakID_4 interval 2: 185.03 um, 9.21 um/day, 9.21 um/day, start: 2022-05-12 00:12:07, end: 2022-06-01 02:22:53
# peakID_4 interval 1: 2433.41 um, 143.52 um/day, 143.52 um/day, start: 2022-04-25 00:04:21, end: 2022-05-11 23:00:40
# peakID_4 interval 0: 3157.93 um, 38.24 um/day, 38.24 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:43:41
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G719_int_peakid.csv_peakID_1:
# peakID_1 interval 7: 1209.02 um, 26.10 um/day, 26.10 um/day, start: 2022-09-09 02:03:59, end: 2022-10-25 10:00:00
# peakID_1 interval 6: 504.41 um, 18.04 um/day, 18.04 um/day, start: 2022-08-12 01:55:03, end: 2022-09-09 01:05:18
# peakID_1 interval 4: 353.74 um, 13.53 um/day, 13.53 um/day, start: 2022-06-28 01:54:08, end: 2022-07-24 05:13:22
# peakID_1 interval 3: 2328.73 um, 86.53 um/day, 86.53 um/day, start: 2022-06-01 03:07:14, end: 2022-06-28 01:00:14
# peakID_1 interval 2: 3350.11 um, 166.08 um/day, 166.08 um/day, start: 2022-05-11 22:48:50, end: 2022-06-01 02:56:14
# peakID_1 interval 0: 4808.51 um, 58.23 um/day, 58.23 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:49:20
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G719_int_peakid.csv_peakID_2:
# peakID_2 interval 7: 837.56 um, 18.08 um/day, 18.08 um/day, start: 2022-09-09 02:14:52, end: 2022-10-25 10:00:00
# peakID_2 interval 6: 891.95 um, 31.87 um/day, 31.87 um/day, start: 2022-08-12 01:39:50, end: 2022-09-09 01:20:22
# peakID_2 interval 4: 353.74 um, 13.53 um/day, 13.53 um/day, start: 2022-06-28 01:54:08, end: 2022-07-24 05:13:22
# peakID_2 interval 3: 2328.73 um, 86.53 um/day, 86.53 um/day, start: 2022-06-01 03:07:14, end: 2022-06-28 01:00:14
# peakID_2 interval 2: 3350.11 um, 166.08 um/day, 166.08 um/day, start: 2022-05-11 22:48:50, end: 2022-06-01 02:56:14
# peakID_2 interval 0: 5353.43 um, 64.83 um/day, 64.83 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:50:25
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G719_int_peakid.csv_peakID_3:
# peakID_3 interval 7: 1209.02 um, 26.10 um/day, 26.10 um/day, start: 2022-09-09 02:03:59, end: 2022-10-25 10:00:00
# peakID_3 interval 6: 262.54 um, 9.40 um/day, 9.40 um/day, start: 2022-08-12 02:27:14, end: 2022-09-09 00:33:26
# peakID_3 interval 5: 353.74 um, 18.86 um/day, 18.86 um/day, start: 2022-07-24 06:33:28, end: 2022-08-12 00:46:32
# peakID_3 interval 4: 362.23 um, 13.86 um/day, 13.86 um/day, start: 2022-06-28 01:53:53, end: 2022-07-24 05:14:38
# peakID_3 interval 3: 1133.57 um, 42.14 um/day, 42.14 um/day, start: 2022-06-01 03:14:51, end: 2022-06-28 00:52:56
# peakID_3 interval 2: 3350.11 um, 166.08 um/day, 166.08 um/day, start: 2022-05-11 22:48:50, end: 2022-06-01 02:56:14
# peakID_3 interval 0: 4808.51 um, 58.23 um/day, 58.23 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:49:20
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G719_int_peakid.csv_peakID_4:
# peakID_4 interval 7: 2080.75 um, 44.90 um/day, 44.90 um/day, start: 2022-09-09 01:54:05, end: 2022-10-25 10:00:00
# peakID_4 interval 5: 353.74 um, 18.86 um/day, 18.86 um/day, start: 2022-07-24 06:33:28, end: 2022-08-12 00:46:32
# peakID_4 interval 4: 362.23 um, 13.86 um/day, 13.86 um/day, start: 2022-06-28 01:53:53, end: 2022-07-24 05:14:38
# peakID_4 interval 3: 1133.57 um, 42.14 um/day, 42.14 um/day, start: 2022-06-01 03:14:51, end: 2022-06-28 00:52:56
# peakID_4 interval 2: 1955.16 um, 96.94 um/day, 96.94 um/day, start: 2022-05-11 22:51:27, end: 2022-06-01 02:53:33
# peakID_4 interval 1: 614.65 um, 36.32 um/day, 36.32 um/day, start: 2022-04-25 00:17:33, end: 2022-05-11 22:27:27
# peakID_4 interval 0: 5359.90 um, 64.91 um/day, 64.91 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:50:26
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G723_sub_peakid.csv_peakID_1:
# peakID_1 interval 7: 830.78 um, 17.94 um/day, 17.94 um/day, start: 2022-09-09 02:25:35, end: 2022-10-25 10:00:00
# peakID_1 interval 6: 390.69 um, 13.98 um/day, 13.98 um/day, start: 2022-08-12 02:35:41, end: 2022-09-09 01:04:43
# peakID_1 interval 5: 344.55 um, 18.35 um/day, 18.35 um/day, start: 2022-07-24 06:34:29, end: 2022-08-12 01:15:31
# peakID_1 interval 3: 1101.10 um, 20.75 um/day, 20.75 um/day, start: 2022-06-01 04:00:36, end: 2022-07-24 05:29:25
# peakID_1 interval 2: 1991.15 um, 98.69 um/day, 98.69 um/day, start: 2022-05-11 23:11:30, end: 2022-06-01 03:23:34
# peakID_1 interval 1: 1591.01 um, 93.85 um/day, 93.85 um/day, start: 2022-04-25 00:06:44, end: 2022-05-11 22:58:10
# peakID_1 interval 0: 5876.80 um, 71.17 um/day, 71.17 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:51:15
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G723_sub_peakid.csv_peakID_2:
# peakID_2 interval 7: 500.03 um, 10.80 um/day, 10.80 um/day, start: 2022-09-09 02:46:47, end: 2022-10-25 10:00:00
# peakID_2 interval 6: 91.84 um, 3.31 um/day, 3.31 um/day, start: 2022-08-12 05:02:55, end: 2022-09-08 22:37:05
# peakID_2 interval 5: 344.55 um, 18.35 um/day, 18.35 um/day, start: 2022-07-24 06:34:29, end: 2022-08-12 01:15:31
# peakID_2 interval 3: 1101.10 um, 20.75 um/day, 20.75 um/day, start: 2022-06-01 04:00:36, end: 2022-07-24 05:29:25
# peakID_2 interval 2: 1991.15 um, 98.69 um/day, 98.69 um/day, start: 2022-05-11 23:11:30, end: 2022-06-01 03:23:34
# peakID_2 interval 1: 1591.01 um, 93.85 um/day, 93.85 um/day, start: 2022-04-25 00:06:44, end: 2022-05-11 22:58:10
# peakID_2 interval 0: 5876.80 um, 71.17 um/day, 71.17 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:51:15
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G723_sub_peakid.csv_peakID_3:
# peakID_3 interval 7: 830.78 um, 17.94 um/day, 17.94 um/day, start: 2022-09-09 02:25:35, end: 2022-10-25 10:00:00
# peakID_3 interval 6: 444.81 um, 15.92 um/day, 15.92 um/day, start: 2022-08-12 02:30:08, end: 2022-09-09 01:10:13
# peakID_3 interval 5: 1190.64 um, 63.29 um/day, 63.29 um/day, start: 2022-07-24 06:10:00, end: 2022-08-12 01:39:54
# peakID_3 interval 3: 1101.10 um, 20.75 um/day, 20.75 um/day, start: 2022-06-01 04:00:36, end: 2022-07-24 05:29:25
# peakID_3 interval 2: 1991.15 um, 98.69 um/day, 98.69 um/day, start: 2022-05-11 23:11:30, end: 2022-06-01 03:23:34
# peakID_3 interval 1: 1591.01 um, 93.85 um/day, 93.85 um/day, start: 2022-04-25 00:06:44, end: 2022-05-11 22:58:10
# peakID_3 interval 0: 5876.80 um, 71.17 um/day, 71.17 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:51:15
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G723_sub_peakid.csv_peakID_4:
# peakID_4 interval 7: 830.78 um, 17.94 um/day, 17.94 um/day, start: 2022-09-09 02:25:35, end: 2022-10-25 10:00:00
# peakID_4 interval 6: 444.81 um, 15.92 um/day, 15.92 um/day, start: 2022-08-12 02:30:08, end: 2022-09-09 01:10:13
# peakID_4 interval 5: 1190.64 um, 63.29 um/day, 63.29 um/day, start: 2022-07-24 06:10:00, end: 2022-08-12 01:39:54
# peakID_4 interval 3: 1101.10 um, 20.75 um/day, 20.75 um/day, start: 2022-06-01 04:00:36, end: 2022-07-24 05:29:25
# peakID_4 interval 2: 1992.04 um, 98.74 um/day, 98.74 um/day, start: 2022-05-11 23:11:30, end: 2022-06-01 03:23:34
# peakID_4 interval 1: 1585.22 um, 93.51 um/day, 93.51 um/day, start: 2022-04-25 00:06:46, end: 2022-05-11 22:58:08
# peakID_4 interval 0: 5876.80 um, 71.17 um/day, 71.17 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:51:15
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G728_int_peakid.csv_peakID_1:
# peakID_1 interval 7: 873.59 um, 18.86 um/day, 18.86 um/day, start: 2022-09-09 02:13:11, end: 2022-10-25 10:00:00
# peakID_1 interval 6: 848.01 um, 30.30 um/day, 30.30 um/day, start: 2022-08-12 01:41:12, end: 2022-09-09 01:19:21
# peakID_1 interval 5: 319.50 um, 17.04 um/day, 17.04 um/day, start: 2022-07-24 06:36:42, end: 2022-08-12 00:43:18
# peakID_1 interval 4: 1130.94 um, 43.19 um/day, 43.19 um/day, start: 2022-06-28 01:22:07, end: 2022-07-24 05:45:32
# peakID_1 interval 3: 2937.27 um, 109.14 um/day, 109.14 um/day, start: 2022-06-01 03:05:46, end: 2022-06-28 01:01:48
# peakID_1 interval 2: 2717.86 um, 134.74 um/day, 134.74 um/day, start: 2022-05-11 22:49:38, end: 2022-06-01 02:55:20
# peakID_1 interval 1: 566.09 um, 33.45 um/day, 33.45 um/day, start: 2022-04-25 00:18:23, end: 2022-05-11 22:26:19
# peakID_1 interval 0: 9362.57 um, 113.38 um/day, 113.38 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:54:35
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G728_int_peakid.csv_peakID_2:
# peakID_2 interval 7: 873.59 um, 18.86 um/day, 18.86 um/day, start: 2022-09-09 02:13:11, end: 2022-10-25 10:00:00
# peakID_2 interval 5: 1450.30 um, 30.99 um/day, 30.99 um/day, start: 2022-07-24 06:20:10, end: 2022-09-09 01:19:49
# peakID_2 interval 4: 1130.94 um, 43.19 um/day, 43.19 um/day, start: 2022-06-28 01:22:07, end: 2022-07-24 05:45:32
# peakID_2 interval 3: 2937.27 um, 109.14 um/day, 109.14 um/day, start: 2022-06-01 03:05:46, end: 2022-06-28 01:01:48
# peakID_2 interval 2: 2717.86 um, 134.74 um/day, 134.74 um/day, start: 2022-05-11 22:49:38, end: 2022-06-01 02:55:20
# peakID_2 interval 1: 566.09 um, 33.45 um/day, 33.45 um/day, start: 2022-04-25 00:18:23, end: 2022-05-11 22:26:19
# peakID_2 interval 0: 9362.57 um, 113.38 um/day, 113.38 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:54:35
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G728_int_peakid.csv_peakID_3:
# peakID_3 interval 7: 873.59 um, 18.86 um/day, 18.86 um/day, start: 2022-09-09 02:13:11, end: 2022-10-25 10:00:00
# peakID_3 interval 5: 1452.04 um, 31.03 um/day, 31.03 um/day, start: 2022-07-24 06:20:09, end: 2022-09-09 01:19:50
# peakID_3 interval 4: 1357.97 um, 51.86 um/day, 51.86 um/day, start: 2022-06-28 01:19:41, end: 2022-07-24 05:47:57
# peakID_3 interval 3: 847.54 um, 31.51 um/day, 31.51 um/day, start: 2022-06-01 03:19:43, end: 2022-06-28 00:47:47
# peakID_3 interval 2: 1288.01 um, 63.88 um/day, 63.88 um/day, start: 2022-05-11 22:54:51, end: 2022-06-01 02:50:12
# peakID_3 interval 1: 2717.86 um, 160.42 um/day, 160.42 um/day, start: 2022-04-25 00:03:54, end: 2022-05-11 22:41:05
# peakID_3 interval 0: 10356.40 um, 125.41 um/day, 125.41 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:55:01
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G728_int_peakid.csv_peakID_4:
# peakID_4 interval 7: 873.59 um, 18.86 um/day, 18.86 um/day, start: 2022-09-09 02:13:11, end: 2022-10-25 10:00:00
# peakID_4 interval 6: 848.01 um, 30.30 um/day, 30.30 um/day, start: 2022-08-12 01:41:12, end: 2022-09-09 01:19:21
# peakID_4 interval 5: 321.24 um, 17.13 um/day, 17.13 um/day, start: 2022-07-24 06:36:30, end: 2022-08-12 00:43:30
# peakID_4 interval 4: 1357.97 um, 51.86 um/day, 51.86 um/day, start: 2022-06-28 01:19:41, end: 2022-07-24 05:47:57
# peakID_4 interval 3: 2937.27 um, 109.14 um/day, 109.14 um/day, start: 2022-06-01 03:05:46, end: 2022-06-28 01:01:48
# peakID_4 interval 2: 2717.86 um, 134.74 um/day, 134.74 um/day, start: 2022-05-11 22:49:38, end: 2022-06-01 02:55:20
# peakID_4 interval 1: 566.09 um, 33.45 um/day, 33.45 um/day, start: 2022-04-25 00:18:23, end: 2022-05-11 22:26:19
# peakID_4 interval 0: 9362.57 um, 113.38 um/day, 113.38 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:54:35
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G730_sub_peakid.csv_peakID_1:
# peakID_1 interval 7: 282.52 um, 6.11 um/day, 6.11 um/day, start: 2022-09-09 03:34:55, end: 2022-10-25 10:00:00
# peakID_1 interval 6: 1183.32 um, 42.29 um/day, 42.29 um/day, start: 2022-08-12 02:04:36, end: 2022-09-09 01:34:51
# peakID_1 interval 4: 379.57 um, 8.45 um/day, 8.45 um/day, start: 2022-06-28 02:35:07, end: 2022-08-12 00:36:54
# peakID_1 interval 3: 2073.73 um, 77.09 um/day, 77.09 um/day, start: 2022-06-01 03:38:05, end: 2022-06-28 01:14:32
# peakID_1 interval 2: 1676.69 um, 83.11 um/day, 83.11 um/day, start: 2022-05-11 23:12:27, end: 2022-06-01 03:22:22
# peakID_1 interval 1: 1460.87 um, 86.18 um/day, 86.18 um/day, start: 2022-04-25 00:07:11, end: 2022-05-11 22:57:49
# peakID_1 interval 0: 6167.98 um, 74.69 um/day, 74.69 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:51:45
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G730_sub_peakid.csv_peakID_2:
# peakID_2 interval 7: 317.67 um, 6.86 um/day, 6.86 um/day, start: 2022-09-09 03:23:20, end: 2022-10-25 10:00:00
# peakID_2 interval 6: 1052.07 um, 37.61 um/day, 37.61 um/day, start: 2022-08-12 02:06:25, end: 2022-09-09 01:32:58
# peakID_2 interval 4: 2628.45 um, 58.40 um/day, 58.40 um/day, start: 2022-06-28 01:33:11, end: 2022-08-12 01:39:25
# peakID_2 interval 3: 1676.69 um, 62.34 um/day, 62.34 um/day, start: 2022-06-01 03:39:55, end: 2022-06-28 01:12:19
# peakID_2 interval 1: 831.17 um, 49.05 um/day, 49.05 um/day, start: 2022-04-25 00:12:37, end: 2022-05-11 22:52:23
# peakID_2 interval 0: 6167.98 um, 74.69 um/day, 74.69 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:51:45
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G730_sub_peakid.csv_peakID_3:
# peakID_3 interval 7: 282.52 um, 6.11 um/day, 6.11 um/day, start: 2022-09-09 03:34:55, end: 2022-10-25 10:00:00
# peakID_3 interval 6: 1183.32 um, 42.29 um/day, 42.29 um/day, start: 2022-08-12 02:04:36, end: 2022-09-09 01:34:51
# peakID_3 interval 4: 379.57 um, 8.45 um/day, 8.45 um/day, start: 2022-06-28 02:35:07, end: 2022-08-12 00:36:54
# peakID_3 interval 3: 2073.73 um, 77.09 um/day, 77.09 um/day, start: 2022-06-01 03:38:05, end: 2022-06-28 01:14:32
# peakID_3 interval 2: 1676.69 um, 83.11 um/day, 83.11 um/day, start: 2022-05-11 23:12:27, end: 2022-06-01 03:22:22
# peakID_3 interval 0: 7999.27 um, 96.87 um/day, 96.87 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:53:37
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G730_sub_peakid.csv_peakID_4:
# peakID_4 interval 7: 1565.95 um, 33.80 um/day, 33.80 um/day, start: 2022-09-09 02:08:16, end: 2022-10-25 10:00:00
# peakID_4 interval 5: 379.57 um, 8.12 um/day, 8.12 um/day, start: 2022-07-24 07:15:32, end: 2022-09-09 00:33:58
# peakID_4 interval 4: 2094.94 um, 80.01 um/day, 80.01 um/day, start: 2022-06-28 01:30:18, end: 2022-07-24 05:52:20
# peakID_4 interval 3: 1655.52 um, 61.55 um/day, 61.55 um/day, start: 2022-06-01 03:40:03, end: 2022-06-28 01:12:11
# peakID_4 interval 1: 831.17 um, 49.05 um/day, 49.05 um/day, start: 2022-04-25 00:12:37, end: 2022-05-11 22:52:23
# peakID_4 interval 0: 6167.98 um, 74.69 um/day, 74.69 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:51:45
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G732_sub_peakid.csv_peakID_1:
# peakID_1 interval 7: 1509.02 um, 32.57 um/day, 32.57 um/day, start: 2022-09-09 02:09:07, end: 2022-10-25 10:00:00
# peakID_1 interval 6: 599.38 um, 21.44 um/day, 21.44 um/day, start: 2022-08-12 02:18:41, end: 2022-09-09 01:20:57
# peakID_1 interval 5: 385.54 um, 20.52 um/day, 20.52 um/day, start: 2022-07-24 06:30:01, end: 2022-08-12 01:20:03
# peakID_1 interval 4: 789.87 um, 30.19 um/day, 30.19 um/day, start: 2022-06-28 01:42:51, end: 2022-07-24 05:39:35
# peakID_1 interval 3: 937.62 um, 34.87 um/day, 34.87 um/day, start: 2022-06-01 03:47:32, end: 2022-06-28 01:04:47
# peakID_1 interval 2: 1715.99 um, 85.06 um/day, 85.06 um/day, start: 2022-05-11 23:12:12, end: 2022-06-01 03:22:42
# peakID_1 interval 1: 5074.56 um, 299.23 um/day, 299.23 um/day, start: 2022-04-25 00:02:05, end: 2022-05-11 23:02:55
# peakID_1 interval 0: 2898.30 um, 35.10 um/day, 35.10 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:42:14
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G732_sub_peakid.csv_peakID_2:
# peakID_2 interval 7: 1509.02 um, 32.57 um/day, 32.57 um/day, start: 2022-09-09 02:09:07, end: 2022-10-25 10:00:00
# peakID_2 interval 6: 1085.67 um, 38.80 um/day, 38.80 um/day, start: 2022-08-12 02:05:53, end: 2022-09-09 01:33:57
# peakID_2 interval 5: 789.87 um, 42.00 um/day, 42.00 um/day, start: 2022-07-24 06:14:38, end: 2022-08-12 01:35:20
# peakID_2 interval 4: 937.62 um, 35.83 um/day, 35.83 um/day, start: 2022-06-28 01:39:34, end: 2022-07-24 05:42:45
# peakID_2 interval 3: 1715.99 um, 63.80 um/day, 63.80 um/day, start: 2022-06-01 03:39:36, end: 2022-06-28 01:12:46
# peakID_2 interval 2: 5074.56 um, 251.46 um/day, 251.46 um/day, start: 2022-05-11 23:07:29, end: 2022-06-01 03:27:32
# peakID_2 interval 0: 2040.51 um, 24.71 um/day, 24.71 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:34:45
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G732_sub_peakid.csv_peakID_3:
# peakID_3 interval 7: 1509.02 um, 32.57 um/day, 32.57 um/day, start: 2022-09-09 02:09:07, end: 2022-10-25 10:00:00
# peakID_3 interval 6: 599.38 um, 21.44 um/day, 21.44 um/day, start: 2022-08-12 02:18:41, end: 2022-09-09 01:20:57
# peakID_3 interval 5: 385.54 um, 20.52 um/day, 20.52 um/day, start: 2022-07-24 06:30:01, end: 2022-08-12 01:20:03
# peakID_3 interval 4: 789.87 um, 30.19 um/day, 30.19 um/day, start: 2022-06-28 01:42:51, end: 2022-07-24 05:39:35
# peakID_3 interval 3: 937.62 um, 34.87 um/day, 34.87 um/day, start: 2022-06-01 03:47:32, end: 2022-06-28 01:04:47
# peakID_3 interval 2: 1715.99 um, 85.06 um/day, 85.06 um/day, start: 2022-05-11 23:12:12, end: 2022-06-01 03:22:42
# peakID_3 interval 1: 1507.54 um, 88.93 um/day, 88.93 um/day, start: 2022-04-25 00:06:56, end: 2022-05-11 22:58:01
# peakID_3 interval 0: 6438.68 um, 77.97 um/day, 77.97 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:52:00
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G732_sub_peakid.csv_peakID_4:
# peakID_4 interval 7: 1509.02 um, 32.57 um/day, 32.57 um/day, start: 2022-09-09 02:09:07, end: 2022-10-25 10:00:00
# peakID_4 interval 6: 599.38 um, 21.44 um/day, 21.44 um/day, start: 2022-08-12 02:18:41, end: 2022-09-09 01:20:57
# peakID_4 interval 5: 385.54 um, 20.52 um/day, 20.52 um/day, start: 2022-07-24 06:30:01, end: 2022-08-12 01:20:03
# peakID_4 interval 4: 789.87 um, 30.19 um/day, 30.19 um/day, start: 2022-06-28 01:42:51, end: 2022-07-24 05:39:35
# peakID_4 interval 3: 937.62 um, 34.87 um/day, 34.87 um/day, start: 2022-06-01 03:47:32, end: 2022-06-28 01:04:47
# peakID_4 interval 2: 1715.99 um, 85.06 um/day, 85.06 um/day, start: 2022-05-11 23:12:12, end: 2022-06-01 03:22:42
# ...
# peakID_3 interval 2: 1595.20 um, 79.08 um/day, 79.08 um/day, start: 2022-05-11 23:12:53, end: 2022-06-01 03:21:54
# peakID_3 interval 0: 7320.74 um, 88.65 um/day, 88.65 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:52:53
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G753_sub_peakid.csv_peakID_4:
# peakID_4 interval 7: 293.50 um, 6.34 um/day, 6.34 um/day, start: 2022-09-09 03:29:18, end: 2022-10-25 10:00:00
# peakID_4 interval 6: 177.87 um, 6.38 um/day, 6.38 um/day, start: 2022-08-12 03:26:55, end: 2022-09-09 00:13:05
# peakID_4 interval 5: 1381.37 um, 73.42 um/day, 73.42 um/day, start: 2022-07-24 06:08:35, end: 2022-08-12 01:41:14
# peakID_4 interval 4: 3019.59 um, 115.32 um/day, 115.32 um/day, start: 2022-06-28 01:28:03, end: 2022-07-24 05:54:32
# peakID_4 interval 3: 1595.20 um, 59.31 um/day, 59.31 um/day, start: 2022-06-01 03:40:31, end: 2022-06-28 01:11:42
# peakID_4 interval 1: 4241.93 um, 250.14 um/day, 250.14 um/day, start: 2022-04-25 00:02:31, end: 2022-05-11 23:02:29
# peakID_4 interval 0: 2078.34 um, 25.17 um/day, 25.17 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:35:20
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G767_sub_peakid.csv_peakID_1:
# peakID_1 interval 7: 347.22 um, 7.50 um/day, 7.50 um/day, start: 2022-09-09 03:14:54, end: 2022-10-25 10:00:00
# peakID_1 interval 6: 666.11 um, 23.82 um/day, 23.82 um/day, start: 2022-08-12 02:16:22, end: 2022-09-09 01:23:16
# peakID_1 interval 5: 1284.37 um, 68.27 um/day, 68.27 um/day, start: 2022-07-24 06:09:02, end: 2022-08-12 01:40:34
# peakID_1 interval 3: 1498.42 um, 55.71 um/day, 55.71 um/day, start: 2022-06-01 03:41:19, end: 2022-06-28 01:11:27
# peakID_1 interval 2: 1605.61 um, 79.59 um/day, 79.59 um/day, start: 2022-05-11 23:12:48, end: 2022-06-01 03:22:05
# peakID_1 interval 1: 2768.78 um, 163.29 um/day, 163.29 um/day, start: 2022-04-25 00:03:54, end: 2022-05-11 23:01:12
# peakID_1 interval 0: 2284.47 um, 27.67 um/day, 27.67 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:37:14
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G767_sub_peakid.csv_peakID_2:
# peakID_2 interval 7: 347.22 um, 7.50 um/day, 7.50 um/day, start: 2022-09-09 03:14:54, end: 2022-10-25 10:00:00
# peakID_2 interval 6: 666.11 um, 23.82 um/day, 23.82 um/day, start: 2022-08-12 02:16:22, end: 2022-09-09 01:23:16
# peakID_2 interval 5: 1284.37 um, 68.27 um/day, 68.27 um/day, start: 2022-07-24 06:09:02, end: 2022-08-12 01:40:34
# peakID_2 interval 3: 1498.42 um, 55.71 um/day, 55.71 um/day, start: 2022-06-01 03:41:19, end: 2022-06-28 01:11:27
# peakID_2 interval 2: 1605.61 um, 79.59 um/day, 79.59 um/day, start: 2022-05-11 23:12:48, end: 2022-06-01 03:22:05
# peakID_2 interval 1: 2768.78 um, 163.29 um/day, 163.29 um/day, start: 2022-04-25 00:03:54, end: 2022-05-11 23:01:12
# peakID_2 interval 0: 2284.47 um, 27.67 um/day, 27.67 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:37:14
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G767_sub_peakid.csv_peakID_3:
# peakID_3 interval 7: 347.22 um, 7.50 um/day, 7.50 um/day, start: 2022-09-09 03:14:54, end: 2022-10-25 10:00:00
# peakID_3 interval 6: 666.11 um, 23.82 um/day, 23.82 um/day, start: 2022-08-12 02:16:22, end: 2022-09-09 01:23:16
# peakID_3 interval 5: 1284.37 um, 68.27 um/day, 68.27 um/day, start: 2022-07-24 06:09:02, end: 2022-08-12 01:40:34
# peakID_3 interval 3: 1720.31 um, 63.96 um/day, 63.96 um/day, start: 2022-06-01 03:39:51, end: 2022-06-28 01:12:52
# peakID_3 interval 2: 284.58 um, 14.14 um/day, 14.14 um/day, start: 2022-05-11 23:48:55, end: 2022-06-01 02:44:52
# peakID_3 interval 1: 427.22 um, 25.24 um/day, 25.24 um/day, start: 2022-04-25 00:24:57, end: 2022-05-11 22:40:03
# peakID_3 interval 0: 4115.74 um, 49.84 um/day, 49.84 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:47:26
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G767_sub_peakid.csv_peakID_4:
# peakID_4 interval 7: 347.22 um, 7.50 um/day, 7.50 um/day, start: 2022-09-09 03:14:54, end: 2022-10-25 10:00:00
# peakID_4 interval 6: 666.11 um, 23.82 um/day, 23.82 um/day, start: 2022-08-12 02:16:22, end: 2022-09-09 01:23:16
# peakID_4 interval 5: 1284.37 um, 68.27 um/day, 68.27 um/day, start: 2022-07-24 06:09:02, end: 2022-08-12 01:40:34
# peakID_4 interval 3: 1498.42 um, 55.71 um/day, 55.71 um/day, start: 2022-06-01 03:41:19, end: 2022-06-28 01:11:27
# peakID_4 interval 2: 1605.61 um, 79.59 um/day, 79.59 um/day, start: 2022-05-11 23:12:48, end: 2022-06-01 03:22:05
# peakID_4 interval 1: 2768.78 um, 163.29 um/day, 163.29 um/day, start: 2022-04-25 00:03:54, end: 2022-05-11 23:01:12
# peakID_4 interval 0: 2284.47 um, 27.67 um/day, 27.67 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:37:14
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G770_sub_peakid.csv_peakID_1:
# peakID_1 interval 7: 74.59 um, 1.62 um/day, 1.62 um/day, start: 2022-09-09 08:11:19, end: 2022-10-25 10:00:00
# peakID_1 interval 6: 928.53 um, 33.19 um/day, 33.19 um/day, start: 2022-08-12 02:08:44, end: 2022-09-09 01:31:24
# peakID_1 interval 5: 270.65 um, 14.42 um/day, 14.42 um/day, start: 2022-07-24 06:43:06, end: 2022-08-12 01:06:54
# peakID_1 interval 4: 650.08 um, 24.85 um/day, 24.85 um/day, start: 2022-06-28 01:48:26, end: 2022-07-24 05:34:06
# peakID_1 interval 3: 907.02 um, 33.74 um/day, 33.74 um/day, start: 2022-06-01 03:48:24, end: 2022-06-28 01:04:06
# peakID_1 interval 2: 1367.83 um, 67.81 um/day, 67.81 um/day, start: 2022-05-11 23:14:11, end: 2022-06-01 03:20:51
# peakID_1 interval 1: 3453.01 um, 203.63 um/day, 203.63 um/day, start: 2022-04-25 00:03:07, end: 2022-05-11 23:01:56
# peakID_1 interval 0: 4239.34 um, 51.34 um/day, 51.34 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:47:38
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G770_sub_peakid.csv_peakID_2:
# peakID_2 interval 7: 74.59 um, 1.62 um/day, 1.62 um/day, start: 2022-09-09 08:11:19, end: 2022-10-25 10:00:00
# peakID_2 interval 6: 3351.49 um, 119.73 um/day, 119.73 um/day, start: 2022-08-12 01:55:23, end: 2022-09-09 01:44:51
# peakID_2 interval 3: 907.02 um, 17.10 um/day, 17.10 um/day, start: 2022-06-01 04:06:18, end: 2022-07-24 05:23:42
# peakID_2 interval 2: 1367.83 um, 67.81 um/day, 67.81 um/day, start: 2022-05-11 23:14:11, end: 2022-06-01 03:20:51
# peakID_2 interval 1: 3453.01 um, 203.63 um/day, 203.63 um/day, start: 2022-04-25 00:03:07, end: 2022-05-11 23:01:56
# peakID_2 interval 0: 4239.34 um, 51.34 um/day, 51.34 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:47:38
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G770_sub_peakid.csv_peakID_3:
# peakID_3 interval 7: 331.78 um, 7.17 um/day, 7.17 um/day, start: 2022-09-09 03:16:06, end: 2022-10-25 10:00:00
# peakID_3 interval 6: 1204.75 um, 43.06 um/day, 43.06 um/day, start: 2022-08-12 02:04:26, end: 2022-09-09 01:35:30
# peakID_3 interval 5: 650.08 um, 34.58 um/day, 34.58 um/day, start: 2022-07-24 06:18:39, end: 2022-08-12 01:31:23
# peakID_3 interval 3: 129.27 um, 2.45 um/day, 2.45 um/day, start: 2022-06-01 07:43:13, end: 2022-07-24 01:46:47
# peakID_3 interval 2: 189.16 um, 9.41 um/day, 9.41 um/day, start: 2022-05-12 00:10:54, end: 2022-06-01 02:24:06
# peakID_3 interval 1: 1313.50 um, 77.49 um/day, 77.49 um/day, start: 2022-04-25 00:08:09, end: 2022-05-11 22:57:00
# peakID_3 interval 0: 8177.09 um, 99.02 um/day, 99.02 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:53:42
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G770_sub_peakid.csv_peakID_4:
# peakID_4 interval 7: 1636.95 um, 35.33 um/day, 35.33 um/day, start: 2022-09-09 02:07:36, end: 2022-10-25 10:00:00
# peakID_4 interval 6: 650.08 um, 23.25 um/day, 23.25 um/day, start: 2022-08-12 02:17:44, end: 2022-09-09 01:22:19
# peakID_4 interval 4: 129.27 um, 2.89 um/day, 2.89 um/day, start: 2022-06-28 04:57:10, end: 2022-08-11 22:15:20
# peakID_4 interval 3: 189.16 um, 7.06 um/day, 7.06 um/day, start: 2022-06-01 04:57:52, end: 2022-06-27 23:54:38
# peakID_4 interval 2: 1056.98 um, 52.41 um/day, 52.41 um/day, start: 2022-05-11 23:17:03, end: 2022-06-01 03:18:10
# peakID_4 interval 1: 2955.37 um, 174.29 um/day, 174.29 um/day, start: 2022-04-25 00:03:38, end: 2022-05-11 23:01:23
# peakID_4 interval 0: 4239.34 um, 51.34 um/day, 51.34 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:47:38
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G779_int_peakid.csv_peakID_1:
# peakID_1 interval 7: 1589.19 um, 34.30 um/day, 34.30 um/day, start: 2022-09-09 01:58:01, end: 2022-10-25 10:00:00
# peakID_1 interval 6: 244.67 um, 8.77 um/day, 8.77 um/day, start: 2022-08-12 02:32:18, end: 2022-09-09 00:27:42
# peakID_1 interval 5: 1034.12 um, 55.04 um/day, 55.04 um/day, start: 2022-07-24 06:11:24, end: 2022-08-12 01:08:40
# peakID_1 interval 3: 4300.91 um, 80.97 um/day, 80.97 um/day, start: 2022-06-01 03:07:34, end: 2022-07-24 05:52:08
# peakID_1 interval 2: 2857.74 um, 141.68 um/day, 141.68 um/day, start: 2022-05-11 22:49:27, end: 2022-06-01 02:55:40
# peakID_1 interval 1: 2993.25 um, 176.67 um/day, 176.67 um/day, start: 2022-04-25 00:03:36, end: 2022-05-11 22:41:26
# peakID_1 interval 0: 681.92 um, 8.26 um/day, 8.26 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 22:43:55
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G779_int_peakid.csv_peakID_2:
# peakID_2 interval 7: 103.72 um, 2.25 um/day, 2.25 um/day, start: 2022-09-09 06:24:00, end: 2022-10-25 10:00:00
# peakID_2 interval 6: 1384.84 um, 49.47 um/day, 49.47 um/day, start: 2022-08-12 01:32:30, end: 2022-09-09 01:27:06
# peakID_2 interval 5: 1379.17 um, 73.39 um/day, 73.39 um/day, start: 2022-07-24 06:08:33, end: 2022-08-12 01:11:22
# peakID_2 interval 3: 2365.11 um, 44.54 um/day, 44.54 um/day, start: 2022-06-01 03:14:22, end: 2022-07-24 05:45:42
# peakID_2 interval 2: 1704.96 um, 84.54 um/day, 84.54 um/day, start: 2022-05-11 22:52:15, end: 2022-06-01 02:52:36
# peakID_2 interval 1: 1334.57 um, 78.80 um/day, 78.80 um/day, start: 2022-04-25 00:07:48, end: 2022-05-11 22:37:13
# peakID_2 interval 0: 5121.65 um, 62.02 um/day, 62.02 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:49:44
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G779_int_peakid.csv_peakID_3:
# peakID_3 interval 7: 103.72 um, 2.25 um/day, 2.25 um/day, start: 2022-09-09 06:24:00, end: 2022-10-25 10:00:00
# peakID_3 interval 6: 1340.64 um, 47.89 um/day, 47.89 um/day, start: 2022-08-12 01:32:54, end: 2022-09-09 01:26:40
# peakID_3 interval 5: 635.97 um, 33.86 um/day, 33.86 um/day, start: 2022-07-24 06:18:43, end: 2022-08-12 01:01:45
# peakID_3 interval 4: 1034.12 um, 39.50 um/day, 39.50 um/day, start: 2022-06-28 01:23:24, end: 2022-07-24 05:44:13
# peakID_3 interval 2: 2365.11 um, 50.23 um/day, 50.23 um/day, start: 2022-05-11 22:57:44, end: 2022-06-28 00:54:49
# peakID_3 interval 1: 1704.96 um, 100.65 um/day, 100.65 um/day, start: 2022-04-25 00:06:06, end: 2022-05-11 22:38:47
# peakID_3 interval 0: 7456.54 um, 90.30 um/day, 90.30 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:53:12
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G779_int_peakid.csv_peakID_4:
# peakID_4 interval 7: 1544.99 um, 33.34 um/day, 33.34 um/day, start: 2022-09-09 01:58:32, end: 2022-10-25 10:00:00
# peakID_4 interval 6: 635.97 um, 22.73 um/day, 22.73 um/day, start: 2022-08-12 01:47:52, end: 2022-09-09 01:12:49
# peakID_4 interval 5: 1034.12 um, 55.04 um/day, 55.04 um/day, start: 2022-07-24 06:11:24, end: 2022-08-12 01:08:40
# peakID_4 interval 3: 3147.51 um, 59.26 um/day, 59.26 um/day, start: 2022-06-01 03:10:50, end: 2022-07-24 05:49:15
# peakID_4 interval 2: 1052.56 um, 52.21 um/day, 52.21 um/day, start: 2022-05-11 22:56:45, end: 2022-06-01 02:47:42
# peakID_4 interval 1: 2857.74 um, 168.67 um/day, 168.67 um/day, start: 2022-04-25 00:03:45, end: 2022-05-11 22:41:22
# peakID_4 interval 0: 4498.42 um, 54.48 um/day, 54.48 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:48:25
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G781_sub_peakid.csv_peakID_1:
# peakID_1 interval 7: 925.76 um, 19.99 um/day, 19.99 um/day, start: 2022-09-09 02:21:21, end: 2022-10-25 10:00:00
# peakID_1 interval 6: 2607.76 um, 93.16 um/day, 93.16 um/day, start: 2022-08-12 01:56:37, end: 2022-09-09 01:43:21
# peakID_1 interval 5: 22.68 um, 1.25 um/day, 1.25 um/day, start: 2022-07-24 14:12:55, end: 2022-08-11 17:37:05
# peakID_1 interval 4: 1353.34 um, 51.70 um/day, 51.70 um/day, start: 2022-06-28 01:34:53, end: 2022-07-24 05:48:06
# peakID_1 interval 2: 1800.11 um, 38.24 um/day, 38.24 um/day, start: 2022-05-11 23:21:11, end: 2022-06-28 01:05:45
# peakID_1 interval 1: 4839.92 um, 285.39 um/day, 285.39 um/day, start: 2022-04-25 00:02:11, end: 2022-05-11 23:02:48
# peakID_1 interval 0: 2868.42 um, 34.74 um/day, 34.74 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:42:00
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G781_sub_peakid.csv_peakID_2:
# peakID_2 interval 7: 925.76 um, 19.99 um/day, 19.99 um/day, start: 2022-09-09 02:21:21, end: 2022-10-25 10:00:00
# peakID_2 interval 6: 812.37 um, 29.04 um/day, 29.04 um/day, start: 2022-08-12 02:11:11, end: 2022-09-09 01:28:39
# peakID_2 interval 5: 1953.95 um, 103.83 um/day, 103.83 um/day, start: 2022-07-24 06:05:56, end: 2022-08-12 01:44:05
# peakID_2 interval 4: 1353.34 um, 51.70 um/day, 51.70 um/day, start: 2022-06-28 01:34:53, end: 2022-07-24 05:48:06
# peakID_2 interval 2: 2067.91 um, 43.93 um/day, 43.93 um/day, start: 2022-05-11 23:19:18, end: 2022-06-28 01:07:55
# peakID_2 interval 1: 4939.85 um, 291.28 um/day, 291.28 um/day, start: 2022-04-25 00:02:09, end: 2022-05-11 23:02:51
# peakID_2 interval 0: 2868.42 um, 34.74 um/day, 34.74 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:42:00
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G781_sub_peakid.csv_peakID_3:
# peakID_3 interval 7: 925.76 um, 19.99 um/day, 19.99 um/day, start: 2022-09-09 02:21:21, end: 2022-10-25 10:00:00
# peakID_3 interval 6: 812.37 um, 29.04 um/day, 29.04 um/day, start: 2022-08-12 02:11:11, end: 2022-09-09 01:28:39
# peakID_3 interval 5: 1695.01 um, 90.08 um/day, 90.08 um/day, start: 2022-07-24 06:06:51, end: 2022-08-12 01:43:10
# peakID_3 interval 4: 22.68 um, 0.90 um/day, 0.90 um/day, start: 2022-06-28 12:48:16, end: 2022-07-23 18:34:14
# peakID_3 interval 3: 1353.34 um, 50.32 um/day, 50.32 um/day, start: 2022-06-01 03:42:44, end: 2022-06-28 01:10:16
# peakID_3 interval 1: 1800.11 um, 48.48 um/day, 48.48 um/day, start: 2022-04-25 00:12:46, end: 2022-06-01 03:16:47
# peakID_3 interval 0: 7822.07 um, 94.72 um/day, 94.72 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:53:22
# ----------------------------------------
# Total growth, growth rate, and dates for intervals in G781_sub_peakid.csv_peakID_4:
# peakID_4 interval 7: 925.76 um, 19.99 um/day, 19.99 um/day, start: 2022-09-09 02:21:21, end: 2022-10-25 10:00:00
# peakID_4 interval 6: 2607.76 um, 93.16 um/day, 93.16 um/day, start: 2022-08-12 01:56:37, end: 2022-09-09 01:43:21
# peakID_4 interval 5: 22.68 um, 1.25 um/day, 1.25 um/day, start: 2022-07-24 14:12:55, end: 2022-08-11 17:37:05
# peakID_4 interval 4: 1353.34 um, 51.70 um/day, 51.70 um/day, start: 2022-06-28 01:34:53, end: 2022-07-24 05:48:06
# peakID_4 interval 2: 1800.11 um, 38.24 um/day, 38.24 um/day, start: 2022-05-11 23:21:11, end: 2022-06-28 01:05:45
# peakID_4 interval 1: 698.60 um, 41.24 um/day, 41.24 um/day, start: 2022-04-25 00:15:31, end: 2022-05-11 22:49:46
# peakID_4 interval 0: 6435.53 um, 77.93 um/day, 77.93 um/day, start: 2022-02-01 10:00:00, end: 2022-04-24 23:51:50
# ----------------------------------------

# %% [markdown]
# ### Add growth rate info as columns to the dataframes

# %%
# Add growth rate info as columns to each dataframe and save to a new folder in the main directory
output_folder = "TE_data_with_growth_rates"
os.makedirs(output_folder, exist_ok=True)

for file, df in dataframes.items():
    # Loop through each peak identification option
    for peakID_col in ['peakID_1', 'peakID_2', 'peakID_3', 'peakID_4']:
        growths = growth_intervals.get(file + "_" + peakID_col, {})
        # Create columns for growth rate and centered growth rate, default NaN
        df['interval_growth_rate' + '_' + peakID_col] = np.nan
        df['interval_growth_rate_centered' + '_' + peakID_col] = np.nan
        df['interval_total_growth' + '_' + peakID_col] = np.nan
        df['interval_total_growth_centered' + '_' + peakID_col] = np.nan
        df['interval_total_time_days' + '_' + peakID_col] = np.nan

        # Assign growth rate info to interval rows
        for interval_label, stats in growths.items():
            mask = df[peakID_col] == interval_label
            df.loc[mask, 'interval_growth_rate' + '_' + peakID_col] = stats.get('growth_rate', np.nan)
            df.loc[mask, 'interval_growth_rate_centered' + '_' + peakID_col] = stats.get('growth_rate_centered', np.nan)
            df.loc[mask, 'interval_total_growth' + '_' + peakID_col] = stats.get('total_growth', np.nan)
            df.loc[mask, 'interval_total_growth_centered' + '_' + peakID_col] = stats.get('total_growth_centered', np.nan)
            df.loc[mask, 'interval_total_time_days' + '_' + peakID_col] = stats.get('total_time_days', np.nan)

    # Save the updated dataframe to the new folder in the main directory
    output_path = os.path.join(output_folder, file)
    df.to_csv(output_path, index=False)

# %% [markdown]
# ### Extract mean statistics of growth per interval

# %%
# Calculate and print mean growth rate, interval length, and mean date for each interval across all specimen_peakIDs
interval_means = {}
interval_centered_means = {}
interval_lengths = {}
interval_dates = {}

# Define labels as the list of specimen_peakID names combined with peakID columns
labels = list(growth_intervals.keys())

# Automatically determine the interval numbers from the interval labels
interval_numbers = sorted(
    set(
        int(label.split()[-1])
        for growths in growth_intervals.values()
        for label in growths.keys()
        if label.startswith('interval')
    )
)

for i in interval_numbers:
    interval = f'interval {i}'
    rates = []
    rates_centered = []
    lengths = []
    dates = []
    for specimen_peakID in labels:
        growths = growth_intervals.get(specimen_peakID, {})
        stats = growths.get(interval, None)
        if stats and stats['growth_rate'] is not None and not np.isnan(stats['growth_rate']):
            rates.append(stats['growth_rate'])
        if stats and stats['growth_rate_centered'] is not None and not np.isnan(stats['growth_rate_centered']):
            rates_centered.append(stats['growth_rate_centered'])
        if stats and stats['total_time_days'] is not None and not np.isnan(stats['total_time_days']):
            lengths.append(stats['total_time_days'])
        if stats and stats['start_date'] is not None and stats['end_date'] is not None and not pd.isnull(stats['start_date']) and not pd.isnull(stats['end_date']):
            mean_date = stats['start_date'] + (stats['end_date'] - stats['start_date']) / 2
            dates.append(mean_date)
    interval_means[interval] = np.mean(rates) if rates else np.nan
    interval_centered_means[interval] = np.mean(rates_centered) if rates_centered else np.nan
    interval_lengths[interval] = np.mean(lengths) if lengths else np.nan
    interval_dates[interval] = pd.to_datetime(dates).mean() if dates else pd.NaT

for interval in reversed(list(interval_means.keys())):
    mean_rate = interval_means[interval]
    mean_rate_centered = interval_centered_means[interval]
    mean_length = interval_lengths[interval]
    mean_date = interval_dates[interval]
    # Print the mean growth rate, mean interval length, and mean date for each interval
    print(f"{interval}: mean growth rate = {mean_rate:.2f} um/day, mean centered growth rate = {mean_rate_centered:.2f} um/day, mean interval length = {mean_length:.1f} days, mean date = {mean_date.strftime('%Y-%m-%d') if pd.notnull(mean_date) else 'NaT'}")
# Out:
# interval 7: mean growth rate = 17.25 um/day, mean centered growth rate = 17.25 um/day, mean interval length = 46.3 days, mean date = 2022-10-02
# interval 6: mean growth rate = 31.24 um/day, mean centered growth rate = 31.24 um/day, mean interval length = 28.0 days, mean date = 2022-08-26
# interval 5: mean growth rate = 47.98 um/day, mean centered growth rate = 47.98 um/day, mean interval length = 20.7 days, mean date = 2022-08-03
# interval 4: mean growth rate = 45.90 um/day, mean centered growth rate = 45.90 um/day, mean interval length = 27.5 days, mean date = 2022-07-11
# interval 3: mean growth rate = 51.97 um/day, mean centered growth rate = 51.97 um/day, mean interval length = 30.2 days, mean date = 2022-06-16
# interval 2: mean growth rate = 92.88 um/day, mean centered growth rate = 92.88 um/day, mean interval length = 21.7 days, mean date = 2022-05-22
# interval 1: mean growth rate = 128.80 um/day, mean centered growth rate = 128.80 um/day, mean interval length = 17.2 days, mean date = 2022-05-03
# interval 0: mean growth rate = 54.34 um/day, mean centered growth rate = 54.34 um/day, mean interval length = 82.6 days, mean date = 2022-03-14

# %% [markdown]
# ## Plots showing the results of age modelling

# %% [markdown]
# ### Plot total growth and growth rate vs time

# %%
# Create a figure with two subplots: ax1 for shell growth (date x-axis), ax3 for growth rates (interval x-axis)
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(15, 20), sharex=False, gridspec_kw={'height_ratios': [2, 2, 1, 1]})

# Prepare color maps for subtidal and intertidal specimens
subtidal_files = [f for f in dataframes if 'sub' in f.lower()]
intertidal_files = [f for f in dataframes if 'int' in f.lower()]
subtidal_colors = cm.Blues(np.linspace(0.5, 1, len(subtidal_files)))
intertidal_colors = cm.Oranges(np.linspace(0.5, 1, len(intertidal_files)))

sub_idx = 0
inter_idx = 0

# For bar chart
bar_intervals = []
bar_rates = []
bar_colors = []
bar_specimens = []

# Line plot: shell growth vs. date
for file, df in dataframes.items():
    # Loop through each peak identification option
    for timing_col in ['timing_1', 'timing_2', 'timing_3', 'timing_4']:
        # Find column name according to peak label
        if timing_col == 'timing_1':
            timing_centered_col = 'timing_1_centered'
        elif timing_col == 'timing_2':
            timing_centered_col = 'timing_2_centered'
        elif timing_col == 'timing_3':
            timing_centered_col = 'timing_3_centered'
        elif timing_col == 'timing_4':
            timing_centered_col = 'timing_4_centered'
        if 'depth' in df.columns and timing_col in df.columns:
            df_plot = df.copy()
            df_plot[timing_col] = pd.to_datetime(df_plot[timing_col])
            df_plot[timing_centered_col] = pd.to_datetime(df_plot[timing_centered_col])
            df_plot['depth'] = df_plot['depth'].max() - df_plot['depth']
            if 'sub' in file.lower():
                color = subtidal_colors[sub_idx]
            elif 'int' in file.lower():
                color = intertidal_colors[inter_idx]
            ax1.plot(df_plot[timing_col], df_plot['depth'], label=file, alpha=0.7, color=color) # Plotting depth against timing_info
            ax2.plot(df_plot[timing_centered_col], df_plot['depth'], label=file, alpha=0.7, color=color) # Plotting depth against timing_info_centered
    if 'sub' in file.lower():
        sub_idx += 1
    elif 'int' in file.lower():
        inter_idx += 1
    # --- Add caliper long data (distance_mm_individual) with CI to the line plots ---
    for specimen_name in caliper_long['specimen'].unique():
        # Find files containing this specimen name
        matching_files = [f for f in dataframes if specimen_name in f]
        if file in matching_files:
            group = caliper_long[caliper_long['specimen'] == specimen_name]
            # Determine color and label for this specimen (same as line plot)
            if 'sub' in file.lower():
                color = subtidal_colors[subtidal_files.index(file)]
            elif 'int' in file.lower():
                color = intertidal_colors[intertidal_files.index(file)]
            label = file  # Use the same label as in the line plot
            # Plot on ax1 (date x-axis)
            ax1.errorbar(
                group['date'], group['distance_mm_individual'] * 1000,  # Convert to micrometers
                yerr=group['distance_mm_ci_individual'] * 1000 if 'distance_mm_ci_individual' in group.columns else None,
                fmt='o', capsize=4, label=label,
                color=color, alpha=0.8, zorder=10
            )
            # Plot on ax2 (date x-axis, centered if available)
            ax2.errorbar(
                group['date'], group['distance_mm_individual'] * 1000, # Convert to micrometers
                yerr=group['distance_mm_ci_individual'] * 1000 if 'distance_mm_ci_individual' in group.columns else None,
                fmt='o', capsize=4, label=label,
                color=color, alpha=0.8, zorder=10
            )

            # Bar chart: growth rate per interval
            growths = growth_intervals.get(file + "_" + peakID_col, {})
            for interval_label, stats in growths.items():
                if stats['growth_rate'] is not None and not np.isnan(stats['growth_rate']):
                    bar_intervals.append(int(interval_label.split()[-1]))
                    bar_rates.append(stats['growth_rate'])
                    bar_colors.append(color)
                    bar_specimens.append(file)

# --- Prepare for grouped bar plot ---
unique_intervals = [f'interval {i}' for i in interval_numbers][::-1]
unique_specimens_peakIDs = list(labels)
n_intervals = len(unique_intervals)
n_specimens_peakID = len(unique_specimens_peakIDs) # of specimen_peakID combinations
n_specimens = len(dataframes)  # of specimens
print(unique_specimens_peakIDs)

# Build a matrix of growth rates: rows=intervals, cols=specimens
growth_rate_matrix = np.full((n_intervals, n_specimens_peakID), np.nan)
growth_rate_matrix_centered = np.full((n_intervals, n_specimens_peakID), np.nan)
bar_colors_matrix = np.empty((n_intervals, n_specimens_peakID), dtype=object)

for s_idx, specimen_peakID in enumerate(unique_specimens_peakIDs):
    specimen = specimen_peakID.rsplit("_", 2)[0]  # Extract specimen name
    growths = growth_intervals.get(specimen_peakID, {})
    for i_idx, interval in enumerate(unique_intervals):
        stats = growths.get(interval, None)
        if stats and stats['growth_rate'] is not None and not np.isnan(stats['growth_rate']):
            growth_rate_matrix[i_idx, s_idx] = stats['growth_rate']
            growth_rate_matrix_centered[i_idx, s_idx] = stats['growth_rate_centered']
            # Assign color as before
            if 'sub' in specimen_peakID.lower():
                color = subtidal_colors[subtidal_files.index(specimen)]
            elif 'int' in specimen_peakID.lower():
                color = intertidal_colors[intertidal_files.index(specimen)]
            else:
                color = 'green'
            bar_colors_matrix[i_idx, s_idx] = color
        else:
            bar_colors_matrix[i_idx, s_idx] = 'grey'

bar_width = 0.8 / n_specimens_peakID  # Make bars for each interval adjacent

# --- Plot grouped bars ---
for s_idx, specimen_peakID in enumerate(unique_specimens_peakIDs):
    x_positions = np.arange(n_intervals) + s_idx * bar_width - 0.4 + bar_width/2
    ax3.bar(
        x_positions,
        growth_rate_matrix[:, s_idx],
        width=bar_width,
        color=bar_colors_matrix[:, s_idx],
        alpha=0.8,
        label=specimen_peakID if s_idx == 0 else None  # Only label once for legend
    )
    ax4.bar(
        x_positions,
        growth_rate_matrix_centered[:, s_idx],
        width=bar_width,
        color=bar_colors_matrix[:, s_idx],
        alpha=0.8,
        label=specimen_peakID if s_idx == 0 else None  # Only label once for legend
    )

# Set x-ticks for intervals
ax3.set_xticks(np.arange(n_intervals))
ax4.set_xticks(np.arange(n_intervals))
# Add mean dates of intervals to x-tick labels
interval_labels_with_dates = []
for interval in unique_intervals:
    stats = interval_growths.get(interval, {})
    start = stats.get('start_date', None)
    end = stats.get('end_date', None)
    if start is not None and end is not None:
        mean_date = start + (end - start) / 2
        label = f"{interval}\n{mean_date.strftime('%Y-%m-%d')}"
    else:
        label = interval
    interval_labels_with_dates.append(label)

ax3.set_xticklabels(interval_labels_with_dates, rotation=45)
ax3.set_xlabel('Interval')
ax3.set_ylabel('Growth rate (um/day)')
ax3.set_title('Growth rate per interval for all specimens (subtracting peak widths)')
ax4.set_xticklabels(interval_labels_with_dates, rotation=45)
ax4.set_xlabel('Interval')
ax4.set_ylabel('Growth rate (centered; um/day)')
ax4.set_title('Growth rate per interval for all specimens (not regarding peak widths)')

# Format and legend for the shell growth plot
# Add shaded background boxes to delineate intervals on both plots
for i, interval in enumerate(unique_intervals):
    # Get start and end dates for the interval
    stats = interval_growths.get(interval, {})
    start = stats.get('start_date', None)
    end = stats.get('end_date', None)
    if start is not None and end is not None:
        # Alternate color for better visibility
        color = 'lightgrey' if i % 2 == 0 else 'whitesmoke'
        # Shade on ax1 (date x-axis)
        ax1.axvspan(start, end, color=color, alpha=0.3, zorder=0)
        # Shade on ax2 (date x-axis)
        ax2.axvspan(start, end, color=color, alpha=0.3, zorder=0)
        # Shade on ax3 (interval x-axis)
        ax3.axvspan(i - 0.5, i + 0.5, color=color, alpha=0.3, zorder=0)
        # Shade on ax4 (interval x-axis)
        ax4.axvspan(i - 0.5, i + 0.5, color=color, alpha=0.3, zorder=0)
ax1.set_ylabel('Distance along the shell (depth, um)')
ax1.set_title('Shell growth (distance) vs. time for all specimens')
ax2.set_ylabel('Distance along the shell (depth, um)')
ax2.set_title('Shell growth (distance) vs. time for all specimens (not regarding peak widths)')
# Merge legend elements with the same name
handles, labels = ax1.get_legend_handles_labels()
unique = OrderedDict()
for h, l in zip(handles, labels):
    if l not in unique:
        unique[l] = h
ax1.legend(unique.values(), unique.keys(), loc='upper center', bbox_to_anchor=(0.5, 1.25), ncol=6, frameon=False)
plt.tight_layout()
plt.show()
# Out:
# ['B255_int_peakid.csv_peakID_1', 'B255_int_peakid.csv_peakID_2', 'B255_int_peakid.csv_peakID_3', 'B255_int_peakid.csv_peakID_4', 'B323_int_peakid.csv_peakID_1', 'B323_int_peakid.csv_peakID_2', 'B323_int_peakid.csv_peakID_3', 'B323_int_peakid.csv_peakID_4', 'B325_int_peakid.csv_peakID_1', 'B325_int_peakid.csv_peakID_2', 'B325_int_peakid.csv_peakID_3', 'B325_int_peakid.csv_peakID_4', 'G652_sub_peakid.csv_peakID_1', 'G652_sub_peakid.csv_peakID_2', 'G652_sub_peakid.csv_peakID_3', 'G652_sub_peakid.csv_peakID_4', 'G664_sub_peakid.csv_peakID_1', 'G664_sub_peakid.csv_peakID_2', 'G664_sub_peakid.csv_peakID_3', 'G664_sub_peakid.csv_peakID_4', 'G668_sub_peakid.csv_peakID_1', 'G668_sub_peakid.csv_peakID_2', 'G668_sub_peakid.csv_peakID_3', 'G668_sub_peakid.csv_peakID_4', 'G691_int_peakid.csv_peakID_1', 'G691_int_peakid.csv_peakID_2', 'G691_int_peakid.csv_peakID_3', 'G691_int_peakid.csv_peakID_4', 'G717_sub_peakid.csv_peakID_1', 'G717_sub_peakid.csv_peakID_2', 'G717_sub_peakid.csv_peakID_3', 'G717_sub_peakid.csv_peakID_4', 'G719_int_peakid.csv_peakID_1', 'G719_int_peakid.csv_peakID_2', 'G719_int_peakid.csv_peakID_3', 'G719_int_peakid.csv_peakID_4', 'G723_sub_peakid.csv_peakID_1', 'G723_sub_peakid.csv_peakID_2', 'G723_sub_peakid.csv_peakID_3', 'G723_sub_peakid.csv_peakID_4', 'G728_int_peakid.csv_peakID_1', 'G728_int_peakid.csv_peakID_2', 'G728_int_peakid.csv_peakID_3', 'G728_int_peakid.csv_peakID_4', 'G730_sub_peakid.csv_peakID_1', 'G730_sub_peakid.csv_peakID_2', 'G730_sub_peakid.csv_peakID_3', 'G730_sub_peakid.csv_peakID_4', 'G732_sub_peakid.csv_peakID_1', 'G732_sub_peakid.csv_peakID_2', 'G732_sub_peakid.csv_peakID_3', 'G732_sub_peakid.csv_peakID_4', 'G737_sub_peakid.csv_peakID_1', 'G737_sub_peakid.csv_peakID_2', 'G737_sub_peakid.csv_peakID_3', 'G737_sub_peakid.csv_peakID_4', 'G753_sub_peakid.csv_peakID_1', 'G753_sub_peakid.csv_peakID_2', 'G753_sub_peakid.csv_peakID_3', 'G753_sub_peakid.csv_peakID_4', 'G767_sub_peakid.csv_peakID_1', 'G767_sub_peakid.csv_peakID_2', 'G767_sub_peakid.csv_peakID_3', 'G767_sub_peakid.csv_peakID_4', 'G770_sub_peakid.csv_peakID_1', 'G770_sub_peakid.csv_peakID_2', 'G770_sub_peakid.csv_peakID_3', 'G770_sub_peakid.csv_peakID_4', 'G779_int_peakid.csv_peakID_1', 'G779_int_peakid.csv_peakID_2', 'G779_int_peakid.csv_peakID_3', 'G779_int_peakid.csv_peakID_4', 'G781_sub_peakid.csv_peakID_1', 'G781_sub_peakid.csv_peakID_2', 'G781_sub_peakid.csv_peakID_3', 'G781_sub_peakid.csv_peakID_4']

# %% [markdown]
# ### Plot per specimen to scrutinize Sr spiking results on by one

# %%
output_dir = "Figures/Individual growth figures_peakID"
os.makedirs(output_dir, exist_ok=True)

for specimen in dataframes.keys():
    # specimen = next(iter(dataframes.keys())) # First specimen for testing
    df = dataframes[specimen]
    df_plot = df.copy()
    df_plot['depth_rel'] = df_plot['depth'].max() - df_plot['depth'] # Relative depth (distance along shell)

    fig, ax1 = plt.subplots(figsize=(10, 6)) # initialize plot
    ax2 = ax1.twinx()

    # Loop through each peak identification option
    for timing_col in ['timing_1', 'timing_2', 'timing_3', 'timing_4']:
        # Find column name according to peak label
        if timing_col == 'timing_1':
            timing_centered_col = 'timing_1_centered'
            peakID_col = 'peakID_1'
        elif timing_col == 'timing_2':
            timing_centered_col = 'timing_2_centered'
            peakID_col = 'peakID_2'
        elif timing_col == 'timing_3':
            timing_centered_col = 'timing_3_centered'
            peakID_col = 'peakID_3'
        elif timing_col == 'timing_4':
            timing_centered_col = 'timing_4_centered'
            peakID_col = 'peakID_4'
        
        growths = growth_intervals[specimen + "_" + peakID_col]

        # Plot shell growth (distance along shell vs. time)
        df_plot[timing_col] = pd.to_datetime(df_plot[timing_col])
        df_plot[timing_centered_col] = pd.to_datetime(df_plot[timing_centered_col])
        ax1.plot(df_plot[timing_col], df_plot['depth_rel'], label='Shell growth ' + peakID_col, color='blue')
        ax1.plot(df_plot[timing_centered_col], df_plot['depth_rel'], label='Shell growth (ignoring peak widths) ' + peakID_col, color='lightblue')

        # Plot growth rate as bars on a secondary y-axis
        interval_labels = sorted(growths.keys(), key=lambda x: int(x.split()[-1]))
        growth_rates = [growths[label]['growth_rate'] for label in interval_labels]
        growth_rates_centered = [growths[label]['growth_rate_centered'] for label in interval_labels]
        interval_dates = [
            growths[label]['start_date'] + (growths[label]['end_date'] - growths[label]['start_date']) / 2
            if growths[label]['start_date'] is not None and growths[label]['end_date'] is not None else pd.NaT
            for label in interval_labels
        ]
        bar_width = 2 # days, half-width for each bar

        # Offset the bars so they are adjacent
        ax2.bar([d - pd.Timedelta(days=(bar_width * int(peakID_col[-1]))) for d in interval_dates], growth_rates, width=bar_width, alpha=0.6, color='orange', label='Growth rate (um/day) ' + peakID_col)
        ax2.bar([d + pd.Timedelta(days=(bar_width * int(peakID_col[-1]))) for d in interval_dates], growth_rates_centered, width=bar_width, alpha=0.6, color='green', label='Growth rate (ignoring peak widths; um/day) ' + peakID_col)

    # Add caliper measurements (distance_mm_individual) with CI to the plots
    # Extract specimen name (e.g., 'B255' from 'B255_peakid.csv')
    match = re.match(r'([A-Z]\d{3})', specimen)
    if match:
        specimen_short = match.group(1)
        group = caliper_long[caliper_long['specimen'] == specimen_short]
        if not group.empty:
            # Plot on ax1 (distance along shell vs. date)
            ax1.errorbar(
                group['date'],
                group['distance_mm_individual'] * 1000,  # Convert mm to um
                yerr=group['distance_mm_ci_individual'] * 1000 if 'distance_mm_ci_individual' in group.columns else None,
                fmt='o', capsize=4, color='red', alpha=0.8, label='Caliper measurement (converted to distance along shell, um)'
            )

    # Plot layout
    ax1.set_xlabel('Date')
    ax1.set_ylabel('Distance along shell (um)', color='blue')
    ax1.tick_params(axis='y', labelcolor='blue')
    ax2.set_ylabel('Growth rate (um/day)', color='orange')
    ax2.tick_params(axis='y', labelcolor='orange')
    # Merge both legends into one
    handles1, labels1 = ax1.get_legend_handles_labels()
    handles2, labels2 = ax2.get_legend_handles_labels()
    ax1.legend(handles1 + handles2, labels1 + labels2, loc='upper left')

    fig.suptitle(f'Shell Growth and Growth Rate for {specimen}')
    fig.tight_layout()
    fig.savefig(os.path.join(output_dir, f"{specimen.replace('.csv','')}_growth.png"), dpi=300)
    plt.close(fig)

# %% [markdown]
# ## Summarize trace element results per interval and export summary

# %%
# Collect summary statistics for all elemental columns in all dataframes, split by 'peak' and 'interval'
elemental_columns = [
    col for col in next(iter(dataframes.values())).columns
    if any(x in col for x in ['Ca', 'Na', 'Mg', 'Mn', 'Sr', 'Ba'])
]

summary_list = []

for file, df in dataframes.items():
    # Loop through each peak identification option
    for timing_col in ['timing_1', 'timing_2', 'timing_3', 'timing_4']:
        # Determine which peakID column to use based on timing_col
        if timing_col == 'timing_1':
            peakID_col = 'peakID_1'
        elif timing_col == 'timing_2':
            peakID_col = 'peakID_2'
        elif timing_col == 'timing_3':
            peakID_col = 'peakID_3'
        elif timing_col == 'timing_4':
            peakID_col = 'peakID_4'

        # Use the selected peakID column for categorization
        df['peak'] = df[peakID_col]
        for category in ['peak', 'interval']:
            # Select rows where 'peak' column starts with the category name
            unique_categories = df['peak'].dropna().unique()
            for cat in unique_categories:
                if not cat.startswith(category):
                    continue
                cat_rows = df[df['peak'] == cat]
                for elem in elemental_columns:
                    if elem in cat_rows.columns:
                        values = cat_rows[elem].dropna()
                        N = values.count()
                        mean = values.mean()
                        std = values.std(ddof=1)
                        se = std / np.sqrt(N) if N > 0 else np.nan
                        cl95 = se * t.ppf(0.975, N-1) if N > 1 else np.nan

                        # Get start and end date from timing_info
                        timing_info = pd.to_datetime(cat_rows[timing_col], errors='coerce')
                        start_date = timing_info.min() if not timing_info.isnull().all() else None
                        end_date = timing_info.max() if not timing_info.isnull().all() else None

                        # Get growth_rate_centered if available from growth_intervals (only for intervals)
                        growth_rate_centered = None
                        if cat.startswith('interval'):
                            growths = growth_intervals[file + '_' + peakID_col]  # Get growth intervals for the current file
                            if cat in growths and 'growth_rate_centered' in growths[cat]:
                                growth_rate_centered = growths[cat]['growth_rate_centered']

                        # Extract specimen name (e.g., 'B255' from 'B255_peakid.csv')
                        specimen_match = re.match(r'([A-Z]\d{3})', file)
                        specimen_name = specimen_match.group(1) if specimen_match else file

                        summary_list.append({
                            'specimen': specimen_name,
                            'peakID': peakID_col,
                            'category': cat,
                            'element': elem,
                            'mean': mean,
                            'std': std,
                            'se': se,
                            'cl95': cl95,
                            'N': N,
                            'growth_rate': growth_rate_centered,
                            'start_date': start_date,
                            'end_date': end_date
                        })

element_summary_df = pd.DataFrame(summary_list)
print(element_summary_df.head())
# Export the element summary dataframe to CSV
element_summary_df.to_csv("element_summary_by_peak_and_interval_peakID.csv", index=False)
# Out:
#   specimen    peakID category    element           mean           std  \
# 0     B255  peakID_1   peak 7       Ca43  416098.466128  46291.475506
# 1     B255  peakID_1   peak 7  23Na/43Ca      22.945457      3.844426
# 2     B255  peakID_1   peak 7  25Mg/43Ca       0.913142      0.191774
# 3     B255  peakID_1   peak 7  43Ca/43Ca    1000.000000      0.000000
# 4     B255  peakID_1   peak 7  55Mn/43Ca       0.004705      0.000695
#
#             se         cl95    N  growth_rate          start_date  \
# 0  3032.655393  5975.064833  233          NaN 2022-09-09 01:40:00
# 1     0.251857     0.496219  233          NaN 2022-09-09 01:40:00
# 2     0.012564     0.024753  233          NaN 2022-09-09 01:40:00
# 3     0.000000     0.000000  233          NaN 2022-09-09 01:40:00
# 4     0.000046     0.000090  233          NaN 2022-09-09 01:40:00
#
#              end_date
# 0 2022-09-09 01:40:00
# 1 2022-09-09 01:40:00
# 2 2022-09-09 01:40:00
# 3 2022-09-09 01:40:00
# 4 2022-09-09 01:40:00

# %% [markdown]
# ### Example of a growth rate plot

# %%
# Filter for interval rows and Sr/Ca ratios in the summary DataFrame
interval_sr = element_summary_df[
    (element_summary_df['category'].str.startswith('interval')) &
    (element_summary_df['element'] == '88Sr/43Ca')
].copy()

# Remove rows with missing growth_rate or mean
interval_sr = interval_sr.dropna(subset=['growth_rate', 'mean'])

# Assign a color to each specimen
specimens = interval_sr['specimen'].unique()
colors = plt.cm.tab20(np.linspace(0, 1, len(specimens)))
color_map = dict(zip(specimens, colors))

plt.figure(figsize=(8, 6))
for specimen in specimens:
    data = interval_sr[interval_sr['specimen'] == specimen]
    plt.errorbar(
        data['growth_rate'],
        data['mean'],
        yerr=data['cl95'],
        fmt='o',
        ecolor=color_map[specimen],
        color=color_map[specimen],
        capsize=4,
        label=specimen
    )

plt.xlabel('Growth rate (um/day)')
plt.ylabel('Sr/Ca ratio (mean ± 95% CL)')
plt.title('Sr/Ca Ratio vs Growth Rate (Intervals)')
plt.grid(True)
plt.legend(title='Specimen')
plt.tight_layout()
plt.show()
